# %% [markdown]
# # Imports

# %%
# General

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Hyperparameter tuning
import optuna

# Models
import lightgbm as lgb
import xgboost as xgb
from catboost import CatBoostClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier

# Data processing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Metrics
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# # Data preparation

# %%
# Data input

try:
    data = pd.read_csv('../data/train.csv')
    data_to_predict = pd.read_csv('../data/test.csv')
    data_ccrisk = pd.read_csv('../data/credit_risk_dataset.csv')

except:
    data = pd.read_csv('/kaggle/input/playground-series-s4e10/train.csv')
    data_to_predict = pd.read_csv('/kaggle/input/playground-series-s4e10/test.csv')
    data_ccrisk = pd.read_csv('/kaggle/input/loan-approval-prediction/credit_risk_dataset.csv')


data_ccrisk.dropna(inplace=True)
data_ccrisk.drop_duplicates(inplace=True)

X_old = data.drop(['loan_status'], axis=1)
y_old = data['loan_status']

# Merge the dataframes
data_no_id = data.drop(['id'], axis=1)
merged_data = pd.concat([data_no_id, data_ccrisk], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 4
#       3 try:
# ----> 4     data = pd.read_csv('../data/train.csv')
#       5     data_to_predict = pd.read_csv('../data/test.csv')
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     861 if ioargs.encoding and "b" not in ioargs.mode:
#     862     # Encoding
# --> 863     handle = open(
#     864         handle,
#     865         ioargs.mode,
#     866         encoding=ioargs.encoding,
#     867         errors=errors,
#     868         newline="",
#     869     )
#     870 else:
#     871     # Binary mode
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/train.csv'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       6     data_ccrisk = pd.read_csv('../data/credit_risk_dataset.csv')
#       8 except:
# ----> 9     data = pd.read_csv('/kaggle/input/playground-series-s4e10/train.csv')
#      10     data_to_predict = pd.read_csv('/kaggle/input/playground-series-s4e10/test.csv')
#      11     data_ccrisk = pd.read_csv('/kaggle/input/loan-approval-prediction/credit_risk_dataset.csv')
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\Denis\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:863, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     858 elif isinstance(handle, str):
#     859     # Check whether the filename is to be opened in binary mode.
#     860     # Binary mode does not support 'encoding' and 'newline'.
#     861     if ioargs.encoding and "b" not in ioargs.mode:
#     862         # Encoding
# --> 863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#     866             encoding=ioargs.encoding,
#     867             errors=errors,
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
#     872         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/kaggle/input/playground-series-s4e10/train.csv'

# %%
def remove_col_prefix(dataframe, prefix):
	dataframe.columns = dataframe.columns.str.replace(prefix, '')
	return dataframe

merged_data = remove_col_prefix(merged_data, 'person_')
merged_data = remove_col_prefix(merged_data, 'loan_')


print(merged_data.isnull().sum())
print(merged_data.duplicated().sum())
# Out:
# age                    0
# income                 0
# home_ownership         0
# emp_length             0
# intent                 0
# grade                  0
# amnt                   0
# int_rate               0
# percent_income         0
# cb_default_on_file     0
# cb_cred_hist_length    0
# status                 0
# dtype: int64
# 0

# %% [markdown]
# # Feature engineering

# %% [markdown]
# ## Feature engineering function

# %%
from scipy.stats import zscore

numeric_columns = merged_data.select_dtypes(include=[np.number]).columns

def remove_outiers(dataframe, numeric_cols, z_threshold=4):
	dataframe = dataframe[(np.abs(zscore(dataframe[numeric_cols])) < z_threshold).all(axis=1)].copy()
	return dataframe

data_no_outliers = remove_outiers(merged_data, numeric_columns)

merged_data.shape, data_no_outliers.shape# Create income bins before calling the function
income_bins = pd.qcut(data_no_outliers['income'], q=5, retbins=True)[1]

def feature_engineering(dataframe, income_bins):

    # Map grades to numerical values
    grade_mapping = {'A': 1, 'B': 2, 'C': 3, 'D': 4, 'E': 5, 'F': 6, 'G': 7}
    dataframe['grade_numeric'] = dataframe['grade'].map(grade_mapping)

    # Map cb_default_on_file to binary values
    dataframe['cb_default_on_file'] = dataframe['cb_default_on_file'].map({'Y': 1, 'N': 0})
    
    # Feature engineering
    dataframe['total_income'] = (dataframe['emp_length'] + 1) * dataframe['income']
    dataframe['emp_length_to_age_ratio'] = dataframe['emp_length'] / dataframe['age']
    dataframe['income_to_age_ratio'] = dataframe['income'] / dataframe['age']
    dataframe['total_income_to_age_ratio'] = dataframe['total_income'] / dataframe['age']
    dataframe['income_category'] = pd.cut(dataframe['income'], bins=income_bins, labels=[1, 2, 3, 4, 5])
    dataframe['income_to_loan_ratio'] = dataframe['income'] / dataframe['amnt']
    dataframe['total_income_to_loan_ratio'] = dataframe['total_income'] / dataframe['amnt']
    dataframe['loan_income_age_interaction'] = dataframe['amnt'] / (dataframe['income'] * dataframe['age'])
    dataframe['income_grade_interaction'] = dataframe['income'] * dataframe['grade_numeric']
    dataframe['loan_grade_ratio'] = dataframe['amnt'] / dataframe['grade_numeric']
    dataframe['emp_to_cred_hist_ratio'] = dataframe['emp_length'] / (dataframe['cb_cred_hist_length'] + 1)
    dataframe['credit_behavior_score'] = (1 - dataframe['cb_default_on_file']) * dataframe['cb_cred_hist_length']
    dataframe['affordability_score'] = dataframe['income'] / (dataframe['amnt'] * (1 + dataframe['int_rate']/100))
    dataframe['interest_cost'] = dataframe['amnt'] * dataframe['int_rate'] / 100 
    dataframe['emp_length_loan_interaction'] = dataframe['emp_length'] * dataframe['amnt']

    # Lists of numeric and ordinal features
    numeric = [
        'total_income', 'emp_length_to_age_ratio', 'income_to_age_ratio', 
        'total_income_to_age_ratio', 'income_to_loan_ratio', 
        'total_income_to_loan_ratio', 'loan_income_age_interaction', 
        'income_grade_interaction', 'loan_grade_ratio', 'emp_to_cred_hist_ratio', 
        'credit_behavior_score', 'affordability_score', 'interest_cost', 
        'emp_length_loan_interaction'
    ]
    ordinal = ['income_category']

    return dataframe, numeric, ordinal

# %%
# Addind the new features to the data
data_no_outliers, new_features_numeric, new_features_ordinal = feature_engineering(data_no_outliers, income_bins)
X = data_no_outliers.drop(['status'], axis=1)
y = data_no_outliers['status']

X
# Out:
#        age  income home_ownership  emp_length           intent grade   amnt  \
# 0       37   35000           RENT         0.0        EDUCATION     B   6000
# 1       22   56000            OWN         6.0          MEDICAL     C   4000
# 2       29   28800            OWN         8.0         PERSONAL     A   6000
# 3       30   70000           RENT        14.0          VENTURE     B  12000
# 4       22   60000           RENT         2.0          MEDICAL     A   6000
# ...    ...     ...            ...         ...              ...   ...    ...
# 87055   51   76960       MORTGAGE         0.0         PERSONAL     B  15000
# 87122   51   80000           RENT         3.0  HOMEIMPROVEMENT     F  18000
# 87133   52   30000           RENT         6.0          VENTURE     C   5000
# 87139   52   65004           RENT         4.0         PERSONAL     D  20000
# 87140   52   64500           RENT         0.0        EDUCATION     B   5000
#
#        int_rate  percent_income  cb_default_on_file  ...  \
# 0         11.49            0.17                   0  ...
# 1         13.35            0.07                   0  ...
# 2          8.90            0.21                   0  ...
# 3         11.11            0.17                   0  ...
# 4          6.92            0.10                   0  ...
# ...         ...             ...                 ...  ...
# 87055      9.99            0.19                   0  ...
# 87122     18.78            0.23                   1  ...
# 87133     12.73            0.17                   0  ...
# 87139     15.58            0.31                   1  ...
# 87140     11.26            0.08                   0  ...
#
#        income_to_loan_ratio  total_income_to_loan_ratio  \
# 0                  5.833333                    5.833333
# 1                 14.000000                   98.000000
# 2                  4.800000                   43.200000
# 3                  5.833333                   87.500000
# 4                 10.000000                   30.000000
# ...                     ...                         ...
# 87055              5.130667                    5.130667
# 87122              4.444444                   17.777778
# 87133              6.000000                   42.000000
# 87139              3.250200                   16.251000
# 87140             12.900000                   12.900000
#
#        loan_income_age_interaction  income_grade_interaction  \
# 0                         0.004633                     70000
# 1                         0.003247                    168000
# 2                         0.007184                     28800
# 3                         0.005714                    140000
# 4                         0.004545                     60000
# ...                            ...                       ...
# 87055                     0.003822                    153920
# 87122                     0.004412                    480000
# 87133                     0.003205                     90000
# 87139                     0.005917                    260016
# 87140                     0.001491                    129000
#
#        loan_grade_ratio  emp_to_cred_hist_ratio credit_behavior_score  \
# 0           3000.000000                0.000000                    14
# 1           1333.333333                2.000000                     2
# 2           6000.000000                0.727273                    10
# 3           6000.000000                2.333333                     5
# 4           6000.000000                0.500000                     3
# ...                 ...                     ...                   ...
# 87055       7500.000000                0.000000                    20
# 87122       3000.000000                0.142857                     0
# 87133       1666.666667                0.315789                    18
# 87139       5000.000000                0.200000                     0
# 87140       2500.000000                0.000000                    20
#
#        affordability_score  interest_cost  emp_length_loan_interaction
# 0                 5.232158          689.4                          0.0
# 1                12.351125          534.0                      24000.0
# 2                 4.407713          534.0                      48000.0
# 3                 5.250053         1333.2                     168000.0
# 4                 9.352787          415.2                      12000.0
# ...                    ...            ...                          ...
# 87055             4.664666         1498.5                          0.0
# 87122             3.741745         3380.4                      54000.0
# 87133             5.322452          636.5                      30000.0
# 87139             2.812078         3116.0                      80000.0
# 87140            11.594463          563.0                          0.0
#
# [85518 rows x 27 columns]

# %%
# Cleaning and adding the new features to the data to predict
data_to_predict = remove_col_prefix(data_to_predict, 'person_')
data_to_predict = remove_col_prefix(data_to_predict, 'loan_')
data_to_predict = feature_engineering(data_to_predict, income_bins)[0]

# %%
column_names = data_to_predict.columns
column_names, X.dtypes
# Out:
# (Index(['age', 'income', 'home_ownership', 'emp_length', 'intent', 'grade',
#         'amnt', 'int_rate', 'percent_income', 'cb_default_on_file',
#         'cb_cred_hist_length', 'status', 'grade_numeric', 'total_income',
#         'emp_length_to_age_ratio', 'income_to_age_ratio',
#         'total_income_to_age_ratio', 'income_category', 'income_to_loan_ratio',
#         'total_income_to_loan_ratio', 'loan_income_age_interaction',
#         'income_grade_interaction', 'loan_grade_ratio',
#         'emp_to_cred_hist_ratio', 'credit_behavior_score',
#         'affordability_score', 'interest_cost', 'emp_length_loan_interaction'],
#        dtype='object'),
#  age                               int64
#  income                            int64
#  home_ownership                   object
#  emp_length                      float64
#  intent                           object
#  grade                            object
#  amnt                              int64
#  int_rate                        float64
#  percent_income                  float64
#  cb_default_on_file                int64
#  cb_cred_hist_length               int64
#  grade_numeric                     int64
#  total_income                    float64
#  emp_length_to_age_ratio         float64
#  income_to_age_ratio             float64
#  total_income_to_age_ratio       float64
#  income_category                category
#  income_to_loan_ratio            float64
#  total_income_to_loan_ratio      float64
#  loan_income_age_interaction     float64
#  income_grade_interaction          int64
#  loan_grade_ratio                float64
#  emp_to_cred_hist_ratio          float64
#  credit_behavior_score             int64
#  affordability_score             float64
#  interest_cost                   float64
#  emp_length_loan_interaction     float64
#  dtype: object)

# %% [markdown]
# # Preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, shuffle=True, test_size=0.2, random_state=2024)

# %%
onehot_cols = ['home_ownership', 'intent', 'cb_default_on_file']
ordinal_cols = ['grade', 'income_category']
standardize_cols = [
    'age', 'income', 'emp_length', 'amnt', 'int_rate', 'percent_income', 
    'cb_cred_hist_length', 'total_income', 'emp_length_to_age_ratio', 
    'income_to_age_ratio', 'total_income_to_age_ratio', 'income_to_loan_ratio', 
    'total_income_to_loan_ratio', 'loan_income_age_interaction', 
    'income_grade_interaction', 'loan_grade_ratio', 'emp_to_cred_hist_ratio', 
    'credit_behavior_score', 'affordability_score', 'interest_cost', 
    'emp_length_loan_interaction', 'grade_numeric'
]
log_transform_cols = ['income', 'total_income', 'amnt', 'interest_cost']

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.impute import SimpleImputer

def log_transform():
	return FunctionTransformer(np.log1p, validate=True)

# Imputers for missing values
ordinal_imputer = SimpleImputer(strategy='most_frequent')
onehot_imputer = SimpleImputer(strategy='most_frequent')
scaler_imputer = SimpleImputer(strategy='mean')
log_imputer = SimpleImputer(strategy='mean')

preprocessor = ColumnTransformer(
	transformers=[
		('ordinal', Pipeline([('imputer', ordinal_imputer), ('encoder', OrdinalEncoder())]), ordinal_cols),
		('onehot', Pipeline([('imputer', onehot_imputer), ('encoder', OneHotEncoder())]), onehot_cols),
		('scaler', Pipeline([('imputer', scaler_imputer), ('scaler', StandardScaler())]), standardize_cols),
		('log', Pipeline([('imputer', log_imputer), ('log', log_transform())]), log_transform_cols)
	], 
	remainder='passthrough',
	)

preprocessor.fit(X_train)

X_train_prep = preprocessor.transform(X_train)
X_test_prep = preprocessor.transform(X_test)
data_prep = preprocessor.transform(data_no_outliers)
X_all_prep = preprocessor.transform(X)

# %%
# Column naming with prefix for clarity
standardize_cols_names = []
for name in standardize_cols:
	standardize_cols_names.append('std_' + name)

log_transform_cols_names = []
for name in log_transform_cols:
	log_transform_cols_names.append('log_' + name)
    
cols = preprocessor.transformers_[0][1]['encoder'].get_feature_names_out(ordinal_cols).tolist()
cols += preprocessor.transformers_[1][1]['encoder'].get_feature_names_out(onehot_cols).tolist()
cols += standardize_cols_names
cols += log_transform_cols_names

training_data_df = pd.DataFrame(X_train_prep, columns=cols)

training_plus_target = training_data_df.copy()
training_plus_target['status'] = y_train.values

# Taking a look at correlation
training_plus_target.corr()['status'].sort_values(ascending=False)
# Out:
# status                             1.000000
# grade                              0.390432
# std_grade_numeric                  0.390432
# std_percent_income                 0.380154
# std_loan_income_age_interaction    0.363538
# std_int_rate                       0.345783
# std_interest_cost                  0.248579
# home_ownership_RENT                0.235389
# log_interest_cost                  0.220479
# cb_default_on_file_1               0.186356
# std_amnt                           0.133784
# log_amnt                           0.105537
# std_income_grade_interaction       0.096991
# intent_DEBTCONSOLIDATION           0.062272
# intent_MEDICAL                     0.050808
# intent_HOMEIMPROVEMENT             0.031135
# home_ownership_OTHER               0.003491
# std_emp_length_loan_interaction   -0.002656
# intent_PERSONAL                   -0.011013
# std_cb_cred_hist_length           -0.013980
# std_age                           -0.015303
# intent_EDUCATION                  -0.056155
# intent_VENTURE                    -0.067205
# std_emp_to_cred_hist_ratio        -0.079037
# home_ownership_OWN                -0.088541
# std_loan_grade_ratio              -0.097189
# std_emp_length                    -0.098131
# std_emp_length_to_age_ratio       -0.099576
# std_credit_behavior_score         -0.106630
# std_total_income_to_loan_ratio    -0.147973
# std_total_income                  -0.156565
# std_total_income_to_age_ratio     -0.163864
# std_income_to_loan_ratio          -0.173331
# std_affordability_score           -0.181296
# cb_default_on_file_0              -0.186356
# home_ownership_MORTGAGE           -0.196138
# std_income_to_age_ratio           -0.205435
# log_total_income                  -0.208215
# std_income                        -0.212002
# income_category                   -0.236442
# log_income                        -0.258460
# Name: status, dtype: float64

# %% [markdown]
# # Models

# %% [markdown]
# ## XGBoost

# %%
def xgb_objective(trial):
    # Hyperparameter search space
    param = {
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 0.5),
        'lambda': trial.suggest_float('lambda', 1e-8, 10.0, log=True),
        'alpha': trial.suggest_float('alpha', 1e-8, 10.0, log=True),
        'scale_pos_weight': trial.suggest_float('scale_pos_weight', 1.0, 3.0),
        'eval_metric': 'auc',  # AUC is the metric
        'objective': 'binary:logistic'  # Use binary logistic, probability outputs
    }

    # Initialize the model
    model = xgb.XGBClassifier(**param)

    # Fit the model
    model.fit(X_train_prep, y_train, 
              eval_set=[(X_test_prep, y_test)],  
              verbose=False)

    # Predict proba for validation set
    y_pred_prob = model.predict_proba(X_test_prep)[:, 1]

    auc = roc_auc_score(y_test, y_pred_prob)
 
    return auc

# Study object to run the optimization. I want to maximize AUC
xgb_study = optuna.create_study(direction='maximize')
xgb_study.optimize(xgb_objective, n_trials=500, timeout=3600*2)

print(f"Best trial: {xgb_study.best_trial.params}")
# Out:
# [I 2024-10-31 16:02:07,858] A new study created in memory with name: no-name-358c76c5-e610-4466-8687-8f4904f39901
# [I 2024-10-31 16:02:15,714] Trial 0 finished with value: 0.9500792045236812 and parameters: {'max_depth': 6, 'learning_rate': 0.2293494537019517, 'n_estimators': 451, 'subsample': 0.9085805573664184, 'colsample_bytree': 0.8886206491890367, 'gamma': 0.48474332742196896, 'lambda': 0.20043577961299971, 'alpha': 4.506421605253883e-05, 'scale_pos_weight': 1.5429807693918027}. Best is trial 0 with value: 0.9500792045236812.
# [I 2024-10-31 16:02:21,331] Trial 1 finished with value: 0.9474706290960709 and parameters: {'max_depth': 6, 'learning_rate': 0.28216118561305686, 'n_estimators': 328, 'subsample': 0.9196988755107399, 'colsample_bytree': 0.8354086555720813, 'gamma': 0.3379984388905105, 'lambda': 3.164512230207635e-08, 'alpha': 1.6964194852379622e-08, 'scale_pos_weight': 2.926591459263859}. Best is trial 0 with value: 0.9500792045236812.
# [I 2024-10-31 16:02:30,941] Trial 2 finished with value: 0.9535816065286609 and parameters: {'max_depth': 7, 'learning_rate': 0.07532334148500143, 'n_estimators': 395, 'subsample': 0.9249042869494811, 'colsample_bytree': 0.8357151665891027, 'gamma': 0.37162378743106184, 'lambda': 0.0003148403719249849, 'alpha': 0.0008069569796769319, 'scale_pos_weight': 1.0297163284614883}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:02:39,579] Trial 3 finished with value: 0.9507468297148537 and parameters: {'max_depth': 9, 'learning_rate': 0.021779098901286792, 'n_estimators': 304, 'subsample': 0.8136021629219211, 'colsample_bytree': 0.9004953548628731, 'gamma': 0.38239219394201673, 'lambda': 3.180288134964242e-05, 'alpha': 0.006840290701085122, 'scale_pos_weight': 2.0666527812603377}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:02:47,263] Trial 4 finished with value: 0.9492362252948477 and parameters: {'max_depth': 7, 'learning_rate': 0.1598158573532209, 'n_estimators': 405, 'subsample': 0.7253174397288952, 'colsample_bytree': 0.6361276720302499, 'gamma': 0.3677802495181662, 'lambda': 0.010589823676872407, 'alpha': 1.2221969744054198e-06, 'scale_pos_weight': 1.056970120798369}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:02:57,459] Trial 5 finished with value: 0.9489192215355107 and parameters: {'max_depth': 9, 'learning_rate': 0.1805700501947149, 'n_estimators': 420, 'subsample': 0.8635050723581833, 'colsample_bytree': 0.8574614870429056, 'gamma': 0.27310096846284393, 'lambda': 0.009296228915197186, 'alpha': 1.1148890708280445e-07, 'scale_pos_weight': 1.6148480099291893}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:03,508] Trial 6 finished with value: 0.9438327043016264 and parameters: {'max_depth': 8, 'learning_rate': 0.23830429644713494, 'n_estimators': 256, 'subsample': 0.6270967940146447, 'colsample_bytree': 0.9593392560571464, 'gamma': 0.2102274904246318, 'lambda': 0.06700192307640485, 'alpha': 5.266308708300247e-06, 'scale_pos_weight': 1.403171802005884}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:10,210] Trial 7 finished with value: 0.9520156245435745 and parameters: {'max_depth': 3, 'learning_rate': 0.26920365468849417, 'n_estimators': 498, 'subsample': 0.7364018157443424, 'colsample_bytree': 0.6371034411578074, 'gamma': 0.4978777276878908, 'lambda': 0.04641571971736504, 'alpha': 3.419839973532409e-05, 'scale_pos_weight': 2.6890993752115397}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:12,892] Trial 8 finished with value: 0.946841956340595 and parameters: {'max_depth': 9, 'learning_rate': 0.27828085703725436, 'n_estimators': 108, 'subsample': 0.9475470010109537, 'colsample_bytree': 0.6116948177859804, 'gamma': 0.07143093146940505, 'lambda': 0.0006273484418381234, 'alpha': 5.706461216502557e-08, 'scale_pos_weight': 1.7733531912541007}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:18,886] Trial 9 finished with value: 0.9523916325167556 and parameters: {'max_depth': 7, 'learning_rate': 0.07486864647479996, 'n_estimators': 303, 'subsample': 0.6340415025205476, 'colsample_bytree': 0.7277811462809716, 'gamma': 0.3318036090297302, 'lambda': 0.0012641383888669013, 'alpha': 2.6661612120171147e-07, 'scale_pos_weight': 1.6544453842286024}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:21,864] Trial 10 finished with value: 0.9497395496816224 and parameters: {'max_depth': 4, 'learning_rate': 0.08973804311841055, 'n_estimators': 208, 'subsample': 0.9817125412862568, 'colsample_bytree': 0.527707900371315, 'gamma': 0.14114494910311845, 'lambda': 6.513243078435507, 'alpha': 1.290365075109711, 'scale_pos_weight': 2.271127298221315}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:29,099] Trial 11 finished with value: 0.95295404776086 and parameters: {'max_depth': 5, 'learning_rate': 0.0799237625999035, 'n_estimators': 351, 'subsample': 0.618405146610008, 'colsample_bytree': 0.7592074198776787, 'gamma': 0.27571201258783523, 'lambda': 1.3916910498612444e-05, 'alpha': 0.00450129661396698, 'scale_pos_weight': 1.0470864650821903}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:34,920] Trial 12 finished with value: 0.9534818303659178 and parameters: {'max_depth': 5, 'learning_rate': 0.095127737191108, 'n_estimators': 368, 'subsample': 0.7136337394784933, 'colsample_bytree': 0.7507932394912862, 'gamma': 0.23151790581308518, 'lambda': 2.1589963603275226e-06, 'alpha': 0.00589770897833842, 'scale_pos_weight': 1.0413949162387541}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:40,758] Trial 13 finished with value: 0.9531326571180595 and parameters: {'max_depth': 5, 'learning_rate': 0.12289457263394854, 'n_estimators': 382, 'subsample': 0.7367559751620034, 'colsample_bytree': 0.7648815289015505, 'gamma': 0.18986067939189938, 'lambda': 3.6365625814377447e-07, 'alpha': 0.12591021675041358, 'scale_pos_weight': 1.2476347723029515}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:44,714] Trial 14 finished with value: 0.946044143123156 and parameters: {'max_depth': 5, 'learning_rate': 0.03791144423011097, 'n_estimators': 236, 'subsample': 0.8079978449036268, 'colsample_bytree': 0.9923009407114974, 'gamma': 0.42225825645649084, 'lambda': 7.606989937645196e-06, 'alpha': 0.0007537361137364284, 'scale_pos_weight': 1.3403790037770127}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:03:50,973] Trial 15 finished with value: 0.9516812054435875 and parameters: {'max_depth': 3, 'learning_rate': 0.11444900411725045, 'n_estimators': 480, 'subsample': 0.6792172487384049, 'colsample_bytree': 0.8114518008959934, 'gamma': 0.0473626980102419, 'lambda': 6.12530050588308e-07, 'alpha': 0.07047927523313774, 'scale_pos_weight': 1.0328889012218414}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:04:02,550] Trial 16 finished with value: 0.9535245579820683 and parameters: {'max_depth': 10, 'learning_rate': 0.05077073309861931, 'n_estimators': 366, 'subsample': 0.8577040881724677, 'colsample_bytree': 0.6895165901676941, 'gamma': 0.12407608878776291, 'lambda': 9.002950637485477e-05, 'alpha': 8.390901818520875, 'scale_pos_weight': 1.9071373094650879}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:04:14,604] Trial 17 finished with value: 0.9524922379814345 and parameters: {'max_depth': 10, 'learning_rate': 0.05475037835004423, 'n_estimators': 439, 'subsample': 0.8622955020121443, 'colsample_bytree': 0.6965354610549376, 'gamma': 0.10926197287567452, 'lambda': 0.00010885125554934218, 'alpha': 9.836541908561012, 'scale_pos_weight': 2.402706224424247}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:04:19,477] Trial 18 finished with value: 0.9426228765538271 and parameters: {'max_depth': 10, 'learning_rate': 0.01914449056810258, 'n_estimators': 183, 'subsample': 0.8549743606637189, 'colsample_bytree': 0.5326662849569397, 'gamma': 0.160443180735293, 'lambda': 0.00025106502317654984, 'alpha': 8.814718342661248, 'scale_pos_weight': 1.902030759436884}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:04:26,924] Trial 19 finished with value: 0.9532698013784732 and parameters: {'max_depth': 8, 'learning_rate': 0.053168343023160355, 'n_estimators': 343, 'subsample': 0.985186428511744, 'colsample_bytree': 0.8022351907823538, 'gamma': 0.10296687727045739, 'lambda': 1.3373754938318665e-08, 'alpha': 0.3305958984491506, 'scale_pos_weight': 2.2171337719084345}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:04:34,512] Trial 20 finished with value: 0.9504378590444164 and parameters: {'max_depth': 8, 'learning_rate': 0.13401559024402843, 'n_estimators': 268, 'subsample': 0.8960035699466188, 'colsample_bytree': 0.908566716605625, 'gamma': 0.0016784528030670681, 'lambda': 0.002712917138028998, 'alpha': 0.00017823872033848417, 'scale_pos_weight': 2.596809704740619}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:04:40,846] Trial 21 finished with value: 0.9528868371711448 and parameters: {'max_depth': 6, 'learning_rate': 0.09906858613058274, 'n_estimators': 382, 'subsample': 0.7619539319393911, 'colsample_bytree': 0.6892380301541643, 'gamma': 0.2228878965211686, 'lambda': 1.1735884955739431e-06, 'alpha': 0.00918536598072373, 'scale_pos_weight': 1.2516250019547819}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:04:46,422] Trial 22 finished with value: 0.9514960359367473 and parameters: {'max_depth': 4, 'learning_rate': 0.05291701482324869, 'n_estimators': 395, 'subsample': 0.7785685350050727, 'colsample_bytree': 0.6914342707087416, 'gamma': 0.2969417984682912, 'lambda': 2.4527630802007578e-06, 'alpha': 0.0008832148305681076, 'scale_pos_weight': 1.4606613719187356}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:04:51,330] Trial 23 finished with value: 0.9527594960022696 and parameters: {'max_depth': 4, 'learning_rate': 0.15279504458188561, 'n_estimators': 352, 'subsample': 0.6760864341549058, 'colsample_bytree': 0.7817298982789629, 'gamma': 0.42338615466178464, 'lambda': 4.812719721247556e-05, 'alpha': 0.034511651554735186, 'scale_pos_weight': 1.1649572575751153}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:04:59,763] Trial 24 finished with value: 0.9534511214390147 and parameters: {'max_depth': 7, 'learning_rate': 0.07251377829775385, 'n_estimators': 454, 'subsample': 0.8226102126302147, 'colsample_bytree': 0.5852968668293586, 'gamma': 0.2521560133690563, 'lambda': 1.0010476545628953e-07, 'alpha': 0.8967784454037923, 'scale_pos_weight': 1.8529015181952604}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:05:10,124] Trial 25 finished with value: 0.9513719253321291 and parameters: {'max_depth': 10, 'learning_rate': 0.10296191262229183, 'n_estimators': 327, 'subsample': 0.9477970440566493, 'colsample_bytree': 0.7213129745573656, 'gamma': 0.18990548719286746, 'lambda': 7.72125350985616e-06, 'alpha': 0.00018848434680458716, 'scale_pos_weight': 2.0595704159460406}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:05:15,935] Trial 26 finished with value: 0.9524748226407845 and parameters: {'max_depth': 5, 'learning_rate': 0.1360113528056883, 'n_estimators': 370, 'subsample': 0.6867502144592286, 'colsample_bytree': 0.85260576612728, 'gamma': 0.14363057639149737, 'lambda': 0.00016072464274807184, 'alpha': 0.0019346280572407094, 'scale_pos_weight': 1.1661936010576053}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:05:23,087] Trial 27 finished with value: 0.9527683831483866 and parameters: {'max_depth': 6, 'learning_rate': 0.037368283618645526, 'n_estimators': 428, 'subsample': 0.8357278455278015, 'colsample_bytree': 0.6602059318963351, 'gamma': 0.4377689253719393, 'lambda': 5.575764986732597e-06, 'alpha': 1.4319804468812911e-05, 'scale_pos_weight': 1.7366230253274368}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:05:29,218] Trial 28 finished with value: 0.9492238847869388 and parameters: {'max_depth': 8, 'learning_rate': 0.17796203497984367, 'n_estimators': 279, 'subsample': 0.7834533932148332, 'colsample_bytree': 0.7345603135350058, 'gamma': 0.2316700306383658, 'lambda': 1.2434208316869588e-07, 'alpha': 0.01732497564294562, 'scale_pos_weight': 1.464012784077155}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:05:39,162] Trial 29 finished with value: 0.945066000056442 and parameters: {'max_depth': 6, 'learning_rate': 0.012215870421409543, 'n_estimators': 458, 'subsample': 0.9003192372172218, 'colsample_bytree': 0.9395920094765392, 'gamma': 0.3108047166782584, 'lambda': 0.003975258151522686, 'alpha': 7.468336493763697e-05, 'scale_pos_weight': 1.526332813980338}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:05:47,843] Trial 30 finished with value: 0.9523699964005821 and parameters: {'max_depth': 9, 'learning_rate': 0.06243252237340541, 'n_estimators': 373, 'subsample': 0.9352331797698357, 'colsample_bytree': 0.571167104172704, 'gamma': 0.37500250119088313, 'lambda': 1.6071123606591633, 'alpha': 1.3450028307959871, 'scale_pos_weight': 2.9975131966172324}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:05:56,402] Trial 31 finished with value: 0.9529984092256002 and parameters: {'max_depth': 7, 'learning_rate': 0.07080850339825678, 'n_estimators': 455, 'subsample': 0.8354210720982358, 'colsample_bytree': 0.6177982420243968, 'gamma': 0.25197018502965707, 'lambda': 8.174326128136845e-08, 'alpha': 1.1304341394295903, 'scale_pos_weight': 1.9602916461284712}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:06:03,844] Trial 32 finished with value: 0.9535207085357696 and parameters: {'max_depth': 7, 'learning_rate': 0.03922210882843469, 'n_estimators': 409, 'subsample': 0.8675009095905679, 'colsample_bytree': 0.5634609998547313, 'gamma': 0.46740531744748537, 'lambda': 1.6592977268280927e-07, 'alpha': 0.4941812732260955, 'scale_pos_weight': 1.8165102439339942}. Best is trial 2 with value: 0.9535816065286609.
# [I 2024-10-31 16:06:13,314] Trial 33 finished with value: 0.9537450285205599 and parameters: {'max_depth': 7, 'learning_rate': 0.04195705471108598, 'n_estimators': 405, 'subsample': 0.8873724383647141, 'colsample_bytree': 0.8240260041915645, 'gamma': 0.43992629623677026, 'lambda': 2.0164395517590307e-05, 'alpha': 0.19132362041184273, 'scale_pos_weight': 2.1091665966845317}. Best is trial 33 with value: 0.9537450285205599.
# [I 2024-10-31 16:06:21,312] Trial 34 finished with value: 0.9539661179410932 and parameters: {'max_depth': 7, 'learning_rate': 0.03420687892019365, 'n_estimators': 408, 'subsample': 0.8835249202316486, 'colsample_bytree': 0.8753632374442587, 'gamma': 0.45064627136211793, 'lambda': 6.463989102425319e-05, 'alpha': 0.23053423344182866, 'scale_pos_weight': 2.129011707845698}. Best is trial 34 with value: 0.9539661179410932.
# [I 2024-10-31 16:06:28,562] Trial 35 finished with value: 0.952589736658265 and parameters: {'max_depth': 8, 'learning_rate': 0.029008862564124063, 'n_estimators': 324, 'subsample': 0.8904374874490427, 'colsample_bytree': 0.8631760404466798, 'gamma': 0.45192604763818667, 'lambda': 3.532976758910488e-05, 'alpha': 4.30332992570228, 'scale_pos_weight': 2.1813212252932224}. Best is trial 34 with value: 0.9539661179410932.
# [I 2024-10-31 16:06:37,264] Trial 36 finished with value: 0.9436726985385967 and parameters: {'max_depth': 7, 'learning_rate': 0.010381032648546104, 'n_estimators': 410, 'subsample': 0.9233310714236805, 'colsample_bytree': 0.8768223857322698, 'gamma': 0.40513321232239863, 'lambda': 0.0006790461632257469, 'alpha': 0.18430357412114326, 'scale_pos_weight': 2.4850433498949056}. Best is trial 34 with value: 0.9539661179410932.
# [I 2024-10-31 16:06:49,871] Trial 37 finished with value: 0.9531372863557304 and parameters: {'max_depth': 9, 'learning_rate': 0.04779695200979987, 'n_estimators': 434, 'subsample': 0.8802362438285916, 'colsample_bytree': 0.8130104596013721, 'gamma': 0.3497169041837521, 'lambda': 5.7422850004073766e-05, 'alpha': 3.1455095344398036, 'scale_pos_weight': 2.785661722226402}. Best is trial 34 with value: 0.9539661179410932.
# [I 2024-10-31 16:06:57,838] Trial 38 finished with value: 0.9481404822625932 and parameters: {'max_depth': 8, 'learning_rate': 0.20760582338247388, 'n_estimators': 474, 'subsample': 0.9146120807164119, 'colsample_bytree': 0.8343384808888727, 'gamma': 0.4754714546019198, 'lambda': 0.02222329395539711, 'alpha': 0.03652659782790083, 'scale_pos_weight': 2.3612922294470087}. Best is trial 34 with value: 0.9539661179410932.
# [I 2024-10-31 16:07:04,890] Trial 39 finished with value: 0.9513430111631468 and parameters: {'max_depth': 6, 'learning_rate': 0.027754627656785172, 'n_estimators': 397, 'subsample': 0.9638655679062882, 'colsample_bytree': 0.9062251867946122, 'gamma': 0.39832995836379403, 'lambda': 0.00035660608804955916, 'alpha': 1.0091542238574304e-06, 'scale_pos_weight': 2.0779888962923607}. Best is trial 34 with value: 0.9539661179410932.
# [I 2024-10-31 16:07:17,047] Trial 40 finished with value: 0.9518106508114038 and parameters: {'max_depth': 9, 'learning_rate': 0.08224378404731042, 'n_estimators': 420, 'subsample': 0.8433864306541499, 'colsample_bytree': 0.928813845434441, 'gamma': 0.35905355000436034, 'lambda': 1.9238456872327975e-05, 'alpha': 0.20221595680176324, 'scale_pos_weight': 2.133083906167071}. Best is trial 34 with value: 0.9539661179410932.
# [I 2024-10-31 16:07:24,330] Trial 41 finished with value: 0.9539945493820835 and parameters: {'max_depth': 7, 'learning_rate': 0.04001680589487803, 'n_estimators': 402, 'subsample': 0.8745918590152126, 'colsample_bytree': 0.5074269635598109, 'gamma': 0.4701601153284309, 'lambda': 0.0019044310985422556, 'alpha': 0.5472174398337372, 'scale_pos_weight': 1.9341604654074354}. Best is trial 41 with value: 0.9539945493820835.
# [I 2024-10-31 16:07:32,023] Trial 42 finished with value: 0.9546749359209535 and parameters: {'max_depth': 7, 'learning_rate': 0.06284882075416437, 'n_estimators': 393, 'subsample': 0.8783734906350138, 'colsample_bytree': 0.8290946872773904, 'gamma': 0.49592753432856357, 'lambda': 0.0027754089535269974, 'alpha': 2.7563694530658305, 'scale_pos_weight': 1.997028790081819}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:07:41,182] Trial 43 finished with value: 0.9534211304152798 and parameters: {'max_depth': 7, 'learning_rate': 0.06408501319385017, 'n_estimators': 494, 'subsample': 0.8796764827365444, 'colsample_bytree': 0.8274374193695557, 'gamma': 0.4992469113159272, 'lambda': 0.003247770414889149, 'alpha': 0.06571559013995924, 'scale_pos_weight': 2.336554721833932}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:07:50,537] Trial 44 finished with value: 0.95263417238885 and parameters: {'max_depth': 7, 'learning_rate': 0.027047424774032446, 'n_estimators': 399, 'subsample': 0.9127675438726315, 'colsample_bytree': 0.7859684661889957, 'gamma': 0.4628096475354883, 'lambda': 0.33695487248061945, 'alpha': 2.4979951490168393, 'scale_pos_weight': 1.6962621808056033}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:07:57,886] Trial 45 finished with value: 0.9519139050912205 and parameters: {'max_depth': 8, 'learning_rate': 0.08600336617099302, 'n_estimators': 341, 'subsample': 0.9594482603920529, 'colsample_bytree': 0.88811649342729, 'gamma': 0.44322042552981794, 'lambda': 0.0009425425928344487, 'alpha': 0.7976725056291188, 'scale_pos_weight': 2.067075307986018}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:08:06,016] Trial 46 finished with value: 0.9516400002772591 and parameters: {'max_depth': 7, 'learning_rate': 0.10911038719997102, 'n_estimators': 439, 'subsample': 0.8823182349699054, 'colsample_bytree': 0.8514035450318314, 'gamma': 0.4846474207215347, 'lambda': 0.009506105358633376, 'alpha': 0.017128513437940984, 'scale_pos_weight': 2.001931018698446}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:08:11,097] Trial 47 finished with value: 0.9518635899812404 and parameters: {'max_depth': 6, 'learning_rate': 0.04087909100684352, 'n_estimators': 309, 'subsample': 0.9289863876041482, 'colsample_bytree': 0.5062240792111468, 'gamma': 0.3953604233651431, 'lambda': 0.09526935639545038, 'alpha': 0.35788920009960534, 'scale_pos_weight': 2.2354176942852213}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:08:19,885] Trial 48 finished with value: 0.944799472316416 and parameters: {'max_depth': 7, 'learning_rate': 0.29349222939995745, 'n_estimators': 388, 'subsample': 0.8194893751637875, 'colsample_bytree': 0.9856237427485657, 'gamma': 0.4214435193459568, 'lambda': 0.001780146207939259, 'alpha': 0.10231977583569167, 'scale_pos_weight': 1.5925948739534244}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:08:26,834] Trial 49 finished with value: 0.9488364274959885 and parameters: {'max_depth': 6, 'learning_rate': 0.2363579808653199, 'n_estimators': 420, 'subsample': 0.9408181157766682, 'colsample_bytree': 0.7843169242418725, 'gamma': 0.4790245478873237, 'lambda': 0.00041113571913672193, 'alpha': 0.002828374912818174, 'scale_pos_weight': 2.482531508410394}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:08:36,689] Trial 50 finished with value: 0.9520071582372457 and parameters: {'max_depth': 8, 'learning_rate': 0.06459553303307922, 'n_estimators': 471, 'subsample': 0.9667415145018228, 'colsample_bytree': 0.8747843253519587, 'gamma': 0.32608499943685026, 'lambda': 0.0274424689306577, 'alpha': 1.15097056821517e-08, 'scale_pos_weight': 2.8154489140870007}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:08:43,817] Trial 51 finished with value: 0.9543248714829553 and parameters: {'max_depth': 7, 'learning_rate': 0.04954171012034828, 'n_estimators': 364, 'subsample': 0.8571649198711955, 'colsample_bytree': 0.816973859008781, 'gamma': 0.4988666007080758, 'lambda': 6.738093456062501e-05, 'alpha': 4.647169326652155, 'scale_pos_weight': 1.9044630035513297}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:08:52,536] Trial 52 finished with value: 0.9496699997177898 and parameters: {'max_depth': 7, 'learning_rate': 0.020130347180079, 'n_estimators': 358, 'subsample': 0.908915749851223, 'colsample_bytree': 0.8329979414315559, 'gamma': 0.49904201755833677, 'lambda': 0.0001493465960562424, 'alpha': 3.1364574295702345, 'scale_pos_weight': 1.9756737266461526}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:08:55,026] Trial 53 finished with value: 0.9416688575090939 and parameters: {'max_depth': 7, 'learning_rate': 0.03513297636965168, 'n_estimators': 112, 'subsample': 0.8713936023747249, 'colsample_bytree': 0.766918150802257, 'gamma': 0.45895182805454027, 'lambda': 2.0741315049895948e-05, 'alpha': 1.6627515710482172, 'scale_pos_weight': 2.1367455878629262}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:09:03,854] Trial 54 finished with value: 0.9533444756856101 and parameters: {'max_depth': 8, 'learning_rate': 0.04778775289917604, 'n_estimators': 412, 'subsample': 0.8968631713280002, 'colsample_bytree': 0.805962603707242, 'gamma': 0.4389167598007957, 'lambda': 0.005018122008948624, 'alpha': 0.5195369603560523, 'scale_pos_weight': 2.292175953440949}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:09:10,521] Trial 55 finished with value: 0.954283356875606 and parameters: {'max_depth': 6, 'learning_rate': 0.059756847549145536, 'n_estimators': 375, 'subsample': 0.850051835967305, 'colsample_bytree': 0.850224443559144, 'gamma': 0.4183849197417616, 'lambda': 0.001349018088214408, 'alpha': 6.498109073676808, 'scale_pos_weight': 1.870797752093781}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:09:17,470] Trial 56 finished with value: 0.9545979469949811 and parameters: {'max_depth': 6, 'learning_rate': 0.07866778863217974, 'n_estimators': 385, 'subsample': 0.844585726806365, 'colsample_bytree': 0.925411435973256, 'gamma': 0.42808800706232664, 'lambda': 0.001311037528109943, 'alpha': 5.19545113176496, 'scale_pos_weight': 1.7910417162794317}. Best is trial 42 with value: 0.9546749359209535.
# [I 2024-10-31 16:09:25,319] Trial 57 finished with value: 0.9546906060142463 and parameters: {'max_depth': 5, 'learning_rate': 0.08731062800331044, 'n_estimators': 384, 'subsample': 0.8475583921490736, 'colsample_bytree': 0.9257983966614733, 'gamma': 0.4093640064140275, 'lambda': 0.0014120488899603285, 'alpha': 5.204689619823454, 'scale_pos_weight': 1.785581598947428}. Best is trial 57 with value: 0.9546906060142463.
# [I 2024-10-31 16:09:30,832] Trial 58 finished with value: 0.9548695867006705 and parameters: {'max_depth': 5, 'learning_rate': 0.08968696957037485, 'n_estimators': 339, 'subsample': 0.8503922621193063, 'colsample_bytree': 0.960327068453372, 'gamma': 0.4060374415857059, 'lambda': 0.017730324876043653, 'alpha': 4.012502506241041, 'scale_pos_weight': 1.8263336323811528}. Best is trial 58 with value: 0.9548695867006705.
# [I 2024-10-31 16:09:36,572] Trial 59 finished with value: 0.9535481250102116 and parameters: {'max_depth': 5, 'learning_rate': 0.12879817126732046, 'n_estimators': 341, 'subsample': 0.7895068872282435, 'colsample_bytree': 0.9682692956477577, 'gamma': 0.3804899149348281, 'lambda': 0.16642736800602345, 'alpha': 5.102939594279366, 'scale_pos_weight': 1.767239082768343}. Best is trial 58 with value: 0.9548695867006705.
# [I 2024-10-31 16:09:41,206] Trial 60 finished with value: 0.9539279205414872 and parameters: {'max_depth': 5, 'learning_rate': 0.09370306224884584, 'n_estimators': 286, 'subsample': 0.8502177657394356, 'colsample_bytree': 0.9301245963652413, 'gamma': 0.41598425700263975, 'lambda': 0.014469116077218205, 'alpha': 9.79161169812499, 'scale_pos_weight': 1.8583628384948583}. Best is trial 58 with value: 0.9548695867006705.
# [I 2024-10-31 16:09:45,980] Trial 61 finished with value: 0.9525321063625529 and parameters: {'max_depth': 4, 'learning_rate': 0.08091981035179553, 'n_estimators': 317, 'subsample': 0.827720660918009, 'colsample_bytree': 0.9394983658362615, 'gamma': 0.48291065537211036, 'lambda': 0.0016177836964145604, 'alpha': 4.824445690810881, 'scale_pos_weight': 1.6631704521124977}. Best is trial 58 with value: 0.9548695867006705.
# [I 2024-10-31 16:09:51,870] Trial 62 finished with value: 0.9548091095475674 and parameters: {'max_depth': 5, 'learning_rate': 0.05996430709257525, 'n_estimators': 377, 'subsample': 0.8133349900466682, 'colsample_bytree': 0.9515544148122608, 'gamma': 0.40919296461878735, 'lambda': 0.008562381136760411, 'alpha': 1.9660334634568202, 'scale_pos_weight': 1.9014353122266743}. Best is trial 58 with value: 0.9548695867006705.
# [I 2024-10-31 16:09:59,652] Trial 63 finished with value: 0.9546200534615064 and parameters: {'max_depth': 5, 'learning_rate': 0.11872045900060618, 'n_estimators': 384, 'subsample': 0.8004517998858667, 'colsample_bytree': 0.965319395097599, 'gamma': 0.39107017053464305, 'lambda': 0.007260806981306711, 'alpha': 1.7797228518325439, 'scale_pos_weight': 1.804534237845348}. Best is trial 58 with value: 0.9548695867006705.
# [I 2024-10-31 16:10:05,693] Trial 64 finished with value: 0.9543161328685282 and parameters: {'max_depth': 5, 'learning_rate': 0.11529733560078761, 'n_estimators': 361, 'subsample': 0.7956775487200527, 'colsample_bytree': 0.9617572308144527, 'gamma': 0.3629140246751369, 'lambda': 0.005362104114920692, 'alpha': 1.9907269181496194, 'scale_pos_weight': 1.7993152834096406}. Best is trial 58 with value: 0.9548695867006705.
# [I 2024-10-31 16:10:11,335] Trial 65 finished with value: 0.9537090467186627 and parameters: {'max_depth': 4, 'learning_rate': 0.15170753043835478, 'n_estimators': 387, 'subsample': 0.8100318259483537, 'colsample_bytree': 0.9922714386807446, 'gamma': 0.3471916262977284, 'lambda': 0.03910989487217187, 'alpha': 2.041828568130547, 'scale_pos_weight': 1.5954890219253552}. Best is trial 58 with value: 0.9548695867006705.
# [I 2024-10-31 16:10:16,938] Trial 66 finished with value: 0.9549959624135607 and parameters: {'max_depth': 5, 'learning_rate': 0.10384844143304744, 'n_estimators': 337, 'subsample': 0.8043305572023686, 'colsample_bytree': 0.9758939047499094, 'gamma': 0.3878112270969476, 'lambda': 0.008892934677279925, 'alpha': 0.9831797749802362, 'scale_pos_weight': 1.7129800481934905}. Best is trial 66 with value: 0.9549959624135607.
# [I 2024-10-31 16:10:22,371] Trial 67 finished with value: 0.9546097057537711 and parameters: {'max_depth': 5, 'learning_rate': 0.10339069450500399, 'n_estimators': 338, 'subsample': 0.8079326809067395, 'colsample_bytree': 0.951399071371472, 'gamma': 0.38736996215938313, 'lambda': 0.01358804379766172, 'alpha': 0.8629466059854042, 'scale_pos_weight': 1.7328720878810808}. Best is trial 66 with value: 0.9549959624135607.
# [I 2024-10-31 16:10:29,735] Trial 68 finished with value: 0.9546593400935055 and parameters: {'max_depth': 5, 'learning_rate': 0.1036488797419317, 'n_estimators': 344, 'subsample': 0.766641165192479, 'colsample_bytree': 0.9719311618610086, 'gamma': 0.3876222169803103, 'lambda': 0.013529490622059492, 'alpha': 0.6566269686204034, 'scale_pos_weight': 1.7201522441335024}. Best is trial 66 with value: 0.9549959624135607.
# [I 2024-10-31 16:10:34,693] Trial 69 finished with value: 0.9542465952823365 and parameters: {'max_depth': 4, 'learning_rate': 0.12415680139728792, 'n_estimators': 331, 'subsample': 0.7626419403543455, 'colsample_bytree': 0.9743430368961131, 'gamma': 0.2873688756480232, 'lambda': 0.006969702398579576, 'alpha': 1.402691540014912, 'scale_pos_weight': 1.503060898895428}. Best is trial 66 with value: 0.9549959624135607.
# [I 2024-10-31 16:10:39,377] Trial 70 finished with value: 0.9521698004377723 and parameters: {'max_depth': 3, 'learning_rate': 0.14502887262487515, 'n_estimators': 350, 'subsample': 0.7655624681934456, 'colsample_bytree': 0.9981807631731432, 'gamma': 0.330423881210272, 'lambda': 0.09870275111641066, 'alpha': 0.5742581559259321, 'scale_pos_weight': 2.008287172009718}. Best is trial 66 with value: 0.9549959624135607.
# [I 2024-10-31 16:10:44,135] Trial 71 finished with value: 0.9537302124844846 and parameters: {'max_depth': 5, 'learning_rate': 0.10487662176671896, 'n_estimators': 299, 'subsample': 0.7418174282722969, 'colsample_bytree': 0.9493013733144303, 'gamma': 0.38977569306438764, 'lambda': 0.01695288562326206, 'alpha': 0.8638070733802926, 'scale_pos_weight': 1.7184636526181483}. Best is trial 66 with value: 0.9549959624135607.
# [I 2024-10-31 16:10:49,630] Trial 72 finished with value: 0.9550419329716091 and parameters: {'max_depth': 5, 'learning_rate': 0.11470790267008785, 'n_estimators': 339, 'subsample': 0.8011168076094347, 'colsample_bytree': 0.9519830283779752, 'gamma': 0.40701245536049846, 'lambda': 0.4697869621194396, 'alpha': 2.065326091034202, 'scale_pos_weight': 1.6554735198430426}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:10:54,580] Trial 73 finished with value: 0.9535085660701139 and parameters: {'max_depth': 5, 'learning_rate': 0.11270976325581439, 'n_estimators': 301, 'subsample': 0.7756923715259776, 'colsample_bytree': 0.9770636125729519, 'gamma': 0.40587127069525675, 'lambda': 0.5462799361443119, 'alpha': 2.483679794173654, 'scale_pos_weight': 1.6396442492530297}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:01,213] Trial 74 finished with value: 0.9519469533922409 and parameters: {'max_depth': 4, 'learning_rate': 0.0938036495466983, 'n_estimators': 318, 'subsample': 0.7435359546537321, 'colsample_bytree': 0.8996362019846943, 'gamma': 0.373620328758342, 'lambda': 2.8667846318157815, 'alpha': 9.475805970105064, 'scale_pos_weight': 1.8282728633727772}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:07,474] Trial 75 finished with value: 0.9540708575378098 and parameters: {'max_depth': 5, 'learning_rate': 0.07092347413480243, 'n_estimators': 351, 'subsample': 0.7977699918859973, 'colsample_bytree': 0.9574077911482558, 'gamma': 0.3148486006690926, 'lambda': 0.044933926237668904, 'alpha': 0.3832616898281241, 'scale_pos_weight': 1.5566276339480132}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:12,883] Trial 76 finished with value: 0.9542856219838782 and parameters: {'max_depth': 4, 'learning_rate': 0.12127366499072935, 'n_estimators': 376, 'subsample': 0.8305134171232567, 'colsample_bytree': 0.9187228648666453, 'gamma': 0.349893988129669, 'lambda': 0.7539381763307351, 'alpha': 0.10168823578208332, 'scale_pos_weight': 1.396615849368236}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:18,856] Trial 77 finished with value: 0.9530145372916037 and parameters: {'max_depth': 5, 'learning_rate': 0.14177120203010227, 'n_estimators': 335, 'subsample': 0.7534483480251649, 'colsample_bytree': 0.9790887747881112, 'gamma': 0.4112985178983668, 'lambda': 0.06055670754475775, 'alpha': 1.5525273761788212, 'scale_pos_weight': 1.6769578249346162}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:23,632] Trial 78 finished with value: 0.9543835910110602 and parameters: {'max_depth': 5, 'learning_rate': 0.09677174482150784, 'n_estimators': 287, 'subsample': 0.7155487488796201, 'colsample_bytree': 0.9413797151838235, 'gamma': 0.3711798678027989, 'lambda': 0.0029290943927097763, 'alpha': 3.057367951928671, 'scale_pos_weight': 1.7555465448454965}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:29,018] Trial 79 finished with value: 0.9535190127989759 and parameters: {'max_depth': 4, 'learning_rate': 0.16417423380451773, 'n_estimators': 352, 'subsample': 0.8083635927260848, 'colsample_bytree': 0.9132334750702705, 'gamma': 0.4315607418795249, 'lambda': 9.94773406186218, 'alpha': 6.631204838910917e-08, 'scale_pos_weight': 1.9289893125834892}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:36,718] Trial 80 finished with value: 0.9540696940395718 and parameters: {'max_depth': 5, 'learning_rate': 0.08804125504551068, 'n_estimators': 367, 'subsample': 0.7906623712147897, 'colsample_bytree': 0.8943264708857832, 'gamma': 0.4001625814247537, 'lambda': 0.00983508115666895, 'alpha': 0.25509719079186566, 'scale_pos_weight': 1.6105548398332281}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:41,962] Trial 81 finished with value: 0.9540795466416737 and parameters: {'max_depth': 5, 'learning_rate': 0.10166618971281016, 'n_estimators': 332, 'subsample': 0.8173394595334762, 'colsample_bytree': 0.9529550073627502, 'gamma': 0.3861584862530858, 'lambda': 0.02420998742139572, 'alpha': 1.0377882870026445, 'scale_pos_weight': 1.7119580185323628}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:46,976] Trial 82 finished with value: 0.9549696970597161 and parameters: {'max_depth': 5, 'learning_rate': 0.11910127812176609, 'n_estimators': 310, 'subsample': 0.8037596293305803, 'colsample_bytree': 0.9644726978189178, 'gamma': 0.38031654705243195, 'lambda': 0.012980056564696958, 'alpha': 0.7701002977170862, 'scale_pos_weight': 1.858856983186281}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:51,442] Trial 83 finished with value: 0.9539739158548172 and parameters: {'max_depth': 5, 'learning_rate': 0.11800215585354383, 'n_estimators': 268, 'subsample': 0.7741985771847903, 'colsample_bytree': 0.9673906301975751, 'gamma': 0.3566897947751231, 'lambda': 0.16458647042336969, 'alpha': 3.480339626023453, 'scale_pos_weight': 1.8658155932956568}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:11:57,286] Trial 84 finished with value: 0.9516614507288202 and parameters: {'max_depth': 6, 'learning_rate': 0.13049429655703457, 'n_estimators': 321, 'subsample': 0.8349687532211567, 'colsample_bytree': 0.9995710276103974, 'gamma': 0.40852566259739853, 'lambda': 0.0006596262347187723, 'alpha': 0.741398045793662, 'scale_pos_weight': 2.025272912830162}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:01,473] Trial 85 finished with value: 0.9542190426538454 and parameters: {'max_depth': 5, 'learning_rate': 0.11074258003815982, 'n_estimators': 245, 'subsample': 0.7997636974631299, 'colsample_bytree': 0.9372336502894174, 'gamma': 0.33845205992238464, 'lambda': 0.005334513289997619, 'alpha': 1.4028874011800647, 'scale_pos_weight': 1.8168251014524566}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:08,882] Trial 86 finished with value: 0.9536345209432159 and parameters: {'max_depth': 4, 'learning_rate': 0.08744320808654849, 'n_estimators': 375, 'subsample': 0.7805066359990707, 'colsample_bytree': 0.9836379033570014, 'gamma': 0.45051114947096405, 'lambda': 0.007921128929743634, 'alpha': 0.05493881445556653, 'scale_pos_weight': 1.886373315577788}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:14,389] Trial 87 finished with value: 0.953540884090325 and parameters: {'max_depth': 6, 'learning_rate': 0.0751485834863275, 'n_estimators': 314, 'subsample': 0.820971589761659, 'colsample_bytree': 0.9640356828497357, 'gamma': 0.36790814275974254, 'lambda': 0.002437968303995456, 'alpha': 0.13645645354162475, 'scale_pos_weight': 1.55686201121611}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:20,199] Trial 88 finished with value: 0.9545316152177646 and parameters: {'max_depth': 5, 'learning_rate': 0.1407285567526594, 'n_estimators': 358, 'subsample': 0.8645638109133412, 'colsample_bytree': 0.9237322185588855, 'gamma': 0.39386981647776304, 'lambda': 0.03197297281887993, 'alpha': 0.33163574081404423, 'scale_pos_weight': 1.9632962314434796}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:27,635] Trial 89 finished with value: 0.9537884492845972 and parameters: {'max_depth': 6, 'learning_rate': 0.06612716469302507, 'n_estimators': 392, 'subsample': 0.7533187384310676, 'colsample_bytree': 0.9510807906913001, 'gamma': 0.425654481217433, 'lambda': 0.07434997431007628, 'alpha': 5.839431242894035, 'scale_pos_weight': 1.6675165857418304}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:34,148] Trial 90 finished with value: 0.9534526438888368 and parameters: {'max_depth': 5, 'learning_rate': 0.1640061805012099, 'n_estimators': 345, 'subsample': 0.8035947399459646, 'colsample_bytree': 0.9870688330585103, 'gamma': 0.3777555966409249, 'lambda': 0.00023122426900832414, 'alpha': 2.243500621283204, 'scale_pos_weight': 1.757872730935473}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:41,516] Trial 91 finished with value: 0.9547633741646949 and parameters: {'max_depth': 5, 'learning_rate': 0.10753752751313406, 'n_estimators': 335, 'subsample': 0.8140656371140893, 'colsample_bytree': 0.9511796956721863, 'gamma': 0.3880162058235064, 'lambda': 0.012182787330435806, 'alpha': 0.7301695122052902, 'scale_pos_weight': 1.7418677406496348}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:46,530] Trial 92 finished with value: 0.9540961079251064 and parameters: {'max_depth': 5, 'learning_rate': 0.12242717490263519, 'n_estimators': 307, 'subsample': 0.8398634081524098, 'colsample_bytree': 0.945356786189894, 'gamma': 0.40195102910736735, 'lambda': 0.003620508686259334, 'alpha': 0.5285472810783383, 'scale_pos_weight': 1.8270389593785468}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:52,029] Trial 93 finished with value: 0.9508139289058017 and parameters: {'max_depth': 5, 'learning_rate': 0.2581950993143102, 'n_estimators': 328, 'subsample': 0.7888459946551145, 'colsample_bytree': 0.9666431118845791, 'gamma': 0.3428823862555127, 'lambda': 0.0192234515757734, 'alpha': 3.595240279678796, 'scale_pos_weight': 1.9361931362713065}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:12:56,949] Trial 94 finished with value: 0.9523724100405442 and parameters: {'max_depth': 5, 'learning_rate': 0.10812482553802445, 'n_estimators': 293, 'subsample': 0.6026476542338959, 'colsample_bytree': 0.9130779278799473, 'gamma': 0.2644962311922676, 'lambda': 0.0009141138119882846, 'alpha': 1.171306025593395, 'scale_pos_weight': 1.7777671813410236}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:03,057] Trial 95 finished with value: 0.9544656919026959 and parameters: {'max_depth': 4, 'learning_rate': 0.09764026797097618, 'n_estimators': 381, 'subsample': 0.8229554172299286, 'colsample_bytree': 0.9307087279024472, 'gamma': 0.4334971872161951, 'lambda': 0.008788232533107395, 'alpha': 0.29579209737837064, 'scale_pos_weight': 1.6387973874331632}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:11,262] Trial 96 finished with value: 0.9543673763015709 and parameters: {'max_depth': 6, 'learning_rate': 0.057548836073419894, 'n_estimators': 345, 'subsample': 0.8145334873491752, 'colsample_bytree': 0.8879532462503904, 'gamma': 0.32096215555491847, 'lambda': 0.0004497428681925006, 'alpha': 6.1227677126690665, 'scale_pos_weight': 1.4746978943719595}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:17,067] Trial 97 finished with value: 0.9540596186399349 and parameters: {'max_depth': 5, 'learning_rate': 0.13487788536027123, 'n_estimators': 359, 'subsample': 0.8282228340820134, 'colsample_bytree': 0.977683427728355, 'gamma': 0.3820467373752693, 'lambda': 0.013261659302735734, 'alpha': 1.8036353553148108, 'scale_pos_weight': 1.693917239094023}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:22,729] Trial 98 finished with value: 0.9548358081188412 and parameters: {'max_depth': 5, 'learning_rate': 0.09067255816475472, 'n_estimators': 366, 'subsample': 0.7707440736762206, 'colsample_bytree': 0.9698772761811573, 'gamma': 0.4144332263822122, 'lambda': 0.002541879557445186, 'alpha': 0.6925802959163341, 'scale_pos_weight': 1.8980728295790852}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:28,073] Trial 99 finished with value: 0.9528998832045812 and parameters: {'max_depth': 4, 'learning_rate': 0.08432154258994769, 'n_estimators': 366, 'subsample': 0.7731422881597346, 'colsample_bytree': 0.9058533169155012, 'gamma': 0.4549006164347105, 'lambda': 0.0023048963274010276, 'alpha': 2.6079176909911455e-06, 'scale_pos_weight': 2.0570833180690147}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:33,900] Trial 100 finished with value: 0.9540516226839578 and parameters: {'max_depth': 6, 'learning_rate': 0.09189745375683976, 'n_estimators': 324, 'subsample': 0.7271763662459302, 'colsample_bytree': 0.9379227616977934, 'gamma': 0.41533009385546393, 'lambda': 0.26808391809139553, 'alpha': 0.1821710891139902, 'scale_pos_weight': 1.9150099404106893}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:41,843] Trial 101 finished with value: 0.953451307103627 and parameters: {'max_depth': 5, 'learning_rate': 0.11686082135693625, 'n_estimators': 393, 'subsample': 0.7870137475256688, 'colsample_bytree': 0.9592636095834296, 'gamma': 0.3634363141451925, 'lambda': 0.005136982649790567, 'alpha': 0.7371094543444265, 'scale_pos_weight': 1.846597869613398}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:48,070] Trial 102 finished with value: 0.9547051373645825 and parameters: {'max_depth': 5, 'learning_rate': 0.07826583937418316, 'n_estimators': 378, 'subsample': 0.7677230641521207, 'colsample_bytree': 0.9731143198625195, 'gamma': 0.3932768656006097, 'lambda': 0.007011622485161728, 'alpha': 2.8148144812889595, 'scale_pos_weight': 1.9761415537873068}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:53,177] Trial 103 finished with value: 0.9542590719442946 and parameters: {'max_depth': 5, 'learning_rate': 0.06948280911944546, 'n_estimators': 312, 'subsample': 0.7552820048602402, 'colsample_bytree': 0.9930329610498381, 'gamma': 0.41600248757495256, 'lambda': 0.0009980914366346028, 'alpha': 2.7328463843060784, 'scale_pos_weight': 1.9995656424903636}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:13:59,124] Trial 104 finished with value: 0.9548901088291692 and parameters: {'max_depth': 5, 'learning_rate': 0.0740356239028318, 'n_estimators': 354, 'subsample': 0.8480704909059853, 'colsample_bytree': 0.9730852483131897, 'gamma': 0.44029990974862115, 'lambda': 0.004144645868110092, 'alpha': 0.44187499284978693, 'scale_pos_weight': 1.8946663390763459}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:14:05,590] Trial 105 finished with value: 0.954335466743507 and parameters: {'max_depth': 5, 'learning_rate': 0.07695491137974082, 'n_estimators': 370, 'subsample': 0.8468898104115248, 'colsample_bytree': 0.982713731562715, 'gamma': 0.428290394170447, 'lambda': 0.004198355549834761, 'alpha': 7.0141243750259115, 'scale_pos_weight': 1.9607168666474974}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:14:13,039] Trial 106 finished with value: 0.9536072282451823 and parameters: {'max_depth': 4, 'learning_rate': 0.07824592169281663, 'n_estimators': 401, 'subsample': 0.8583623902271457, 'colsample_bytree': 0.9515674956651133, 'gamma': 0.44505666912026476, 'lambda': 0.002161515381870674, 'alpha': 0.4011971662153326, 'scale_pos_weight': 2.0380043705581534}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:14:21,222] Trial 107 finished with value: 0.9538898840512117 and parameters: {'max_depth': 6, 'learning_rate': 0.0899783831745008, 'n_estimators': 416, 'subsample': 0.8362914069526303, 'colsample_bytree': 0.9200628106864137, 'gamma': 0.46682129719682547, 'lambda': 0.02498499341412287, 'alpha': 3.6960143109272745, 'scale_pos_weight': 1.878869836718201}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:14:26,860] Trial 108 finished with value: 0.9538381950230991 and parameters: {'max_depth': 5, 'learning_rate': 0.0556548919062694, 'n_estimators': 335, 'subsample': 0.9998864908318283, 'colsample_bytree': 0.9324000130494617, 'gamma': 0.4896360939995783, 'lambda': 0.0032888607326213887, 'alpha': 1.3361620017009468, 'scale_pos_weight': 1.9810178201269277}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:14:32,602] Trial 109 finished with value: 0.9540298380360942 and parameters: {'max_depth': 5, 'learning_rate': 0.0834199253339509, 'n_estimators': 355, 'subsample': 0.8726072331332074, 'colsample_bytree': 0.958997689752047, 'gamma': 0.4025954217587189, 'lambda': 0.0444089090275409, 'alpha': 1.3327570813128306e-05, 'scale_pos_weight': 2.113342065433496}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:14:40,199] Trial 110 finished with value: 0.9549244196495543 and parameters: {'max_depth': 6, 'learning_rate': 0.06734399655096186, 'n_estimators': 430, 'subsample': 0.8522747238308797, 'colsample_bytree': 0.9887765531817969, 'gamma': 0.44423574397187193, 'lambda': 0.001531311317387699, 'alpha': 1.0578695414746035, 'scale_pos_weight': 1.8918777265795919}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:14:49,458] Trial 111 finished with value: 0.9546072426032456 and parameters: {'max_depth': 6, 'learning_rate': 0.06428307322597758, 'n_estimators': 427, 'subsample': 0.8504188140424049, 'colsample_bytree': 0.9872082010787687, 'gamma': 0.44065264897722684, 'lambda': 0.0006634746348972411, 'alpha': 0.9984585325686728, 'scale_pos_weight': 1.8923449179168057}. Best is trial 72 with value: 0.9550419329716091.
# [I 2024-10-31 16:14:55,474] Trial 112 finished with value: 0.9553203803797559 and parameters: {'max_depth': 5, 'learning_rate': 0.072976992485151, 'n_estimators': 381, 'subsample': 0.8140639680921335, 'colsample_bytree': 0.9443675293317597, 'gamma': 0.4096970838406727, 'lambda': 0.0017006881798142502, 'alpha': 2.5429372708967, 'scale_pos_weight': 1.7799139194800866}. Best is trial 112 with value: 0.9553203803797559.
# ...
# [I 2024-10-31 16:55:11,436] Trial 464 finished with value: 0.9526258051036479 and parameters: {'max_depth': 5, 'learning_rate': 0.13956161919541057, 'n_estimators': 482, 'subsample': 0.929831699766692, 'colsample_bytree': 0.7488084291727871, 'gamma': 0.23466225970301197, 'lambda': 1.5721268858154005e-06, 'alpha': 0.0010153089825404593, 'scale_pos_weight': 2.14869266518327}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:55:18,385] Trial 465 finished with value: 0.9544289179317855 and parameters: {'max_depth': 5, 'learning_rate': 0.08460346092578008, 'n_estimators': 469, 'subsample': 0.977873300425376, 'colsample_bytree': 0.7912952176594772, 'gamma': 0.22913997397143385, 'lambda': 6.589910081914377e-07, 'alpha': 0.034982328894762986, 'scale_pos_weight': 2.0610523945979615}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:55:25,530] Trial 466 finished with value: 0.9546414791577857 and parameters: {'max_depth': 5, 'learning_rate': 0.09139650951356039, 'n_estimators': 490, 'subsample': 0.9580762770165535, 'colsample_bytree': 0.7622932423257354, 'gamma': 0.3519530868811479, 'lambda': 2.5557191916150236e-06, 'alpha': 1.607218174517827e-06, 'scale_pos_weight': 1.9906616076420445}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:55:34,130] Trial 467 finished with value: 0.9548866307120955 and parameters: {'max_depth': 5, 'learning_rate': 0.06553826813297613, 'n_estimators': 479, 'subsample': 0.9372943401470544, 'colsample_bytree': 0.7404275469541332, 'gamma': 0.22119670267873104, 'lambda': 4.964997775789127e-06, 'alpha': 0.0004656252493289309, 'scale_pos_weight': 2.0246769085635363}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:55:40,817] Trial 468 finished with value: 0.9546979954658226 and parameters: {'max_depth': 5, 'learning_rate': 0.0798485112172656, 'n_estimators': 447, 'subsample': 0.9237240331313991, 'colsample_bytree': 0.802514873805271, 'gamma': 0.38727280022017296, 'lambda': 1.0906306555798526e-06, 'alpha': 0.017549919678107363, 'scale_pos_weight': 2.1109377508138816}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:55:47,748] Trial 469 finished with value: 0.9546526809227383 and parameters: {'max_depth': 5, 'learning_rate': 0.07353114591880004, 'n_estimators': 475, 'subsample': 0.9672062592328304, 'colsample_bytree': 0.771682866931497, 'gamma': 0.3708296641480231, 'lambda': 6.919767369857149e-07, 'alpha': 0.011529889605844968, 'scale_pos_weight': 2.0738352419355333}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:55:55,093] Trial 470 finished with value: 0.9550317461732047 and parameters: {'max_depth': 5, 'learning_rate': 0.08736651220996138, 'n_estimators': 492, 'subsample': 0.9448410495682505, 'colsample_bytree': 0.7850227782027899, 'gamma': 0.3455606838734617, 'lambda': 0.00020958970834952174, 'alpha': 0.008348627448732457, 'scale_pos_weight': 2.1593879891689736}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:56:03,499] Trial 471 finished with value: 0.9551521187302917 and parameters: {'max_depth': 5, 'learning_rate': 0.09268632945755725, 'n_estimators': 459, 'subsample': 0.929862156422683, 'colsample_bytree': 0.8220484719570533, 'gamma': 0.24848589200218793, 'lambda': 2.525065904788938e-07, 'alpha': 0.06933197096486585, 'scale_pos_weight': 2.244484614426228}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:56:10,664] Trial 472 finished with value: 0.9546577805107609 and parameters: {'max_depth': 5, 'learning_rate': 0.08247218926147168, 'n_estimators': 484, 'subsample': 0.9449029979866405, 'colsample_bytree': 0.7941979595836592, 'gamma': 0.26538025686550154, 'lambda': 1.63787235811185e-06, 'alpha': 0.0016177766291981702, 'scale_pos_weight': 2.0374305588897665}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:56:18,782] Trial 473 finished with value: 0.9545260205241088 and parameters: {'max_depth': 6, 'learning_rate': 0.06933677968819742, 'n_estimators': 500, 'subsample': 0.9523809870874312, 'colsample_bytree': 0.8464145451825296, 'gamma': 0.3778106824528938, 'lambda': 3.244302150829044e-06, 'alpha': 0.0033446919680632384, 'scale_pos_weight': 2.1939382340713673}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:56:25,647] Trial 474 finished with value: 0.9551060615287575 and parameters: {'max_depth': 5, 'learning_rate': 0.07788757850199637, 'n_estimators': 470, 'subsample': 0.9338927495503974, 'colsample_bytree': 0.7562399559784794, 'gamma': 0.3608661502566354, 'lambda': 3.701025875638951e-07, 'alpha': 0.005418071645467545, 'scale_pos_weight': 1.9802215159590457}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:56:34,368] Trial 475 finished with value: 0.9550364496767207 and parameters: {'max_depth': 5, 'learning_rate': 0.09900070325401002, 'n_estimators': 491, 'subsample': 0.9236353722323029, 'colsample_bytree': 0.879814647239754, 'gamma': 0.2899977293786302, 'lambda': 8.803820054913174e-07, 'alpha': 0.02053922205618306, 'scale_pos_weight': 2.1181831354501006}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:56:41,344] Trial 476 finished with value: 0.9547304620177237 and parameters: {'max_depth': 5, 'learning_rate': 0.08723891905849858, 'n_estimators': 480, 'subsample': 0.9592803987751517, 'colsample_bytree': 0.81319375264399, 'gamma': 0.38729752665104034, 'lambda': 5.656954175712958e-07, 'alpha': 0.00866070385965952, 'scale_pos_weight': 2.0961473271514426}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:56:48,508] Trial 477 finished with value: 0.954966701670635 and parameters: {'max_depth': 5, 'learning_rate': 0.09468366511698087, 'n_estimators': 492, 'subsample': 0.9380399939178076, 'colsample_bytree': 0.7756648113869381, 'gamma': 0.3788064612929216, 'lambda': 4.940569033829106e-06, 'alpha': 0.0036751571051447073, 'scale_pos_weight': 2.0545881804943864}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:56:55,655] Trial 478 finished with value: 0.9542625129284459 and parameters: {'max_depth': 5, 'learning_rate': 0.08350593257108455, 'n_estimators': 476, 'subsample': 0.7308306381738273, 'colsample_bytree': 0.8033168639371768, 'gamma': 0.3991572698101944, 'lambda': 2.278605896295202e-06, 'alpha': 0.012889721751078187, 'scale_pos_weight': 2.3070703885547252}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:57:02,710] Trial 479 finished with value: 0.9532632659841139 and parameters: {'max_depth': 5, 'learning_rate': 0.17191745205139503, 'n_estimators': 486, 'subsample': 0.9702493585156616, 'colsample_bytree': 0.905054059643501, 'gamma': 0.32488418176661416, 'lambda': 1.341029928651351e-06, 'alpha': 0.005148631808315092, 'scale_pos_weight': 2.374375750055859}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:57:10,476] Trial 480 finished with value: 0.9538932012589546 and parameters: {'max_depth': 4, 'learning_rate': 0.07583526536132501, 'n_estimators': 463, 'subsample': 0.9424946756156691, 'colsample_bytree': 0.7631517955694723, 'gamma': 0.3621762913684986, 'lambda': 9.656818826812994e-07, 'alpha': 0.002670412179270635, 'scale_pos_weight': 1.976998393728991}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:57:16,184] Trial 481 finished with value: 0.9524291986566794 and parameters: {'max_depth': 3, 'learning_rate': 0.0914332252427523, 'n_estimators': 451, 'subsample': 0.9262247917950699, 'colsample_bytree': 0.7891382417974507, 'gamma': 0.30995156584872796, 'lambda': 5.153507240826392e-07, 'alpha': 0.00022012217103666707, 'scale_pos_weight': 2.015220881955105}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:57:22,483] Trial 482 finished with value: 0.9545267879378404 and parameters: {'max_depth': 5, 'learning_rate': 0.06957797252432567, 'n_estimators': 431, 'subsample': 0.9541806222250373, 'colsample_bytree': 0.8285579489363746, 'gamma': 0.20522366643092974, 'lambda': 6.903367735045714e-06, 'alpha': 0.006890141191785819, 'scale_pos_weight': 1.398849708410219}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:57:29,806] Trial 483 finished with value: 0.9494260487946405 and parameters: {'max_depth': 5, 'learning_rate': 0.26127254253293736, 'n_estimators': 494, 'subsample': 0.9207873397280848, 'colsample_bytree': 0.7294977740303595, 'gamma': 0.3447149207448317, 'lambda': 3.656692580657383e-06, 'alpha': 0.0347316245088466, 'scale_pos_weight': 2.1459196502065256}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:57:40,727] Trial 484 finished with value: 0.9513720862414599 and parameters: {'max_depth': 8, 'learning_rate': 0.08339887289440982, 'n_estimators': 471, 'subsample': 0.9464979389955774, 'colsample_bytree': 0.7510222126505038, 'gamma': 0.37083026284454146, 'lambda': 1.6514202070661328e-06, 'alpha': 0.015321771939099667, 'scale_pos_weight': 2.084617571671302}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:57:47,787] Trial 485 finished with value: 0.9547413543416555 and parameters: {'max_depth': 5, 'learning_rate': 0.07846322167086663, 'n_estimators': 484, 'subsample': 0.934279257534404, 'colsample_bytree': 0.7753913042063671, 'gamma': 0.38747639990487204, 'lambda': 1.8553341757794776e-07, 'alpha': 0.008730037889466257, 'scale_pos_weight': 2.034181071323797}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:57:54,765] Trial 486 finished with value: 0.9551004173245384 and parameters: {'max_depth': 5, 'learning_rate': 0.06309065013250714, 'n_estimators': 481, 'subsample': 0.964276004710909, 'colsample_bytree': 0.8105437281252194, 'gamma': 0.3561438702554773, 'lambda': 8.516969737391604e-07, 'alpha': 0.0015864602913522755, 'scale_pos_weight': 2.176550280657393}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:58:01,917] Trial 487 finished with value: 0.9546503291709802 and parameters: {'max_depth': 5, 'learning_rate': 0.08890813142932368, 'n_estimators': 493, 'subsample': 0.9813236117781453, 'colsample_bytree': 0.7625413226640158, 'gamma': 0.376618931693966, 'lambda': 3.340597641101725e-07, 'alpha': 0.004178304535056371, 'scale_pos_weight': 2.213240951003248}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:58:10,602] Trial 488 finished with value: 0.9548525550668862 and parameters: {'max_depth': 5, 'learning_rate': 0.10008504485552494, 'n_estimators': 475, 'subsample': 0.9390177920404139, 'colsample_bytree': 0.796596943696048, 'gamma': 0.3958189027292402, 'lambda': 1.365740548109124e-05, 'alpha': 0.02424292627248852, 'scale_pos_weight': 2.115248464946444}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:58:17,598] Trial 489 finished with value: 0.9524327386619572 and parameters: {'max_depth': 5, 'learning_rate': 0.0349928143987825, 'n_estimators': 464, 'subsample': 0.9554607738075954, 'colsample_bytree': 0.7879391205664827, 'gamma': 0.3645044795627802, 'lambda': 6.314709772453875e-07, 'alpha': 0.0060634920849925895, 'scale_pos_weight': 1.9688286120615868}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:58:20,789] Trial 490 finished with value: 0.9511869167346199 and parameters: {'max_depth': 5, 'learning_rate': 0.07312799068482927, 'n_estimators': 200, 'subsample': 0.9294721529652488, 'colsample_bytree': 0.7708312912315348, 'gamma': 0.4994531956458403, 'lambda': 2.302635102299909e-06, 'alpha': 0.012078010269051698, 'scale_pos_weight': 2.085991536547667}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:58:28,187] Trial 491 finished with value: 0.9528997841834547 and parameters: {'max_depth': 5, 'learning_rate': 0.08177663778715422, 'n_estimators': 485, 'subsample': 0.6187959439979964, 'colsample_bytree': 0.6296205383312563, 'gamma': 0.35244004601338264, 'lambda': 1.114460821723874e-06, 'alpha': 0.0006374710457174843, 'scale_pos_weight': 2.0145820530848493}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:58:35,594] Trial 492 finished with value: 0.9540888793828608 and parameters: {'max_depth': 5, 'learning_rate': 0.0894241285173891, 'n_estimators': 499, 'subsample': 0.9464861503320543, 'colsample_bytree': 0.7797590641061191, 'gamma': 0.37766874806106715, 'lambda': 3.1429260893045906e-06, 'alpha': 0.05006691612484932, 'scale_pos_weight': 2.0545667734932076}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:58:44,328] Trial 493 finished with value: 0.9547554153416403 and parameters: {'max_depth': 5, 'learning_rate': 0.09519683127085822, 'n_estimators': 500, 'subsample': 0.9723078171141613, 'colsample_bytree': 0.7460383630235334, 'gamma': 0.39019605464598583, 'lambda': 1.6161646523635217e-06, 'alpha': 0.0023711259353123362, 'scale_pos_weight': 2.150365538897557}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:58:51,494] Trial 494 finished with value: 0.9546994188945183 and parameters: {'max_depth': 5, 'learning_rate': 0.0776673853650547, 'n_estimators': 488, 'subsample': 0.9198735260870285, 'colsample_bytree': 0.8030179771958589, 'gamma': 0.34053423408020256, 'lambda': 5.127112267526612e-06, 'alpha': 0.018585501018495362, 'scale_pos_weight': 1.9697465101521117}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:58:58,535] Trial 495 finished with value: 0.9540080781435123 and parameters: {'max_depth': 5, 'learning_rate': 0.08551865503152928, 'n_estimators': 470, 'subsample': 0.9351855360331778, 'colsample_bytree': 0.8194844611725381, 'gamma': 0.33537058484182714, 'lambda': 3.350139131159213e-07, 'alpha': 0.008700720591421667, 'scale_pos_weight': 2.064355914816466}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:59:06,612] Trial 496 finished with value: 0.9547266744596293 and parameters: {'max_depth': 6, 'learning_rate': 0.06886071047559941, 'n_estimators': 478, 'subsample': 0.9603040604394097, 'colsample_bytree': 0.7587149116732428, 'gamma': 0.40337242585431554, 'lambda': 9.645218052004323e-06, 'alpha': 0.004068862324599894, 'scale_pos_weight': 2.257325844137986}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:59:15,585] Trial 497 finished with value: 0.9550943275252491 and parameters: {'max_depth': 5, 'learning_rate': 0.10358758092392721, 'n_estimators': 491, 'subsample': 0.9477494217713449, 'colsample_bytree': 0.7887569895747916, 'gamma': 0.3683011269886841, 'lambda': 5.082940291438436e-07, 'alpha': 0.01174966368504867, 'scale_pos_weight': 2.1109026804270186}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:59:22,167] Trial 498 finished with value: 0.9540286497825742 and parameters: {'max_depth': 4, 'learning_rate': 0.0811309767126715, 'n_estimators': 480, 'subsample': 0.918887720481353, 'colsample_bytree': 0.7375618987492193, 'gamma': 0.3827494503978693, 'lambda': 7.577359086649608e-07, 'alpha': 0.006078384017670545, 'scale_pos_weight': 2.0181727801183125}. Best is trial 365 with value: 0.9560193210022325.
# [I 2024-10-31 16:59:29,291] Trial 499 finished with value: 0.9549078831214034 and parameters: {'max_depth': 5, 'learning_rate': 0.08809354015453934, 'n_estimators': 438, 'subsample': 0.9287037046940209, 'colsample_bytree': 0.7780367800904162, 'gamma': 0.23204260334473342, 'lambda': 2.06535822829317e-06, 'alpha': 0.00281911906370217, 'scale_pos_weight': 2.168250874107937}. Best is trial 365 with value: 0.9560193210022325.
# Best trial: {'max_depth': 5, 'learning_rate': 0.09071934481163234, 'n_estimators': 477, 'subsample': 0.9364296482600055, 'colsample_bytree': 0.7656377652218407, 'gamma': 0.3778302171303889, 'lambda': 1.1354525660669237e-06, 'alpha': 0.0024598591905306668, 'scale_pos_weight': 2.1368290316656604}

# %%
xgb_best_params = xgb_study.best_trial.params
xgb_best_score = xgb_study.best_trial.value
xgb_best_score
# Out:
# 0.9560193210022325

# %% [markdown]
# ## CatBoostClassifier

# %%
from catboost import CatBoostClassifier

def cat_objective(trial):

    # Define the hyperparameter search space

    param = {
        'depth': trial.suggest_int('depth', 4, 10),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'l2_leaf_reg': trial.suggest_float('l2_leaf_reg', 1e-5, 10.0, log=True),
        'border_count': trial.suggest_int('border_count', 32, 255),
        'bagging_temperature': trial.suggest_float('bagging_temperature', 0.0, 1.0),
        'eval_metric': 'AUC',  
        'logging_level': 'Silent',  # Disable CatBoost output
        'task_type': 'CPU',  # Try using GPU
        'use_best_model': True
    }

    # Initialize the CatBoost model with the trial's parameters
    model = CatBoostClassifier(**param)

    # Fit the model
    model.fit(X_train_prep, y_train,
              eval_set=[(X_test_prep, y_test)],
              early_stopping_rounds=20,  # Early stopping to prevent overfitting
              verbose=False)

    # Get predictions and calculate AUC score
    y_pred_prob = model.predict_proba(X_test_prep)[:, 1]  # Probabilities for class 1

    auc = roc_auc_score(y_test, y_pred_prob)

    return auc

cat_study = optuna.create_study(direction='maximize')  # We want to maximize AUC

cat_study.optimize(cat_objective, n_trials=500, timeout=3600*2)

# Output the best trial
print(f"Best trial: {cat_study.best_trial.params}")
# Out:
# [I 2024-10-31 16:59:29,598] A new study created in memory with name: no-name-498b92dc-a3bb-4c4c-83ce-47074b09dfc4
# [W 2024-10-31 16:59:37,842] Trial 0 failed with parameters: {'depth': 4, 'learning_rate': 0.12168668368848211, 'l2_leaf_reg': 0.023705980577632266, 'border_count': 38, 'bagging_temperature': 0.6799535524428815} because of the following error: NameError("name 'aucaa' is not defined").
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/optuna/study/_optimize.py", line 197, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_17/2184984520.py", line 33, in cat_objective
#     return aucaa
# NameError: name 'aucaa' is not defined
# [W 2024-10-31 16:59:37,847] Trial 0 failed with value None.
# name 'aucaa' is not defined

# %%
cat_best_params = cat_study.best_trial.params
cat_best_score = cat_study.best_trial.value
cat_best_score
# Out:
# No trials are completed yet.

# %% [markdown]
# ## LightGBM

# %%
# Objective function for LightGBM

def lgb_objective(trial):
    param = {
        'objective': 'binary',
        'metric': 'auc',
        'boosting_type': 'gbdt',
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3),
        'num_leaves': trial.suggest_int('num_leaves', 20, 150),  # Adjusted num_leaves range
        'max_depth': trial.suggest_int('max_depth', 3, 10),      # Reduced max_depth
        'min_child_samples': trial.suggest_int('min_child_samples', 1, 100),  # Reduced min_child_samples
        'min_child_weight': trial.suggest_float('min_child_weight', 1e-3, 10.0),
        'subsample': trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'n_estimators': trial.suggest_int('n_estimators', 100, 1000),
        'min_gain_to_split': trial.suggest_float('min_gain_to_split', 0.0, 0.2),  # Added min_gain_to_split
        'verbosity': 0
    }

    lgb_model = lgb.LGBMClassifier(**param)

    # Train the model with early stopping
    lgb_model.fit(X_train_prep, y_train,
                  eval_set=[(X_test_prep, y_test)],
                  eval_metric='auc',
                  callbacks=[lgb.early_stopping(stopping_rounds=100)])

    # Predict and evaluate AUC
    y_pred_prob = lgb_model.predict_proba(X_test_prep)[:, 1]
    auc = roc_auc_score(y_test, y_pred_prob)

    return auc


# Optimize the objective function
lgb_study = optuna.create_study(direction='maximize')
lgb_study.optimize(lgb_objective, n_trials=500, timeout=3600*2)

# Best parameters and AUC
print("Best LGBM Params: ", lgb_study.best_trial.params)
print("Best AUC for LGBM: ", lgb_study.best_value)
# Out:
# KeyboardInterrupt

# %%
lgb_best_params = lgb_study.best_trial.params
lgb_best_score = lgb_study.best_value
lgb_best_score
# Out:
# 0.957882750074142

# %% [markdown]
# ## ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier

def extratrees_objective(trial):
    param = {
        'n_estimators': trial.suggest_int('n_estimators', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 10),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 10),
        'max_features': trial.suggest_float('max_features', 0.1, 1.0)
    }

    model = ExtraTreesClassifier(**param)
    score = cross_val_score(model, X_train_prep, y_train, cv=3, scoring='roc_auc').mean()

    return score

extratrees_study = optuna.create_study(direction='maximize')
extratrees_study.optimize(extratrees_objective, n_trials=200, timeout=1800)

print('Best parameters for ExtraTrees:', extratrees_study.best_params)
# Out:
# [I 2024-10-31 18:39:22,949] A new study created in memory with name: no-name-0e0e5b12-8e54-4d4e-9a9a-98d9d50cb57d
# [I 2024-10-31 18:42:28,069] Trial 0 finished with value: 0.9379868765478628 and parameters: {'n_estimators': 353, 'max_depth': 18, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.5982092428135277}. Best is trial 0 with value: 0.9379868765478628.
# [I 2024-10-31 18:43:51,163] Trial 1 finished with value: 0.9184487354378609 and parameters: {'n_estimators': 243, 'max_depth': 6, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 0.8068286675599466}. Best is trial 0 with value: 0.9379868765478628.
# [I 2024-10-31 18:44:20,416] Trial 2 finished with value: 0.927020325371489 and parameters: {'n_estimators': 119, 'max_depth': 10, 'min_samples_split': 9, 'min_samples_leaf': 7, 'max_features': 0.35468499038011336}. Best is trial 0 with value: 0.9379868765478628.
# [I 2024-10-31 18:45:37,599] Trial 3 finished with value: 0.9261044979740927 and parameters: {'n_estimators': 355, 'max_depth': 10, 'min_samples_split': 2, 'min_samples_leaf': 8, 'max_features': 0.31087849466126427}. Best is trial 0 with value: 0.9379868765478628.
# [I 2024-10-31 18:50:38,768] Trial 4 finished with value: 0.9385991451247291 and parameters: {'n_estimators': 446, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.8333350015175908}. Best is trial 4 with value: 0.9385991451247291.
# [I 2024-10-31 18:54:00,911] Trial 5 finished with value: 0.936724848471174 and parameters: {'n_estimators': 404, 'max_depth': 19, 'min_samples_split': 8, 'min_samples_leaf': 8, 'max_features': 0.5907263313791085}. Best is trial 4 with value: 0.9385991451247291.
# [I 2024-10-31 18:55:01,921] Trial 6 finished with value: 0.9209996674295032 and parameters: {'n_estimators': 367, 'max_depth': 9, 'min_samples_split': 9, 'min_samples_leaf': 9, 'max_features': 0.22528233086084604}. Best is trial 4 with value: 0.9385991451247291.
# [I 2024-10-31 18:55:44,841] Trial 7 finished with value: 0.9326021515574526 and parameters: {'n_estimators': 146, 'max_depth': 13, 'min_samples_split': 8, 'min_samples_leaf': 1, 'max_features': 0.33364292780818905}. Best is trial 4 with value: 0.9385991451247291.
# [I 2024-10-31 18:56:37,902] Trial 8 finished with value: 0.936606994541687 and parameters: {'n_estimators': 108, 'max_depth': 16, 'min_samples_split': 5, 'min_samples_leaf': 4, 'max_features': 0.5857631403526367}. Best is trial 4 with value: 0.9385991451247291.
# [I 2024-10-31 18:58:35,493] Trial 9 finished with value: 0.9232413526196258 and parameters: {'n_estimators': 286, 'max_depth': 7, 'min_samples_split': 3, 'min_samples_leaf': 3, 'max_features': 0.8847139004077075}. Best is trial 4 with value: 0.9385991451247291.
# [I 2024-10-31 19:04:37,410] Trial 10 finished with value: 0.9379150712216257 and parameters: {'n_estimators': 494, 'max_depth': 14, 'min_samples_split': 3, 'min_samples_leaf': 5, 'max_features': 0.9867172347843486}. Best is trial 4 with value: 0.9385991451247291.
# [I 2024-10-31 19:09:22,483] Trial 11 finished with value: 0.9378004846888746 and parameters: {'n_estimators': 440, 'max_depth': 20, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.7091825619943514}. Best is trial 4 with value: 0.9385991451247291.
# [I 2024-10-31 19:14:14,142] Trial 12 finished with value: 0.9380337707433403 and parameters: {'n_estimators': 495, 'max_depth': 17, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 0.6937643034829201}. Best is trial 4 with value: 0.9385991451247291.
# Best parameters for ExtraTrees: {'n_estimators': 446, 'max_depth': 16, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.8333350015175908}

# %%
extratrees_best_params = extratrees_study.best_params
extratrees_best_score = extratrees_study.best_value
extratrees_best_score
# Out:
# 0.9385991451247291

# %% [markdown]
# ## HistGradientBoostingClassifier

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

def histgb_objective(trial):
    param = {
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1, log=True),
        'max_iter': trial.suggest_int('max_iter', 100, 500),
        'max_depth': trial.suggest_int('max_depth', 5, 20),
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 10, 50),
        'max_leaf_nodes': trial.suggest_int('max_leaf_nodes', 10, 50),
        'l2_regularization': trial.suggest_float('l2_regularization', 1e-5, 1.0, log=True)
    }

    model = HistGradientBoostingClassifier(**param)
    score = cross_val_score(model, X_train_prep, y_train, cv=3, scoring='roc_auc').mean()

    return score

histgb_study = optuna.create_study(direction='maximize')
histgb_study.optimize(histgb_objective, n_trials=200, timeout=1800)
print('Best parameters for HistGradientBoosting:', histgb_study.best_params)
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:16: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(
# [I 2024-10-31 19:14:28,371] A new study created in memory with name: no-name-5016838b-cdef-455a-9277-ba084a6dff24
# [I 2024-10-31 19:14:46,483] Trial 0 finished with value: 0.9502664544773637 and parameters: {'learning_rate': 0.047616203242832236, 'max_iter': 471, 'max_depth': 7, 'min_samples_leaf': 12, 'max_leaf_nodes': 19, 'l2_regularization': 1.9930579832794328e-05}. Best is trial 0 with value: 0.9502664544773637.
# [I 2024-10-31 19:15:10,065] Trial 1 finished with value: 0.9489651136703233 and parameters: {'learning_rate': 0.02532349425624152, 'max_iter': 338, 'max_depth': 12, 'min_samples_leaf': 26, 'max_leaf_nodes': 23, 'l2_regularization': 0.007037708421238262}. Best is trial 0 with value: 0.9502664544773637.
# [I 2024-10-31 19:15:31,144] Trial 2 finished with value: 0.9433762966497641 and parameters: {'learning_rate': 0.015715675740876622, 'max_iter': 222, 'max_depth': 17, 'min_samples_leaf': 30, 'max_leaf_nodes': 35, 'l2_regularization': 2.293959660634556e-05}. Best is trial 0 with value: 0.9502664544773637.
# [I 2024-10-31 19:15:53,615] Trial 3 finished with value: 0.9511847713989324 and parameters: {'learning_rate': 0.04496678215405626, 'max_iter': 362, 'max_depth': 8, 'min_samples_leaf': 31, 'max_leaf_nodes': 34, 'l2_regularization': 0.10797376333034876}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:16:13,518] Trial 4 finished with value: 0.9438131343909596 and parameters: {'learning_rate': 0.01733194278818151, 'max_iter': 191, 'max_depth': 13, 'min_samples_leaf': 16, 'max_leaf_nodes': 45, 'l2_regularization': 1.1054992028664632e-05}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:16:35,028] Trial 5 finished with value: 0.9498077974909896 and parameters: {'learning_rate': 0.03627116561314555, 'max_iter': 492, 'max_depth': 11, 'min_samples_leaf': 50, 'max_leaf_nodes': 36, 'l2_regularization': 1.5770139821835337e-05}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:16:48,326] Trial 6 finished with value: 0.9318420470881886 and parameters: {'learning_rate': 0.014782741221778029, 'max_iter': 221, 'max_depth': 5, 'min_samples_leaf': 31, 'max_leaf_nodes': 13, 'l2_regularization': 1.6505050992638492e-05}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:17:06,434] Trial 7 finished with value: 0.9495103725278925 and parameters: {'learning_rate': 0.0392063126961111, 'max_iter': 267, 'max_depth': 9, 'min_samples_leaf': 14, 'max_leaf_nodes': 25, 'l2_regularization': 0.26621899452855335}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:17:44,646] Trial 8 finished with value: 0.9474860501564731 and parameters: {'learning_rate': 0.010692389101009255, 'max_iter': 414, 'max_depth': 16, 'min_samples_leaf': 26, 'max_leaf_nodes': 37, 'l2_regularization': 0.04116638687369305}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:17:56,852] Trial 9 finished with value: 0.9500238849696698 and parameters: {'learning_rate': 0.07452626722588862, 'max_iter': 463, 'max_depth': 10, 'min_samples_leaf': 26, 'max_leaf_nodes': 49, 'l2_regularization': 8.807295367231216e-05}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:18:07,227] Trial 10 finished with value: 0.9505865203694418 and parameters: {'learning_rate': 0.06957271606501471, 'max_iter': 116, 'max_depth': 20, 'min_samples_leaf': 42, 'max_leaf_nodes': 30, 'l2_regularization': 0.8084781396384045}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:18:16,106] Trial 11 finished with value: 0.9493493286993667 and parameters: {'learning_rate': 0.08968947150832925, 'max_iter': 134, 'max_depth': 19, 'min_samples_leaf': 43, 'max_leaf_nodes': 29, 'l2_regularization': 0.9325773104177831}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:18:32,330] Trial 12 finished with value: 0.9505299845699339 and parameters: {'learning_rate': 0.06262509014893097, 'max_iter': 354, 'max_depth': 20, 'min_samples_leaf': 40, 'max_leaf_nodes': 43, 'l2_regularization': 0.061691341014461346}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:18:42,676] Trial 13 finished with value: 0.9488225070851047 and parameters: {'learning_rate': 0.05465781014617119, 'max_iter': 116, 'max_depth': 14, 'min_samples_leaf': 37, 'max_leaf_nodes': 31, 'l2_regularization': 0.0014039517230062975}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:19:11,913] Trial 14 finished with value: 0.9501195206182542 and parameters: {'learning_rate': 0.02564418260549796, 'max_iter': 391, 'max_depth': 8, 'min_samples_leaf': 48, 'max_leaf_nodes': 40, 'l2_regularization': 0.6829267231489131}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:19:23,571] Trial 15 finished with value: 0.9498089810791548 and parameters: {'learning_rate': 0.09111025852727123, 'max_iter': 286, 'max_depth': 6, 'min_samples_leaf': 35, 'max_leaf_nodes': 30, 'l2_regularization': 0.09098000714447907}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:19:41,173] Trial 16 finished with value: 0.9463332496883 and parameters: {'learning_rate': 0.04502190122690083, 'max_iter': 330, 'max_depth': 16, 'min_samples_leaf': 44, 'max_leaf_nodes': 10, 'l2_regularization': 0.00933580376889091}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:19:54,275] Trial 17 finished with value: 0.9493952745007928 and parameters: {'learning_rate': 0.06888423970218496, 'max_iter': 423, 'max_depth': 14, 'min_samples_leaf': 21, 'max_leaf_nodes': 19, 'l2_regularization': 0.0011322083195705556}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:20:09,445] Trial 18 finished with value: 0.9453116139786549 and parameters: {'learning_rate': 0.02566813387195132, 'max_iter': 151, 'max_depth': 18, 'min_samples_leaf': 35, 'max_leaf_nodes': 33, 'l2_regularization': 0.22095238258582156}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:20:24,281] Trial 19 finished with value: 0.9499643578455107 and parameters: {'learning_rate': 0.05660715862473453, 'max_iter': 256, 'max_depth': 9, 'min_samples_leaf': 45, 'max_leaf_nodes': 26, 'l2_regularization': 0.015800477014152686}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:20:32,805] Trial 20 finished with value: 0.9380609674889824 and parameters: {'learning_rate': 0.032107996755202164, 'max_iter': 101, 'max_depth': 15, 'min_samples_leaf': 39, 'max_leaf_nodes': 21, 'l2_regularization': 0.2930157849293777}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:20:45,481] Trial 21 finished with value: 0.9508629504634792 and parameters: {'learning_rate': 0.06782582532199072, 'max_iter': 357, 'max_depth': 19, 'min_samples_leaf': 39, 'max_leaf_nodes': 42, 'l2_regularization': 0.05556931260502817}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:20:58,054] Trial 22 finished with value: 0.950411089359641 and parameters: {'learning_rate': 0.07913963099451864, 'max_iter': 372, 'max_depth': 20, 'min_samples_leaf': 32, 'max_leaf_nodes': 43, 'l2_regularization': 0.028597309571641666}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:21:06,592] Trial 23 finished with value: 0.9502449038489762 and parameters: {'learning_rate': 0.09958937116272273, 'max_iter': 312, 'max_depth': 18, 'min_samples_leaf': 41, 'max_leaf_nodes': 39, 'l2_regularization': 0.09570978443936183}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:21:25,289] Trial 24 finished with value: 0.9504639429166706 and parameters: {'learning_rate': 0.047272920677343684, 'max_iter': 425, 'max_depth': 19, 'min_samples_leaf': 36, 'max_leaf_nodes': 48, 'l2_regularization': 0.40432244608903645}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:21:37,598] Trial 25 finished with value: 0.9501002337702814 and parameters: {'learning_rate': 0.062050874163230144, 'max_iter': 375, 'max_depth': 17, 'min_samples_leaf': 46, 'max_leaf_nodes': 28, 'l2_regularization': 0.20091481045795453}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:21:49,487] Trial 26 finished with value: 0.9496477086272564 and parameters: {'learning_rate': 0.07604474375998496, 'max_iter': 312, 'max_depth': 20, 'min_samples_leaf': 22, 'max_leaf_nodes': 33, 'l2_regularization': 0.1082656919460363}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:22:07,115] Trial 27 finished with value: 0.9504666437142161 and parameters: {'learning_rate': 0.052510982321397066, 'max_iter': 241, 'max_depth': 12, 'min_samples_leaf': 33, 'max_leaf_nodes': 40, 'l2_regularization': 0.0019320529801971431}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:22:25,395] Trial 28 finished with value: 0.9497315521071457 and parameters: {'learning_rate': 0.04090949394269593, 'max_iter': 189, 'max_depth': 18, 'min_samples_leaf': 39, 'max_leaf_nodes': 45, 'l2_regularization': 0.0004982404329441305}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:22:51,934] Trial 29 finished with value: 0.9505729801857538 and parameters: {'learning_rate': 0.0321169259391804, 'max_iter': 404, 'max_depth': 7, 'min_samples_leaf': 28, 'max_leaf_nodes': 34, 'l2_regularization': 0.00567237477974284}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:23:07,396] Trial 30 finished with value: 0.9507815708357187 and parameters: {'learning_rate': 0.06475409768747262, 'max_iter': 451, 'max_depth': 16, 'min_samples_leaf': 42, 'max_leaf_nodes': 39, 'l2_regularization': 0.022001341457484273}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:23:19,037] Trial 31 finished with value: 0.9498403057337382 and parameters: {'learning_rate': 0.06584812302172109, 'max_iter': 447, 'max_depth': 19, 'min_samples_leaf': 42, 'max_leaf_nodes': 39, 'l2_regularization': 0.035574379839710284}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:23:33,961] Trial 32 finished with value: 0.9495254385248088 and parameters: {'learning_rate': 0.048825593175808285, 'max_iter': 491, 'max_depth': 16, 'min_samples_leaf': 47, 'max_leaf_nodes': 37, 'l2_regularization': 0.022034702317578425}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:23:45,384] Trial 33 finished with value: 0.9505988093617533 and parameters: {'learning_rate': 0.08286331648975881, 'max_iter': 447, 'max_depth': 17, 'min_samples_leaf': 37, 'max_leaf_nodes': 42, 'l2_regularization': 0.01143669405201798}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:23:55,825] Trial 34 finished with value: 0.9504002912575302 and parameters: {'learning_rate': 0.08210132019021478, 'max_iter': 443, 'max_depth': 17, 'min_samples_leaf': 37, 'max_leaf_nodes': 43, 'l2_regularization': 0.010942631689845522}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:24:10,093] Trial 35 finished with value: 0.9495737230113886 and parameters: {'learning_rate': 0.05888646233492042, 'max_iter': 348, 'max_depth': 14, 'min_samples_leaf': 29, 'max_leaf_nodes': 46, 'l2_regularization': 0.0035047062898206954}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:24:30,564] Trial 36 finished with value: 0.9504811741082557 and parameters: {'learning_rate': 0.04126517234102957, 'max_iter': 452, 'max_depth': 13, 'min_samples_leaf': 33, 'max_leaf_nodes': 41, 'l2_regularization': 0.00554978883504349}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:24:41,616] Trial 37 finished with value: 0.9498343936139659 and parameters: {'learning_rate': 0.09026947347117774, 'max_iter': 484, 'max_depth': 11, 'min_samples_leaf': 50, 'max_leaf_nodes': 47, 'l2_regularization': 0.017508334775434696}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:25:01,585] Trial 38 finished with value: 0.9499644530994877 and parameters: {'learning_rate': 0.03577460277464785, 'max_iter': 379, 'max_depth': 15, 'min_samples_leaf': 21, 'max_leaf_nodes': 36, 'l2_regularization': 0.042659243622083426}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:25:16,660] Trial 39 finished with value: 0.9506120953986699 and parameters: {'learning_rate': 0.05172253769083762, 'max_iter': 472, 'max_depth': 15, 'min_samples_leaf': 38, 'max_leaf_nodes': 38, 'l2_regularization': 0.12251067837561214}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:25:45,619] Trial 40 finished with value: 0.9460407672729813 and parameters: {'learning_rate': 0.020204332033146987, 'max_iter': 468, 'max_depth': 5, 'min_samples_leaf': 24, 'max_leaf_nodes': 50, 'l2_regularization': 0.13929520397524728}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:26:01,559] Trial 41 finished with value: 0.9501256789641808 and parameters: {'learning_rate': 0.05304387103805034, 'max_iter': 404, 'max_depth': 17, 'min_samples_leaf': 38, 'max_leaf_nodes': 42, 'l2_regularization': 0.060954187004117984}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:26:14,340] Trial 42 finished with value: 0.9502245093971132 and parameters: {'learning_rate': 0.06995555121746526, 'max_iter': 437, 'max_depth': 15, 'min_samples_leaf': 30, 'max_leaf_nodes': 38, 'l2_regularization': 0.43442727777523826}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:26:33,509] Trial 43 finished with value: 0.9509523257566802 and parameters: {'learning_rate': 0.0464108268196617, 'max_iter': 482, 'max_depth': 16, 'min_samples_leaf': 34, 'max_leaf_nodes': 35, 'l2_regularization': 0.061256481954974774}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:26:48,743] Trial 44 finished with value: 0.9499145500426697 and parameters: {'learning_rate': 0.04413046434971526, 'max_iter': 475, 'max_depth': 13, 'min_samples_leaf': 34, 'max_leaf_nodes': 35, 'l2_regularization': 0.05330367187611029}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:27:12,596] Trial 45 finished with value: 0.9501799847512857 and parameters: {'learning_rate': 0.034815315134190866, 'max_iter': 464, 'max_depth': 16, 'min_samples_leaf': 11, 'max_leaf_nodes': 33, 'l2_regularization': 0.1322115358438}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:27:28,921] Trial 46 finished with value: 0.9501010492442862 and parameters: {'learning_rate': 0.050599416012215126, 'max_iter': 493, 'max_depth': 11, 'min_samples_leaf': 40, 'max_leaf_nodes': 37, 'l2_regularization': 0.06628355001922431}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:27:49,507] Trial 47 finished with value: 0.9503110795518169 and parameters: {'learning_rate': 0.03880493449800934, 'max_iter': 332, 'max_depth': 15, 'min_samples_leaf': 28, 'max_leaf_nodes': 32, 'l2_regularization': 0.02747427242833414}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:28:03,703] Trial 48 finished with value: 0.9493442231619728 and parameters: {'learning_rate': 0.05976765914980808, 'max_iter': 500, 'max_depth': 14, 'min_samples_leaf': 31, 'max_leaf_nodes': 35, 'l2_regularization': 0.5192896152792287}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:28:31,313] Trial 49 finished with value: 0.9500257610141807 and parameters: {'learning_rate': 0.028605106891552923, 'max_iter': 358, 'max_depth': 16, 'min_samples_leaf': 43, 'max_leaf_nodes': 45, 'l2_regularization': 0.0001429472057098799}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:29:03,948] Trial 50 finished with value: 0.9465661072059572 and parameters: {'learning_rate': 0.011484598875096223, 'max_iter': 398, 'max_depth': 19, 'min_samples_leaf': 17, 'max_leaf_nodes': 27, 'l2_regularization': 0.18067253303056682}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:29:14,768] Trial 51 finished with value: 0.9500947515870678 and parameters: {'learning_rate': 0.08360389296631006, 'max_iter': 427, 'max_depth': 18, 'min_samples_leaf': 36, 'max_leaf_nodes': 41, 'l2_regularization': 0.011741056600185679}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:29:26,533] Trial 52 finished with value: 0.9493682223574224 and parameters: {'learning_rate': 0.07150058367801082, 'max_iter': 462, 'max_depth': 17, 'min_samples_leaf': 38, 'max_leaf_nodes': 38, 'l2_regularization': 0.02009047820005465}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:29:40,849] Trial 53 finished with value: 0.9504300435047291 and parameters: {'learning_rate': 0.06221591944150635, 'max_iter': 415, 'max_depth': 16, 'min_samples_leaf': 41, 'max_leaf_nodes': 43, 'l2_regularization': 0.07142069652330342}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:29:51,735] Trial 54 finished with value: 0.9499305983322466 and parameters: {'learning_rate': 0.09971943409067964, 'max_iter': 478, 'max_depth': 17, 'min_samples_leaf': 34, 'max_leaf_nodes': 31, 'l2_regularization': 0.03808974505569649}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:30:09,860] Trial 55 finished with value: 0.9498851124187881 and parameters: {'learning_rate': 0.04517418808957736, 'max_iter': 281, 'max_depth': 6, 'min_samples_leaf': 44, 'max_leaf_nodes': 36, 'l2_regularization': 0.008333175698449252}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:30:24,295] Trial 56 finished with value: 0.9496005286322905 and parameters: {'learning_rate': 0.05548068615915252, 'max_iter': 436, 'max_depth': 18, 'min_samples_leaf': 35, 'max_leaf_nodes': 40, 'l2_regularization': 0.004458973325130437}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:30:37,773] Trial 57 finished with value: 0.9492927347127377 and parameters: {'learning_rate': 0.06567690687322858, 'max_iter': 387, 'max_depth': 9, 'min_samples_leaf': 37, 'max_leaf_nodes': 45, 'l2_regularization': 0.2682293938952282}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:30:50,343] Trial 58 finished with value: 0.9500145554802834 and parameters: {'learning_rate': 0.07662677443649783, 'max_iter': 454, 'max_depth': 15, 'min_samples_leaf': 32, 'max_leaf_nodes': 24, 'l2_regularization': 0.08396890223427629}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:31:08,504] Trial 59 finished with value: 0.9505895536935468 and parameters: {'learning_rate': 0.049693015871235424, 'max_iter': 366, 'max_depth': 19, 'min_samples_leaf': 40, 'max_leaf_nodes': 39, 'l2_regularization': 0.014050583121163454}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:31:20,334] Trial 60 finished with value: 0.9505136087649247 and parameters: {'learning_rate': 0.084510983161925, 'max_iter': 415, 'max_depth': 12, 'min_samples_leaf': 38, 'max_leaf_nodes': 35, 'l2_regularization': 0.12703321779428278}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:31:36,437] Trial 61 finished with value: 0.9500064628661432 and parameters: {'learning_rate': 0.04808692959058145, 'max_iter': 315, 'max_depth': 19, 'min_samples_leaf': 40, 'max_leaf_nodes': 38, 'l2_regularization': 0.01345696512340596}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:31:51,128] Trial 62 finished with value: 0.9506288261861123 and parameters: {'learning_rate': 0.05618526251881568, 'max_iter': 368, 'max_depth': 17, 'min_samples_leaf': 42, 'max_leaf_nodes': 41, 'l2_regularization': 0.002187560832605186}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:32:07,075] Trial 63 finished with value: 0.9504480798839422 and parameters: {'learning_rate': 0.056923309610355265, 'max_iter': 291, 'max_depth': 16, 'min_samples_leaf': 42, 'max_leaf_nodes': 41, 'l2_regularization': 0.0020002189422085974}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:32:22,155] Trial 64 finished with value: 0.9491411240421722 and parameters: {'learning_rate': 0.06485005050176032, 'max_iter': 340, 'max_depth': 17, 'min_samples_leaf': 48, 'max_leaf_nodes': 16, 'l2_regularization': 0.000996095414915512}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:32:40,837] Trial 65 finished with value: 0.9500632315294902 and parameters: {'learning_rate': 0.04191454133871794, 'max_iter': 392, 'max_depth': 18, 'min_samples_leaf': 36, 'max_leaf_nodes': 43, 'l2_regularization': 0.00036222536162027987}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:32:52,064] Trial 66 finished with value: 0.9501308236006839 and parameters: {'learning_rate': 0.07239100617526262, 'max_iter': 434, 'max_depth': 15, 'min_samples_leaf': 43, 'max_leaf_nodes': 44, 'l2_regularization': 0.02886619190042045}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:33:07,361] Trial 67 finished with value: 0.950579201690298 and parameters: {'learning_rate': 0.05413296081191249, 'max_iter': 361, 'max_depth': 14, 'min_samples_leaf': 46, 'max_leaf_nodes': 42, 'l2_regularization': 0.00723727859973649}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:33:21,674] Trial 68 finished with value: 0.9507114093558241 and parameters: {'learning_rate': 0.05970670128205248, 'max_iter': 453, 'max_depth': 18, 'min_samples_leaf': 39, 'max_leaf_nodes': 34, 'l2_regularization': 0.0033957907184117902}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:33:37,065] Trial 69 finished with value: 0.9493850504726767 and parameters: {'learning_rate': 0.06033983711680983, 'max_iter': 326, 'max_depth': 20, 'min_samples_leaf': 39, 'max_leaf_nodes': 29, 'l2_regularization': 0.0019912709646967073}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:33:55,764] Trial 70 finished with value: 0.9501730384800561 and parameters: {'learning_rate': 0.04434067120546426, 'max_iter': 344, 'max_depth': 8, 'min_samples_leaf': 45, 'max_leaf_nodes': 32, 'l2_regularization': 0.0007759709300785894}. Best is trial 3 with value: 0.9511847713989324.
# [I 2024-10-31 19:34:13,171] Trial 71 finished with value: 0.9513325161803893 and parameters: {'learning_rate': 0.06500114925960461, 'max_iter': 456, 'max_depth': 17, 'min_samples_leaf': 41, 'max_leaf_nodes': 34, 'l2_regularization': 0.002846689063034667}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:34:27,025] Trial 72 finished with value: 0.9495933899004805 and parameters: {'learning_rate': 0.0671129399726304, 'max_iter': 480, 'max_depth': 18, 'min_samples_leaf': 41, 'max_leaf_nodes': 34, 'l2_regularization': 0.0025359678919046366}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:34:49,676] Trial 73 finished with value: 0.9498495861672422 and parameters: {'learning_rate': 0.038057473214811524, 'max_iter': 457, 'max_depth': 16, 'min_samples_leaf': 44, 'max_leaf_nodes': 37, 'l2_regularization': 3.288177528028802e-05}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:35:07,621] Trial 74 finished with value: 0.949839773320448 and parameters: {'learning_rate': 0.05089719813544255, 'max_iter': 488, 'max_depth': 18, 'min_samples_leaf': 42, 'max_leaf_nodes': 34, 'l2_regularization': 0.0004447491173751782}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:35:20,861] Trial 75 finished with value: 0.9499749265774877 and parameters: {'learning_rate': 0.057627563685497984, 'max_iter': 470, 'max_depth': 19, 'min_samples_leaf': 34, 'max_leaf_nodes': 30, 'l2_regularization': 0.0035522162384003645}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:35:38,568] Trial 76 finished with value: 0.9509253669702648 and parameters: {'learning_rate': 0.04656260351905764, 'max_iter': 382, 'max_depth': 17, 'min_samples_leaf': 39, 'max_leaf_nodes': 36, 'l2_regularization': 0.19223414525331886}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:35:56,292] Trial 77 finished with value: 0.9504741051699449 and parameters: {'learning_rate': 0.047248911633920615, 'max_iter': 382, 'max_depth': 17, 'min_samples_leaf': 39, 'max_leaf_nodes': 36, 'l2_regularization': 0.0013327886414333623}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:36:11,723] Trial 78 finished with value: 0.9501518713199136 and parameters: {'learning_rate': 0.0622395167514913, 'max_iter': 404, 'max_depth': 18, 'min_samples_leaf': 43, 'max_leaf_nodes': 32, 'l2_regularization': 0.3311808298343176}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:36:42,522] Trial 79 finished with value: 0.9494439926418842 and parameters: {'learning_rate': 0.021011262577831976, 'max_iter': 372, 'max_depth': 10, 'min_samples_leaf': 41, 'max_leaf_nodes': 34, 'l2_regularization': 0.19722353599078835}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:36:56,659] Trial 80 finished with value: 0.9499290478662714 and parameters: {'learning_rate': 0.07301789445232708, 'max_iter': 350, 'max_depth': 20, 'min_samples_leaf': 27, 'max_leaf_nodes': 39, 'l2_regularization': 0.04729214541125531}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:37:11,882] Trial 81 finished with value: 0.9495729738733941 and parameters: {'learning_rate': 0.05334652476311258, 'max_iter': 416, 'max_depth': 17, 'min_samples_leaf': 38, 'max_leaf_nodes': 37, 'l2_regularization': 0.09638243046776387}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:37:27,313] Trial 82 finished with value: 0.9503220965475802 and parameters: {'learning_rate': 0.05782508206888877, 'max_iter': 423, 'max_depth': 16, 'min_samples_leaf': 36, 'max_leaf_nodes': 40, 'l2_regularization': 0.15243716988436715}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:37:44,841] Trial 83 finished with value: 0.950560981697135 and parameters: {'learning_rate': 0.04614140144076946, 'max_iter': 444, 'max_depth': 15, 'min_samples_leaf': 40, 'max_leaf_nodes': 38, 'l2_regularization': 0.005154843748768829}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:38:04,632] Trial 84 finished with value: 0.9511346412718922 and parameters: {'learning_rate': 0.05089365397925472, 'max_iter': 464, 'max_depth': 17, 'min_samples_leaf': 42, 'max_leaf_nodes': 36, 'l2_regularization': 0.6547292206953423}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:38:25,509] Trial 85 finished with value: 0.9504774692632086 and parameters: {'learning_rate': 0.042066694692440794, 'max_iter': 500, 'max_depth': 17, 'min_samples_leaf': 45, 'max_leaf_nodes': 35, 'l2_regularization': 0.49009466491448467}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:38:49,611] Trial 86 finished with value: 0.9505589061990243 and parameters: {'learning_rate': 0.034358809771608566, 'max_iter': 324, 'max_depth': 19, 'min_samples_leaf': 42, 'max_leaf_nodes': 33, 'l2_regularization': 0.6965305169016418}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:39:01,321] Trial 87 finished with value: 0.9497172735843541 and parameters: {'learning_rate': 0.06794499749608349, 'max_iter': 457, 'max_depth': 18, 'min_samples_leaf': 30, 'max_leaf_nodes': 31, 'l2_regularization': 0.2368248579155912}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:39:12,068] Trial 88 finished with value: 0.9502931654516719 and parameters: {'learning_rate': 0.0781445370276351, 'max_iter': 299, 'max_depth': 17, 'min_samples_leaf': 44, 'max_leaf_nodes': 36, 'l2_regularization': 0.0027331628970925907}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:39:27,348] Trial 89 finished with value: 0.9508672336166463 and parameters: {'learning_rate': 0.06484475336356083, 'max_iter': 429, 'max_depth': 16, 'min_samples_leaf': 47, 'max_leaf_nodes': 34, 'l2_regularization': 0.8023712718866836}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:39:40,278] Trial 90 finished with value: 0.949192357243029 and parameters: {'learning_rate': 0.0632963443182698, 'max_iter': 433, 'max_depth': 16, 'min_samples_leaf': 50, 'max_leaf_nodes': 30, 'l2_regularization': 0.7921360528382178}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:39:54,563] Trial 91 finished with value: 0.9500583304806017 and parameters: {'learning_rate': 0.054830388345381745, 'max_iter': 399, 'max_depth': 17, 'min_samples_leaf': 48, 'max_leaf_nodes': 33, 'l2_regularization': 0.9730223936603277}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:40:09,443] Trial 92 finished with value: 0.9501806723128349 and parameters: {'learning_rate': 0.05977279314517176, 'max_iter': 447, 'max_depth': 16, 'min_samples_leaf': 46, 'max_leaf_nodes': 34, 'l2_regularization': 0.3537442389134298}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:40:20,592] Trial 93 finished with value: 0.9498895301127074 and parameters: {'learning_rate': 0.06969958171946652, 'max_iter': 466, 'max_depth': 18, 'min_samples_leaf': 39, 'max_leaf_nodes': 37, 'l2_regularization': 0.49290076351193596}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:40:40,374] Trial 94 finished with value: 0.9507097401972825 and parameters: {'learning_rate': 0.050306257598796936, 'max_iter': 426, 'max_depth': 17, 'min_samples_leaf': 49, 'max_leaf_nodes': 35, 'l2_regularization': 0.6172232110547621}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:40:56,359] Trial 95 finished with value: 0.9506783007269736 and parameters: {'learning_rate': 0.050823600483438244, 'max_iter': 425, 'max_depth': 16, 'min_samples_leaf': 49, 'max_leaf_nodes': 35, 'l2_regularization': 0.575475358628009}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:41:14,938] Trial 96 finished with value: 0.9498174024627589 and parameters: {'learning_rate': 0.04004244339520386, 'max_iter': 442, 'max_depth': 19, 'min_samples_leaf': 47, 'max_leaf_nodes': 32, 'l2_regularization': 0.28659134835908956}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:41:33,179] Trial 97 finished with value: 0.9494480081506107 and parameters: {'learning_rate': 0.043332860991853156, 'max_iter': 479, 'max_depth': 18, 'min_samples_leaf': 49, 'max_leaf_nodes': 36, 'l2_regularization': 0.72422933572562}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:41:52,283] Trial 98 finished with value: 0.9504847361112363 and parameters: {'learning_rate': 0.04886464955348895, 'max_iter': 410, 'max_depth': 15, 'min_samples_leaf': 32, 'max_leaf_nodes': 33, 'l2_regularization': 0.392431965586357}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:42:22,845] Trial 99 finished with value: 0.9506669538388005 and parameters: {'learning_rate': 0.02848185701565637, 'max_iter': 452, 'max_depth': 17, 'min_samples_leaf': 47, 'max_leaf_nodes': 39, 'l2_regularization': 0.18101198354927786}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:42:36,639] Trial 100 finished with value: 0.9503443169081706 and parameters: {'learning_rate': 0.06484607500740722, 'max_iter': 431, 'max_depth': 16, 'min_samples_leaf': 37, 'max_leaf_nodes': 31, 'l2_regularization': 0.08031107603145612}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:42:50,818] Trial 101 finished with value: 0.94989076481364 and parameters: {'learning_rate': 0.05123461304512824, 'max_iter': 462, 'max_depth': 16, 'min_samples_leaf': 50, 'max_leaf_nodes': 35, 'l2_regularization': 0.618371200325719}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:43:07,830] Trial 102 finished with value: 0.9502662444153431 and parameters: {'learning_rate': 0.05306539756780591, 'max_iter': 423, 'max_depth': 17, 'min_samples_leaf': 49, 'max_leaf_nodes': 35, 'l2_regularization': 0.5909195715852046}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:43:31,547] Trial 103 finished with value: 0.9506769529230855 and parameters: {'learning_rate': 0.045883365587043604, 'max_iter': 393, 'max_depth': 16, 'min_samples_leaf': 48, 'max_leaf_nodes': 34, 'l2_regularization': 0.948091967949331}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:43:48,957] Trial 104 finished with value: 0.9495387619786712 and parameters: {'learning_rate': 0.047962702052717444, 'max_iter': 442, 'max_depth': 17, 'min_samples_leaf': 49, 'max_leaf_nodes': 36, 'l2_regularization': 0.24151131233697365}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:44:06,563] Trial 105 finished with value: 0.9505628383896342 and parameters: {'learning_rate': 0.06132542305241857, 'max_iter': 383, 'max_depth': 14, 'min_samples_leaf': 45, 'max_leaf_nodes': 38, 'l2_regularization': 0.0322741154013482}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:44:25,489] Trial 106 finished with value: 0.9500863185353841 and parameters: {'learning_rate': 0.038215185200972605, 'max_iter': 485, 'max_depth': 16, 'min_samples_leaf': 46, 'max_leaf_nodes': 37, 'l2_regularization': 0.06019445167727364}. Best is trial 71 with value: 0.9513325161803893.
# [I 2024-10-31 19:44:37,599] Trial 107 finished with value: 0.950101136591181 and parameters: {'learning_rate': 0.0755173401010746, 'max_iter': 409, 'max_depth': 15, 'min_samples_leaf': 33, 'max_leaf_nodes': 35, 'l2_regularization': 0.10702336203227185}. Best is trial 71 with value: 0.9513325161803893.
# Best parameters for HistGradientBoosting: {'learning_rate': 0.06500114925960461, 'max_iter': 456, 'max_depth': 17, 'min_samples_leaf': 41, 'max_leaf_nodes': 34, 'l2_regularization': 0.002846689063034667}

# %%
histgb_best_params = histgb_study.best_trial.params
histgb_best_score = histgb_study.best_trial.value
histgb_best_score
# Out:
# 0.9513325161803893

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

def knn_objective(trial):
    param = {
        'n_neighbors': trial.suggest_int('n_neighbors', 3, 15),
        'leaf_size': trial.suggest_int('leaf_size', 20, 50),
        'p': trial.suggest_categorical('p', [1, 2]),  # Minkowski distance parameter
        'weights': trial.suggest_categorical('weights', ['uniform', 'distance'])
    }

    model = KNeighborsClassifier(**param)
    score = cross_val_score(model, X_train_prep, y_train, cv=3, scoring='roc_auc').mean()

    return score

knn_study = optuna.create_study(direction='maximize')
knn_study.optimize(knn_objective, n_trials=200, timeout=1800)
print('Best parameters for KNN:', knn_study.best_params)
print('Best score for KNN:', knn_study.best_value)
# Out:
# [I 2024-10-31 19:44:49,865] A new study created in memory with name: no-name-fe7721a1-07a5-4649-8a0b-216f8194c455
# [I 2024-10-31 19:45:09,987] Trial 0 finished with value: 0.8704534030249357 and parameters: {'n_neighbors': 5, 'leaf_size': 29, 'p': 2, 'weights': 'distance'}. Best is trial 0 with value: 0.8704534030249357.
# [I 2024-10-31 19:47:56,987] Trial 1 finished with value: 0.8813159676698725 and parameters: {'n_neighbors': 7, 'leaf_size': 44, 'p': 1, 'weights': 'uniform'}. Best is trial 1 with value: 0.8813159676698725.
# [I 2024-10-31 19:48:17,326] Trial 2 finished with value: 0.885600102529513 and parameters: {'n_neighbors': 9, 'leaf_size': 23, 'p': 2, 'weights': 'distance'}. Best is trial 2 with value: 0.885600102529513.
# [I 2024-10-31 19:51:06,787] Trial 3 finished with value: 0.8915004619622682 and parameters: {'n_neighbors': 13, 'leaf_size': 36, 'p': 1, 'weights': 'uniform'}. Best is trial 3 with value: 0.8915004619622682.
# [I 2024-10-31 19:53:55,110] Trial 4 finished with value: 0.8856081799880874 and parameters: {'n_neighbors': 8, 'leaf_size': 35, 'p': 1, 'weights': 'distance'}. Best is trial 3 with value: 0.8915004619622682.
# [I 2024-10-31 19:54:15,410] Trial 5 finished with value: 0.8876065426448281 and parameters: {'n_neighbors': 10, 'leaf_size': 37, 'p': 2, 'weights': 'distance'}. Best is trial 3 with value: 0.8915004619622682.
# [I 2024-10-31 19:54:35,514] Trial 6 finished with value: 0.852562427765598 and parameters: {'n_neighbors': 3, 'leaf_size': 35, 'p': 2, 'weights': 'distance'}. Best is trial 3 with value: 0.8915004619622682.
# [I 2024-10-31 19:57:23,592] Trial 7 finished with value: 0.8886188509923315 and parameters: {'n_neighbors': 11, 'leaf_size': 44, 'p': 1, 'weights': 'uniform'}. Best is trial 3 with value: 0.8915004619622682.
# [I 2024-10-31 19:57:43,840] Trial 8 finished with value: 0.8829924947917629 and parameters: {'n_neighbors': 8, 'leaf_size': 40, 'p': 2, 'weights': 'distance'}. Best is trial 3 with value: 0.8915004619622682.
# [I 2024-10-31 19:58:04,234] Trial 9 finished with value: 0.8872399357741357 and parameters: {'n_neighbors': 11, 'leaf_size': 32, 'p': 2, 'weights': 'uniform'}. Best is trial 3 with value: 0.8915004619622682.
# [I 2024-10-31 20:00:52,142] Trial 10 finished with value: 0.892947823786483 and parameters: {'n_neighbors': 15, 'leaf_size': 48, 'p': 1, 'weights': 'uniform'}. Best is trial 10 with value: 0.892947823786483.
# [I 2024-10-31 20:03:42,788] Trial 11 finished with value: 0.892947823786483 and parameters: {'n_neighbors': 15, 'leaf_size': 49, 'p': 1, 'weights': 'uniform'}. Best is trial 10 with value: 0.892947823786483.
# [I 2024-10-31 20:06:34,041] Trial 12 finished with value: 0.892947823786483 and parameters: {'n_neighbors': 15, 'leaf_size': 50, 'p': 1, 'weights': 'uniform'}. Best is trial 10 with value: 0.892947823786483.
# [I 2024-10-31 20:09:23,680] Trial 13 finished with value: 0.892947823786483 and parameters: {'n_neighbors': 15, 'leaf_size': 50, 'p': 1, 'weights': 'uniform'}. Best is trial 10 with value: 0.892947823786483.
# [I 2024-10-31 20:12:11,063] Trial 14 finished with value: 0.8915004619622682 and parameters: {'n_neighbors': 13, 'leaf_size': 45, 'p': 1, 'weights': 'uniform'}. Best is trial 10 with value: 0.892947823786483.
# [I 2024-10-31 20:14:58,569] Trial 15 finished with value: 0.8915004619622682 and parameters: {'n_neighbors': 13, 'leaf_size': 47, 'p': 1, 'weights': 'uniform'}. Best is trial 10 with value: 0.892947823786483.
# Best parameters for KNN: {'n_neighbors': 15, 'leaf_size': 48, 'p': 1, 'weights': 'uniform'}
# Best score for KNN: 0.892947823786483

# %%
knn_best_params = knn_study.best_trial.params
knn_best_score = knn_study.best_trial.value
knn_best_score
# Out:
# 0.892947823786483

# %% [markdown]
# # Stacking

# %%
from sklearn.ensemble import StackingClassifier

# Init base models

xgb_model = xgb.XGBClassifier(**xgb_best_params)
try:
    cat_model = CatBoostClassifier(**cat_best_params)
except Exception as e:
    print(e)
    
lgb_model = lgb.LGBMClassifier(**lgb_best_params)
extratrees_model = ExtraTreesClassifier(**extratrees_best_params)
# logreg_model = LogisticRegression(**logreg_best_params)
histgb_model = HistGradientBoostingClassifier(**histgb_best_params)
knn_model = KNeighborsClassifier(**knn_best_params)

# Base and meta models
try:
    base_estimators = [
    	('xgb', xgb_model),
    	('cat', cat_model),
    	('lgb', lgb_model),
    	('extratrees', extratrees_model),
    	('histgb', histgb_model),
    	('knn', knn_model)
    ]
except:
    base_estimators = [
    	('xgb', xgb_model),
    	# ('cat', cat_model),
    	('lgb', lgb_model),
    	('extratrees', extratrees_model),
    	('histgb', histgb_model),
    	('knn', knn_model)
    ]
    
meta_model = lgb.LGBMClassifier()

# Stack

stack_model = StackingClassifier(estimators=base_estimators, final_estimator=meta_model, cv=3, n_jobs=-1)

stack_model.fit(X_train_prep, y_train)
# Out:
# name 'cat_best_params' is not defined
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Info] Number of positive: 11322, number of negative: 57092
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.046024 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5123
# [LightGBM] [Info] Number of data points in the train set: 68414, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165492 -> initscore=-1.617916
# [LightGBM] [Info] Start training from score -1.617916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Info] Number of positive: 7548, number of negative: 38061
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.030997 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5121
# [LightGBM] [Info] Number of data points in the train set: 45609, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165494 -> initscore=-1.617908
# [LightGBM] [Info] Start training from score -1.617908
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Info] Number of positive: 11322, number of negative: 57092
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.007788 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1036
# [LightGBM] [Info] Number of data points in the train set: 68414, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165492 -> initscore=-1.617916
# [LightGBM] [Info] Start training from score -1.617916
# StackingClassifier(cv=3,
#                    estimators=[('xgb',
#                                 XGBClassifier(alpha=0.0024598591905306668,
#                                               base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=0.7656377652218407,
#                                               device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None,
#                                               gamma=0.3778302171303889,
#                                               grow_policy=Non...
#                                                      max_features=0.8333350015175908,
#                                                      min_samples_leaf=2,
#                                                      min_samples_split=3,
#                                                      n_estimators=446)),
#                                ('histgb',
#                                 HistGradientBoostingClassifier(l2_regularization=0.002846689063034667,
#                                                                learning_rate=0.06500114925960461,
#                                                                max_depth=17,
#                                                                max_iter=456,
#                                                                max_leaf_nodes=34,
#                                                                min_samples_leaf=41)),
#                                ('knn',
#                                 KNeighborsClassifier(leaf_size=48,
#                                                      n_neighbors=15, p=1))],
#                    final_estimator=LGBMClassifier(), n_jobs=-1)

# %%
print('Stacking Classifier ROC AUC:', roc_auc_score(y_test, stack_model.predict_proba(X_test_prep)[:, 1]))
# Out:
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# Stacking Classifier ROC AUC: 0.9570040489738689

# %% [markdown]
# # Submission

# %%
X_train_all = preprocessor.transform(X)

stack_model = StackingClassifier(estimators=base_estimators, final_estimator=meta_model, cv=5, n_jobs=-1)

stack_model.fit(X_train_all, y)
# Out:
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Info] Number of positive: 14152, number of negative: 71366
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.055512 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5140
# [LightGBM] [Info] Number of data points in the train set: 85518, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165486 -> initscore=-1.617966
# [LightGBM] [Info] Start training from score -1.617966
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Info] Number of positive: 11322, number of negative: 57092
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.047132 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 5137
# [LightGBM] [Info] Number of data points in the train set: 68414, number of used features: 40
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165492 -> initscore=-1.617916
# [LightGBM] [Info] Start training from score -1.617916
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
# [LightGBM] [Info] Number of positive: 14152, number of negative: 71366
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009423 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1036
# [LightGBM] [Info] Number of data points in the train set: 85518, number of used features: 5
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.165486 -> initscore=-1.617966
# [LightGBM] [Info] Start training from score -1.617966
# StackingClassifier(cv=5,
#                    estimators=[('xgb',
#                                 XGBClassifier(alpha=0.0024598591905306668,
#                                               base_score=None, booster=None,
#                                               callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=0.7656377652218407,
#                                               device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric=None,
#                                               feature_types=None,
#                                               gamma=0.3778302171303889,
#                                               grow_policy=Non...
#                                                      max_features=0.8333350015175908,
#                                                      min_samples_leaf=2,
#                                                      min_samples_split=3,
#                                                      n_estimators=446)),
#                                ('histgb',
#                                 HistGradientBoostingClassifier(l2_regularization=0.002846689063034667,
#                                                                learning_rate=0.06500114925960461,
#                                                                max_depth=17,
#                                                                max_iter=456,
#                                                                max_leaf_nodes=34,
#                                                                min_samples_leaf=41)),
#                                ('knn',
#                                 KNeighborsClassifier(leaf_size=48,
#                                                      n_neighbors=15, p=1))],
#                    final_estimator=LGBMClassifier(), n_jobs=-1)

# %%
import joblib

try:
    joblib.dump(stack_model, '../models/stack_model_FeatEng.pkl')
except:
    joblib.dump(stack_model, 'stack_model_FeatEng.pkl')
    
X_to_pred = preprocessor.transform(data_to_predict)
y_pred_submit = stack_model.predict_proba(X_to_pred)[:, 1]

submission = pd.DataFrame({'id': data_to_predict['id'], 'loan_status': y_pred_submit})
try:
    submission.to_csv('../submissions/stack_model_FeatEng.csv', index=False)
except:
    submission.to_csv('stack_model_FeatEng.csv', index=False)
# Out:
# [LightGBM] [Warning] min_gain_to_split is set=0.09399801709167936, min_split_gain=0.0 will be ignored. Current value: min_gain_to_split=0.09399801709167936
