# %% [markdown]
# # Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read data

# %%
data = pd.read_csv('../data/train.csv')
data_to_predict = pd.read_csv('../data/test.csv')
data_ccrisk = pd.read_csv('../data/credit_risk_dataset.csv')

data_ccrisk.dropna(inplace=True)
data_ccrisk.drop_duplicates(inplace=True)

X_old = data.drop(['loan_status'], axis=1)
y_old = data['loan_status']

# Merge the dataframes
data_no_id = data.drop(['id'], axis=1)
merged_data = pd.concat([data_no_id, data_ccrisk], ignore_index=True)

def remove_col_prefix(dataframe, prefix):
	dataframe.columns = dataframe.columns.str.replace(prefix, '')
	return dataframe

merged_data = remove_col_prefix(merged_data, 'person_')
merged_data = remove_col_prefix(merged_data, 'loan_')


print(merged_data.isnull().sum())
print(merged_data.duplicated().sum())

X = merged_data.drop(['status'], axis=1)
y = merged_data['status']
# Out:
# age                    0
# income                 0
# home_ownership         0
# emp_length             0
# intent                 0
# grade                  0
# amnt                   0
# int_rate               0
# percent_income         0
# cb_default_on_file     0
# cb_cred_hist_length    0
# status                 0
# dtype: int64
# 0

# %% [markdown]
# # Feature engineering

# %%
X['emp_length_to_age_ratio'] = X['emp_length'] / X['age']
X['income_to_age_ratio'] = X['income'] / X['age']
X['total_income_to_age_ratio'] = X['emp_length']*X['income'] / X['age']
new_features = ['emp_length_to_age_ratio', 'income_to_age_ratio', 'total_income_to_age_ratio']

merged_data['emp_length_to_age_ratio'] = merged_data['emp_length']/merged_data['age']
merged_data['income_to_age_ratio'] = merged_data['income']/merged_data['age']
merged_data['total_income_to_age_ratio'] = merged_data['emp_length']*merged_data['income']/merged_data['age']

# %% [markdown]
# # Preprocessing

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, shuffle=True, test_size=0.2, random_state=2024)

# %%
categorical_columns = X.select_dtypes(include=['object']).columns

categorical_ordinal = ['grade']
categorical_onehot = categorical_columns.drop(categorical_ordinal)

log_columns = ['age', 'income', 'emp_length', 'amnt']
log_columns = log_columns + new_features

numerical_columns = X.select_dtypes(include=['int64', 'float64']).columns
numerical_columns = numerical_columns.drop(log_columns)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer

def log_transform():
	return FunctionTransformer(np.log1p, validate=True)

preprocessor = ColumnTransformer(
	transformers=[
		('ordinal', OrdinalEncoder(), categorical_ordinal),
		('onehot', OneHotEncoder(), categorical_onehot),
		('scaler', StandardScaler(), numerical_columns),
		('log', log_transform(), log_columns)
	], remainder='passthrough'
	)

preprocessor.fit(X_train)

X_train_prep = preprocessor.transform(X_train)
X_test_prep = preprocessor.transform(X_test)
data_prep = preprocessor.transform(merged_data)
X_all_prep = preprocessor.transform(X)

# %%
preprocessor_1hot = ColumnTransformer(
	transformers=[
		('onehot_ordinal', OneHotEncoder(), categorical_ordinal),
		('onehot', OneHotEncoder(), categorical_onehot),
		('scaler', StandardScaler(), numerical_columns),
		('log', log_transform(), log_columns)
	], remainder='passthrough'
	)

preprocessor_1hot.fit(X_train)

X_train_prep_1hot = preprocessor_1hot.transform(X_train)
X_test_prep_1hot = preprocessor_1hot.transform(X_test)
data_prep_1hot = preprocessor_1hot.transform(merged_data)
X_all_prep_1hot = preprocessor_1hot.transform(X)

# %%
X_train_prep = pd.DataFrame(X_train_prep, columns=categorical_ordinal + list(preprocessor.named_transformers_['onehot'].get_feature_names_out()) + list(numerical_columns) + log_columns)
X_test_prep = pd.DataFrame(X_test_prep, columns=categorical_ordinal + list(preprocessor.named_transformers_['onehot'].get_feature_names_out()) + list(numerical_columns) + log_columns)
data_prep = pd.DataFrame(data_prep, columns=categorical_ordinal + list(preprocessor.named_transformers_['onehot'].get_feature_names_out()) + list(numerical_columns) + log_columns)

# %%
X_train_prep_1hot = pd.DataFrame(X_train_prep_1hot, columns=list(preprocessor_1hot.named_transformers_['onehot_ordinal'].get_feature_names_out()) + list(preprocessor_1hot.named_transformers_['onehot'].get_feature_names_out()) + list(numerical_columns) + log_columns)
X_test_prep_1hot = pd.DataFrame(X_test_prep_1hot, columns=list(preprocessor_1hot.named_transformers_['onehot_ordinal'].get_feature_names_out()) + list(preprocessor_1hot.named_transformers_['onehot'].get_feature_names_out()) + list(numerical_columns) + log_columns)
data_prep_1hot = pd.DataFrame(data_prep_1hot, columns=list(preprocessor_1hot.named_transformers_['onehot_ordinal'].get_feature_names_out()) + list(preprocessor_1hot.named_transformers_['onehot'].get_feature_names_out()) + list(numerical_columns) + log_columns)

# %%
data = pd.concat([data_prep, merged_data['status']], axis=1)
data2 = pd.concat([data_prep_1hot, merged_data['status']], axis=1)

# %%
data.corr()['status'].sort_values(ascending=False)
# Out:
# status                       1.000000
# grade                        0.387516
# percent_income               0.381489
# int_rate                     0.342122
# home_ownership_RENT          0.235270
# cb_default_on_file_Y         0.187731
# amnt                         0.107514
# intent_DEBTCONSOLIDATION     0.062683
# intent_MEDICAL               0.052528
# intent_HOMEIMPROVEMENT       0.032807
# home_ownership_OTHER         0.007847
# cb_cred_hist_length         -0.008054
# age                         -0.012068
# intent_PERSONAL             -0.015584
# intent_EDUCATION            -0.053588
# intent_VENTURE              -0.068691
# home_ownership_OWN          -0.089819
# emp_length_to_age_ratio     -0.100412
# emp_length                  -0.107466
# total_income_to_age_ratio   -0.110084
# cb_default_on_file_N        -0.187731
# home_ownership_MORTGAGE     -0.195413
# income_to_age_ratio         -0.240805
# income                      -0.251935
# Name: status, dtype: float64

# %%
data2.corr()['status'].sort_values(ascending=False)
# Out:
# status                       1.000000
# percent_income               0.381489
# grade_D                      0.370396
# int_rate                     0.342122
# home_ownership_RENT          0.235270
# cb_default_on_file_Y         0.187731
# grade_E                      0.186466
# amnt                         0.107514
# grade_F                      0.085307
# grade_G                      0.066016
# intent_DEBTCONSOLIDATION     0.062683
# intent_MEDICAL               0.052528
# intent_HOMEIMPROVEMENT       0.032807
# home_ownership_OTHER         0.007847
# cb_cred_hist_length         -0.008054
# grade_C                     -0.010940
# age                         -0.012068
# intent_PERSONAL             -0.015584
# intent_EDUCATION            -0.053588
# intent_VENTURE              -0.068691
# home_ownership_OWN          -0.089819
# grade_B                     -0.090109
# emp_length_to_age_ratio     -0.100412
# emp_length                  -0.107466
# total_income_to_age_ratio   -0.110084
# cb_default_on_file_N        -0.187731
# home_ownership_MORTGAGE     -0.195413
# grade_A                     -0.202219
# income_to_age_ratio         -0.240805
# income                      -0.251935
# Name: status, dtype: float64

# %%
data_prep.corr()['status'].sort_values(ascending=False)
# Out:
# status                       1.000000
# grade                        0.387516
# percent_income               0.381489
# int_rate                     0.342122
# home_ownership_RENT          0.235270
# cb_default_on_file_Y         0.187731
# amnt                         0.107514
# intent_DEBTCONSOLIDATION     0.062683
# intent_MEDICAL               0.052528
# intent_HOMEIMPROVEMENT       0.032807
# home_ownership_OTHER         0.007847
# cb_cred_hist_length         -0.008054
# age                         -0.012068
# intent_PERSONAL             -0.015584
# intent_EDUCATION            -0.053588
# intent_VENTURE              -0.068691
# home_ownership_OWN          -0.089819
# emp_length_to_age_ratio     -0.100412
# emp_length                  -0.107466
# total_income_to_age_ratio   -0.110084
# cb_default_on_file_N        -0.187731
# home_ownership_MORTGAGE     -0.195413
# income_to_age_ratio         -0.240805
# income                      -0.251935
# Name: status, dtype: float64

# %% [markdown]
# # XGBoost 1

# %%
import xgboost as xgb

# %%
dtrain = xgb.DMatrix(X_train_prep_1hot, label=y_train)
dtest = xgb.DMatrix(X_test_prep_1hot, label=y_test)

# %%
param = {'max_depth': 2, 'eta': 1, 'objective': 'binary:logistic'}
param['nthread'] = 4
param['eval_metric'] = 'auc'

evallist = [(dtest, 'evals'), (dtrain, 'train')]
num_round = 1000
bst = xgb.train(param, dtrain, num_round, evals=evallist, early_stopping_rounds=50)
# Out:
# [0]	evals-auc:0.83162	train-auc:0.82830
# [1]	evals-auc:0.87066	train-auc:0.86329
# [2]	evals-auc:0.89779	train-auc:0.89489
# [3]	evals-auc:0.90517	train-auc:0.90315
# [4]	evals-auc:0.91094	train-auc:0.90918
# [5]	evals-auc:0.90958	train-auc:0.90907
# [6]	evals-auc:0.91172	train-auc:0.91145
# [7]	evals-auc:0.91464	train-auc:0.91506
# [8]	evals-auc:0.91654	train-auc:0.91763
# [9]	evals-auc:0.91665	train-auc:0.91783
# [10]	evals-auc:0.91766	train-auc:0.91899
# [11]	evals-auc:0.91848	train-auc:0.92015
# [12]	evals-auc:0.91871	train-auc:0.92047
# [13]	evals-auc:0.92123	train-auc:0.92363
# [14]	evals-auc:0.92201	train-auc:0.92432
# [15]	evals-auc:0.92322	train-auc:0.92526
# [16]	evals-auc:0.92589	train-auc:0.92729
# [17]	evals-auc:0.92563	train-auc:0.92701
# [18]	evals-auc:0.92818	train-auc:0.92948
# [19]	evals-auc:0.92872	train-auc:0.93009
# [20]	evals-auc:0.92896	train-auc:0.93022
# [21]	evals-auc:0.93103	train-auc:0.93202
# [22]	evals-auc:0.93152	train-auc:0.93262
# [23]	evals-auc:0.93195	train-auc:0.93299
# [24]	evals-auc:0.93203	train-auc:0.93309
# [25]	evals-auc:0.93242	train-auc:0.93383
# [26]	evals-auc:0.93363	train-auc:0.93517
# [27]	evals-auc:0.93334	train-auc:0.93523
# [28]	evals-auc:0.93450	train-auc:0.93621
# [29]	evals-auc:0.93485	train-auc:0.93670
# [30]	evals-auc:0.93564	train-auc:0.93740
# [31]	evals-auc:0.93572	train-auc:0.93752
# [32]	evals-auc:0.93722	train-auc:0.93914
# [33]	evals-auc:0.93914	train-auc:0.94068
# [34]	evals-auc:0.94052	train-auc:0.94216
# [35]	evals-auc:0.94085	train-auc:0.94277
# [36]	evals-auc:0.94096	train-auc:0.94293
# [37]	evals-auc:0.94131	train-auc:0.94340
# [38]	evals-auc:0.94127	train-auc:0.94397
# [39]	evals-auc:0.94166	train-auc:0.94450
# [40]	evals-auc:0.94224	train-auc:0.94481
# [41]	evals-auc:0.94215	train-auc:0.94499
# [42]	evals-auc:0.94196	train-auc:0.94500
# [43]	evals-auc:0.94246	train-auc:0.94524
# [44]	evals-auc:0.94253	train-auc:0.94569
# [45]	evals-auc:0.94267	train-auc:0.94574
# [46]	evals-auc:0.94243	train-auc:0.94592
# [47]	evals-auc:0.94221	train-auc:0.94608
# [48]	evals-auc:0.94421	train-auc:0.94765
# [49]	evals-auc:0.94560	train-auc:0.94875
# [50]	evals-auc:0.94558	train-auc:0.94881
# [51]	evals-auc:0.94565	train-auc:0.94899
# [52]	evals-auc:0.94646	train-auc:0.94950
# [53]	evals-auc:0.94659	train-auc:0.95000
# [54]	evals-auc:0.94646	train-auc:0.95009
# [55]	evals-auc:0.94643	train-auc:0.95020
# [56]	evals-auc:0.94696	train-auc:0.95057
# [57]	evals-auc:0.94685	train-auc:0.95065
# [58]	evals-auc:0.94689	train-auc:0.95070
# [59]	evals-auc:0.94705	train-auc:0.95100
# [60]	evals-auc:0.94718	train-auc:0.95100
# [61]	evals-auc:0.94747	train-auc:0.95118
# [62]	evals-auc:0.94766	train-auc:0.95134
# [63]	evals-auc:0.94782	train-auc:0.95156
# [64]	evals-auc:0.94759	train-auc:0.95165
# [65]	evals-auc:0.94788	train-auc:0.95174
# [66]	evals-auc:0.94786	train-auc:0.95179
# [67]	evals-auc:0.94858	train-auc:0.95220
# [68]	evals-auc:0.94850	train-auc:0.95230
# [69]	evals-auc:0.94860	train-auc:0.95264
# [70]	evals-auc:0.94938	train-auc:0.95324
# [71]	evals-auc:0.94966	train-auc:0.95333
# [72]	evals-auc:0.94979	train-auc:0.95346
# [73]	evals-auc:0.94972	train-auc:0.95339
# [74]	evals-auc:0.94992	train-auc:0.95357
# [75]	evals-auc:0.94999	train-auc:0.95367
# [76]	evals-auc:0.94983	train-auc:0.95373
# [77]	evals-auc:0.94979	train-auc:0.95375
# [78]	evals-auc:0.94983	train-auc:0.95386
# [79]	evals-auc:0.95012	train-auc:0.95420
# [80]	evals-auc:0.95011	train-auc:0.95435
# [81]	evals-auc:0.95023	train-auc:0.95453
# [82]	evals-auc:0.95043	train-auc:0.95480
# [83]	evals-auc:0.95052	train-auc:0.95483
# [84]	evals-auc:0.95038	train-auc:0.95492
# [85]	evals-auc:0.95032	train-auc:0.95502
# [86]	evals-auc:0.95067	train-auc:0.95519
# [87]	evals-auc:0.95061	train-auc:0.95530
# [88]	evals-auc:0.95062	train-auc:0.95539
# [89]	evals-auc:0.95079	train-auc:0.95547
# [90]	evals-auc:0.95077	train-auc:0.95552
# [91]	evals-auc:0.95075	train-auc:0.95560
# [92]	evals-auc:0.95070	train-auc:0.95569
# [93]	evals-auc:0.95070	train-auc:0.95577
# [94]	evals-auc:0.95085	train-auc:0.95580
# [95]	evals-auc:0.95094	train-auc:0.95585
# [96]	evals-auc:0.95105	train-auc:0.95594
# [97]	evals-auc:0.95116	train-auc:0.95605
# [98]	evals-auc:0.95106	train-auc:0.95609
# [99]	evals-auc:0.95098	train-auc:0.95615
# [100]	evals-auc:0.95102	train-auc:0.95618
# [101]	evals-auc:0.95132	train-auc:0.95626
# [102]	evals-auc:0.95146	train-auc:0.95639
# [103]	evals-auc:0.95153	train-auc:0.95649
# [104]	evals-auc:0.95139	train-auc:0.95653
# [105]	evals-auc:0.95150	train-auc:0.95663
# [106]	evals-auc:0.95208	train-auc:0.95685
# [107]	evals-auc:0.95218	train-auc:0.95694
# [108]	evals-auc:0.95217	train-auc:0.95697
# [109]	evals-auc:0.95203	train-auc:0.95705
# [110]	evals-auc:0.95218	train-auc:0.95718
# [111]	evals-auc:0.95206	train-auc:0.95725
# [112]	evals-auc:0.95180	train-auc:0.95724
# [113]	evals-auc:0.95195	train-auc:0.95728
# [114]	evals-auc:0.95188	train-auc:0.95733
# [115]	evals-auc:0.95194	train-auc:0.95735
# [116]	evals-auc:0.95192	train-auc:0.95739
# [117]	evals-auc:0.95187	train-auc:0.95747
# [118]	evals-auc:0.95203	train-auc:0.95750
# [119]	evals-auc:0.95204	train-auc:0.95752
# [120]	evals-auc:0.95208	train-auc:0.95761
# [121]	evals-auc:0.95181	train-auc:0.95775
# [122]	evals-auc:0.95175	train-auc:0.95778
# [123]	evals-auc:0.95183	train-auc:0.95782
# [124]	evals-auc:0.95170	train-auc:0.95789
# [125]	evals-auc:0.95166	train-auc:0.95795
# [126]	evals-auc:0.95158	train-auc:0.95796
# [127]	evals-auc:0.95163	train-auc:0.95801
# [128]	evals-auc:0.95182	train-auc:0.95807
# [129]	evals-auc:0.95201	train-auc:0.95823
# [130]	evals-auc:0.95199	train-auc:0.95827
# [131]	evals-auc:0.95187	train-auc:0.95835
# [132]	evals-auc:0.95158	train-auc:0.95835
# [133]	evals-auc:0.95167	train-auc:0.95845
# [134]	evals-auc:0.95159	train-auc:0.95850
# [135]	evals-auc:0.95165	train-auc:0.95852
# [136]	evals-auc:0.95169	train-auc:0.95857
# [137]	evals-auc:0.95160	train-auc:0.95862
# [138]	evals-auc:0.95155	train-auc:0.95864
# [139]	evals-auc:0.95157	train-auc:0.95870
# [140]	evals-auc:0.95158	train-auc:0.95879
# [141]	evals-auc:0.95152	train-auc:0.95887
# [142]	evals-auc:0.95156	train-auc:0.95901
# [143]	evals-auc:0.95164	train-auc:0.95892
# [144]	evals-auc:0.95176	train-auc:0.95900
# [145]	evals-auc:0.95177	train-auc:0.95907
# [146]	evals-auc:0.95200	train-auc:0.95919
# [147]	evals-auc:0.95200	train-auc:0.95922
# [148]	evals-auc:0.95204	train-auc:0.95942
# [149]	evals-auc:0.95210	train-auc:0.95946
# [150]	evals-auc:0.95209	train-auc:0.95950
# [151]	evals-auc:0.95210	train-auc:0.95955
# [152]	evals-auc:0.95217	train-auc:0.95965
# [153]	evals-auc:0.95251	train-auc:0.95977
# [154]	evals-auc:0.95245	train-auc:0.95979
# [155]	evals-auc:0.95245	train-auc:0.95982
# [156]	evals-auc:0.95260	train-auc:0.95991
# [157]	evals-auc:0.95271	train-auc:0.95998
# [158]	evals-auc:0.95281	train-auc:0.96008
# [159]	evals-auc:0.95269	train-auc:0.96015
# [160]	evals-auc:0.95265	train-auc:0.96017
# [161]	evals-auc:0.95256	train-auc:0.96024
# [162]	evals-auc:0.95288	train-auc:0.96037
# [163]	evals-auc:0.95286	train-auc:0.96043
# [164]	evals-auc:0.95282	train-auc:0.96054
# [165]	evals-auc:0.95274	train-auc:0.96061
# [166]	evals-auc:0.95283	train-auc:0.96069
# [167]	evals-auc:0.95276	train-auc:0.96064
# [168]	evals-auc:0.95285	train-auc:0.96067
# [169]	evals-auc:0.95279	train-auc:0.96075
# [170]	evals-auc:0.95283	train-auc:0.96079
# [171]	evals-auc:0.95279	train-auc:0.96079
# [172]	evals-auc:0.95275	train-auc:0.96086
# [173]	evals-auc:0.95283	train-auc:0.96086
# [174]	evals-auc:0.95290	train-auc:0.96090
# [175]	evals-auc:0.95289	train-auc:0.96096
# [176]	evals-auc:0.95287	train-auc:0.96103
# [177]	evals-auc:0.95290	train-auc:0.96106
# [178]	evals-auc:0.95297	train-auc:0.96110
# [179]	evals-auc:0.95301	train-auc:0.96122
# [180]	evals-auc:0.95310	train-auc:0.96124
# [181]	evals-auc:0.95312	train-auc:0.96125
# [182]	evals-auc:0.95317	train-auc:0.96126
# [183]	evals-auc:0.95320	train-auc:0.96128
# [184]	evals-auc:0.95317	train-auc:0.96133
# [185]	evals-auc:0.95313	train-auc:0.96143
# [186]	evals-auc:0.95299	train-auc:0.96134
# [187]	evals-auc:0.95297	train-auc:0.96143
# [188]	evals-auc:0.95295	train-auc:0.96151
# [189]	evals-auc:0.95318	train-auc:0.96158
# [190]	evals-auc:0.95322	train-auc:0.96160
# [191]	evals-auc:0.95319	train-auc:0.96167
# [192]	evals-auc:0.95322	train-auc:0.96172
# [193]	evals-auc:0.95320	train-auc:0.96173
# [194]	evals-auc:0.95317	train-auc:0.96179
# [195]	evals-auc:0.95319	train-auc:0.96177
# [196]	evals-auc:0.95324	train-auc:0.96181
# [197]	evals-auc:0.95325	train-auc:0.96191
# [198]	evals-auc:0.95312	train-auc:0.96193
# [199]	evals-auc:0.95322	train-auc:0.96196
# [200]	evals-auc:0.95318	train-auc:0.96201
# [201]	evals-auc:0.95314	train-auc:0.96206
# [202]	evals-auc:0.95318	train-auc:0.96208
# [203]	evals-auc:0.95321	train-auc:0.96211
# [204]	evals-auc:0.95374	train-auc:0.96233
# [205]	evals-auc:0.95363	train-auc:0.96237
# [206]	evals-auc:0.95365	train-auc:0.96239
# [207]	evals-auc:0.95371	train-auc:0.96240
# [208]	evals-auc:0.95371	train-auc:0.96242
# [209]	evals-auc:0.95380	train-auc:0.96244
# [210]	evals-auc:0.95385	train-auc:0.96249
# [211]	evals-auc:0.95375	train-auc:0.96254
# [212]	evals-auc:0.95369	train-auc:0.96258
# [213]	evals-auc:0.95363	train-auc:0.96265
# [214]	evals-auc:0.95362	train-auc:0.96267
# [215]	evals-auc:0.95365	train-auc:0.96272
# [216]	evals-auc:0.95362	train-auc:0.96275
# [217]	evals-auc:0.95364	train-auc:0.96276
# [218]	evals-auc:0.95355	train-auc:0.96277
# [219]	evals-auc:0.95365	train-auc:0.96277
# [220]	evals-auc:0.95369	train-auc:0.96286
# [221]	evals-auc:0.95369	train-auc:0.96291
# [222]	evals-auc:0.95372	train-auc:0.96291
# [223]	evals-auc:0.95365	train-auc:0.96293
# [224]	evals-auc:0.95370	train-auc:0.96297
# [225]	evals-auc:0.95380	train-auc:0.96302
# [226]	evals-auc:0.95385	train-auc:0.96304
# [227]	evals-auc:0.95387	train-auc:0.96304
# [228]	evals-auc:0.95403	train-auc:0.96307
# [229]	evals-auc:0.95404	train-auc:0.96308
# [230]	evals-auc:0.95401	train-auc:0.96311
# [231]	evals-auc:0.95397	train-auc:0.96313
# [232]	evals-auc:0.95396	train-auc:0.96315
# [233]	evals-auc:0.95398	train-auc:0.96319
# [234]	evals-auc:0.95396	train-auc:0.96321
# [235]	evals-auc:0.95395	train-auc:0.96323
# [236]	evals-auc:0.95400	train-auc:0.96326
# [237]	evals-auc:0.95391	train-auc:0.96329
# [238]	evals-auc:0.95390	train-auc:0.96330
# [239]	evals-auc:0.95386	train-auc:0.96331
# [240]	evals-auc:0.95380	train-auc:0.96332
# [241]	evals-auc:0.95380	train-auc:0.96333
# [242]	evals-auc:0.95376	train-auc:0.96336
# [243]	evals-auc:0.95388	train-auc:0.96337
# [244]	evals-auc:0.95384	train-auc:0.96340
# [245]	evals-auc:0.95388	train-auc:0.96346
# [246]	evals-auc:0.95382	train-auc:0.96357
# [247]	evals-auc:0.95388	train-auc:0.96361
# [248]	evals-auc:0.95388	train-auc:0.96365
# [249]	evals-auc:0.95388	train-auc:0.96368
# [250]	evals-auc:0.95383	train-auc:0.96370
# [251]	evals-auc:0.95364	train-auc:0.96374
# [252]	evals-auc:0.95362	train-auc:0.96376
# [253]	evals-auc:0.95366	train-auc:0.96377
# [254]	evals-auc:0.95364	train-auc:0.96377
# [255]	evals-auc:0.95371	train-auc:0.96384
# [256]	evals-auc:0.95361	train-auc:0.96389
# [257]	evals-auc:0.95360	train-auc:0.96390
# [258]	evals-auc:0.95360	train-auc:0.96394
# [259]	evals-auc:0.95349	train-auc:0.96397
# [260]	evals-auc:0.95360	train-auc:0.96401
# [261]	evals-auc:0.95363	train-auc:0.96403
# [262]	evals-auc:0.95365	train-auc:0.96404
# [263]	evals-auc:0.95367	train-auc:0.96409
# [264]	evals-auc:0.95365	train-auc:0.96414
# [265]	evals-auc:0.95365	train-auc:0.96414
# [266]	evals-auc:0.95374	train-auc:0.96417
# [267]	evals-auc:0.95372	train-auc:0.96426
# [268]	evals-auc:0.95385	train-auc:0.96430
# [269]	evals-auc:0.95389	train-auc:0.96434
# [270]	evals-auc:0.95394	train-auc:0.96437
# [271]	evals-auc:0.95399	train-auc:0.96439
# [272]	evals-auc:0.95389	train-auc:0.96442
# [273]	evals-auc:0.95394	train-auc:0.96444
# [274]	evals-auc:0.95386	train-auc:0.96445
# [275]	evals-auc:0.95386	train-auc:0.96450
# [276]	evals-auc:0.95393	train-auc:0.96453
# [277]	evals-auc:0.95386	train-auc:0.96455
# [278]	evals-auc:0.95385	train-auc:0.96454
# [279]	evals-auc:0.95390	train-auc:0.96458
# [280]	evals-auc:0.95391	train-auc:0.96462
# [281]	evals-auc:0.95389	train-auc:0.96465
# [282]	evals-auc:0.95390	train-auc:0.96467
# [283]	evals-auc:0.95394	train-auc:0.96467
# [284]	evals-auc:0.95394	train-auc:0.96469
# [285]	evals-auc:0.95389	train-auc:0.96470
# [286]	evals-auc:0.95375	train-auc:0.96475
# [287]	evals-auc:0.95377	train-auc:0.96476
# [288]	evals-auc:0.95377	train-auc:0.96478
# [289]	evals-auc:0.95380	train-auc:0.96480
# [290]	evals-auc:0.95385	train-auc:0.96480
# [291]	evals-auc:0.95378	train-auc:0.96482
# [292]	evals-auc:0.95374	train-auc:0.96485
# [293]	evals-auc:0.95386	train-auc:0.96490
# [294]	evals-auc:0.95385	train-auc:0.96492
# [295]	evals-auc:0.95388	train-auc:0.96494
# [296]	evals-auc:0.95381	train-auc:0.96496
# [297]	evals-auc:0.95386	train-auc:0.96497
# [298]	evals-auc:0.95390	train-auc:0.96500
# [299]	evals-auc:0.95387	train-auc:0.96506
# [300]	evals-auc:0.95398	train-auc:0.96507
# [301]	evals-auc:0.95401	train-auc:0.96507
# [302]	evals-auc:0.95403	train-auc:0.96511
# [303]	evals-auc:0.95409	train-auc:0.96516
# [304]	evals-auc:0.95411	train-auc:0.96518
# [305]	evals-auc:0.95417	train-auc:0.96516
# [306]	evals-auc:0.95411	train-auc:0.96516
# [307]	evals-auc:0.95426	train-auc:0.96519
# [308]	evals-auc:0.95431	train-auc:0.96520
# [309]	evals-auc:0.95431	train-auc:0.96533
# [310]	evals-auc:0.95429	train-auc:0.96531
# [311]	evals-auc:0.95433	train-auc:0.96536
# [312]	evals-auc:0.95433	train-auc:0.96537
# [313]	evals-auc:0.95429	train-auc:0.96538
# [314]	evals-auc:0.95441	train-auc:0.96543
# [315]	evals-auc:0.95426	train-auc:0.96545
# [316]	evals-auc:0.95428	train-auc:0.96548
# [317]	evals-auc:0.95442	train-auc:0.96548
# [318]	evals-auc:0.95435	train-auc:0.96552
# [319]	evals-auc:0.95436	train-auc:0.96551
# [320]	evals-auc:0.95426	train-auc:0.96555
# [321]	evals-auc:0.95422	train-auc:0.96556
# [322]	evals-auc:0.95415	train-auc:0.96562
# [323]	evals-auc:0.95420	train-auc:0.96564
# [324]	evals-auc:0.95414	train-auc:0.96564
# [325]	evals-auc:0.95415	train-auc:0.96567
# [326]	evals-auc:0.95408	train-auc:0.96570
# [327]	evals-auc:0.95398	train-auc:0.96575
# [328]	evals-auc:0.95392	train-auc:0.96577
# [329]	evals-auc:0.95400	train-auc:0.96576
# [330]	evals-auc:0.95401	train-auc:0.96579
# [331]	evals-auc:0.95388	train-auc:0.96581
# [332]	evals-auc:0.95390	train-auc:0.96582
# [333]	evals-auc:0.95381	train-auc:0.96582
# [334]	evals-auc:0.95380	train-auc:0.96583
# [335]	evals-auc:0.95381	train-auc:0.96582
# [336]	evals-auc:0.95375	train-auc:0.96583
# [337]	evals-auc:0.95372	train-auc:0.96584
# [338]	evals-auc:0.95374	train-auc:0.96586
# [339]	evals-auc:0.95377	train-auc:0.96592
# [340]	evals-auc:0.95386	train-auc:0.96591
# [341]	evals-auc:0.95389	train-auc:0.96594
# [342]	evals-auc:0.95399	train-auc:0.96596
# [343]	evals-auc:0.95390	train-auc:0.96598
# [344]	evals-auc:0.95392	train-auc:0.96600
# [345]	evals-auc:0.95388	train-auc:0.96600
# [346]	evals-auc:0.95390	train-auc:0.96604
# [347]	evals-auc:0.95392	train-auc:0.96606
# [348]	evals-auc:0.95381	train-auc:0.96605
# [349]	evals-auc:0.95381	train-auc:0.96608
# [350]	evals-auc:0.95386	train-auc:0.96609
# [351]	evals-auc:0.95390	train-auc:0.96610
# [352]	evals-auc:0.95391	train-auc:0.96612
# [353]	evals-auc:0.95376	train-auc:0.96612
# [354]	evals-auc:0.95381	train-auc:0.96613
# [355]	evals-auc:0.95365	train-auc:0.96619
# [356]	evals-auc:0.95368	train-auc:0.96621
# [357]	evals-auc:0.95358	train-auc:0.96621
# [358]	evals-auc:0.95356	train-auc:0.96622
# [359]	evals-auc:0.95357	train-auc:0.96623
# [360]	evals-auc:0.95364	train-auc:0.96625
# [361]	evals-auc:0.95376	train-auc:0.96627
# [362]	evals-auc:0.95366	train-auc:0.96630
# [363]	evals-auc:0.95370	train-auc:0.96632
# [364]	evals-auc:0.95364	train-auc:0.96633
# [365]	evals-auc:0.95367	train-auc:0.96637
# [366]	evals-auc:0.95360	train-auc:0.96640
# [367]	evals-auc:0.95362	train-auc:0.96642
# [368]	evals-auc:0.95371	train-auc:0.96642
# [369]	evals-auc:0.95365	train-auc:0.96644
# [370]	evals-auc:0.95361	train-auc:0.96646
# [371]	evals-auc:0.95368	train-auc:0.96646
# [372]	evals-auc:0.95361	train-auc:0.96648
# [373]	evals-auc:0.95364	train-auc:0.96650
# [374]	evals-auc:0.95365	train-auc:0.96654
# [375]	evals-auc:0.95360	train-auc:0.96659
# [376]	evals-auc:0.95366	train-auc:0.96659
# [377]	evals-auc:0.95357	train-auc:0.96663
# [378]	evals-auc:0.95362	train-auc:0.96664
# [379]	evals-auc:0.95351	train-auc:0.96667
# [380]	evals-auc:0.95356	train-auc:0.96669
# [381]	evals-auc:0.95353	train-auc:0.96672
# [382]	evals-auc:0.95355	train-auc:0.96673
# [383]	evals-auc:0.95358	train-auc:0.96675
# [384]	evals-auc:0.95350	train-auc:0.96678
# [385]	evals-auc:0.95343	train-auc:0.96681
# [386]	evals-auc:0.95345	train-auc:0.96685
# [387]	evals-auc:0.95354	train-auc:0.96684
# [388]	evals-auc:0.95346	train-auc:0.96687
# [389]	evals-auc:0.95350	train-auc:0.96691
# [390]	evals-auc:0.95348	train-auc:0.96693
# [391]	evals-auc:0.95342	train-auc:0.96694
# [392]	evals-auc:0.95341	train-auc:0.96698
# [393]	evals-auc:0.95331	train-auc:0.96699
# [394]	evals-auc:0.95339	train-auc:0.96700
# [395]	evals-auc:0.95326	train-auc:0.96704
# [396]	evals-auc:0.95324	train-auc:0.96706
# [397]	evals-auc:0.95330	train-auc:0.96708
# [398]	evals-auc:0.95329	train-auc:0.96710
# [399]	evals-auc:0.95322	train-auc:0.96711
# [400]	evals-auc:0.95327	train-auc:0.96713
# [401]	evals-auc:0.95333	train-auc:0.96714
# [402]	evals-auc:0.95342	train-auc:0.96717
# [403]	evals-auc:0.95343	train-auc:0.96722
# [404]	evals-auc:0.95350	train-auc:0.96721
# [405]	evals-auc:0.95345	train-auc:0.96724
# [406]	evals-auc:0.95339	train-auc:0.96725
# [407]	evals-auc:0.95328	train-auc:0.96727
# [408]	evals-auc:0.95337	train-auc:0.96730
# [409]	evals-auc:0.95346	train-auc:0.96731
# [410]	evals-auc:0.95348	train-auc:0.96732
# [411]	evals-auc:0.95347	train-auc:0.96732
# [412]	evals-auc:0.95349	train-auc:0.96733
# [413]	evals-auc:0.95356	train-auc:0.96733
# [414]	evals-auc:0.95359	train-auc:0.96735
# [415]	evals-auc:0.95358	train-auc:0.96738
# [416]	evals-auc:0.95359	train-auc:0.96740
# [417]	evals-auc:0.95349	train-auc:0.96743
# [418]	evals-auc:0.95368	train-auc:0.96744
# [419]	evals-auc:0.95367	train-auc:0.96743
# [420]	evals-auc:0.95367	train-auc:0.96744
# [421]	evals-auc:0.95370	train-auc:0.96745
# [422]	evals-auc:0.95378	train-auc:0.96745
# [423]	evals-auc:0.95380	train-auc:0.96749
# [424]	evals-auc:0.95378	train-auc:0.96749
# [425]	evals-auc:0.95377	train-auc:0.96752
# [426]	evals-auc:0.95374	train-auc:0.96756
# [427]	evals-auc:0.95370	train-auc:0.96758
# [428]	evals-auc:0.95366	train-auc:0.96759
# [429]	evals-auc:0.95364	train-auc:0.96761
# [430]	evals-auc:0.95371	train-auc:0.96764
# [431]	evals-auc:0.95371	train-auc:0.96766
# [432]	evals-auc:0.95377	train-auc:0.96767
# [433]	evals-auc:0.95375	train-auc:0.96767
# [434]	evals-auc:0.95369	train-auc:0.96767
# [435]	evals-auc:0.95362	train-auc:0.96768
# [436]	evals-auc:0.95366	train-auc:0.96770
# [437]	evals-auc:0.95360	train-auc:0.96772
# [438]	evals-auc:0.95358	train-auc:0.96773
# [439]	evals-auc:0.95359	train-auc:0.96772
# [440]	evals-auc:0.95359	train-auc:0.96774
# [441]	evals-auc:0.95360	train-auc:0.96777
# [442]	evals-auc:0.95360	train-auc:0.96780
# [443]	evals-auc:0.95347	train-auc:0.96782
# [444]	evals-auc:0.95346	train-auc:0.96783
# [445]	evals-auc:0.95343	train-auc:0.96785
# [446]	evals-auc:0.95348	train-auc:0.96786
# [447]	evals-auc:0.95347	train-auc:0.96789
# [448]	evals-auc:0.95350	train-auc:0.96789
# [449]	evals-auc:0.95343	train-auc:0.96793
# [450]	evals-auc:0.95345	train-auc:0.96798
# [451]	evals-auc:0.95341	train-auc:0.96797
# [452]	evals-auc:0.95347	train-auc:0.96802
# [453]	evals-auc:0.95341	train-auc:0.96803
# [454]	evals-auc:0.95346	train-auc:0.96804
# [455]	evals-auc:0.95356	train-auc:0.96806
# [456]	evals-auc:0.95355	train-auc:0.96808
# [457]	evals-auc:0.95346	train-auc:0.96811
# [458]	evals-auc:0.95354	train-auc:0.96813
# [459]	evals-auc:0.95355	train-auc:0.96814
# [460]	evals-auc:0.95354	train-auc:0.96817
# [461]	evals-auc:0.95346	train-auc:0.96818
# [462]	evals-auc:0.95333	train-auc:0.96823
# [463]	evals-auc:0.95323	train-auc:0.96823
# [464]	evals-auc:0.95323	train-auc:0.96826
# [465]	evals-auc:0.95327	train-auc:0.96828
# [466]	evals-auc:0.95327	train-auc:0.96828
# [467]	evals-auc:0.95331	train-auc:0.96830
# [468]	evals-auc:0.95337	train-auc:0.96831
# [469]	evals-auc:0.95338	train-auc:0.96833
# [470]	evals-auc:0.95342	train-auc:0.96833
# [471]	evals-auc:0.95348	train-auc:0.96836
# [472]	evals-auc:0.95348	train-auc:0.96836
# [473]	evals-auc:0.95353	train-auc:0.96837
# [474]	evals-auc:0.95358	train-auc:0.96838
# [475]	evals-auc:0.95359	train-auc:0.96842
# [476]	evals-auc:0.95359	train-auc:0.96844
# [477]	evals-auc:0.95368	train-auc:0.96845
# [478]	evals-auc:0.95369	train-auc:0.96847
# [479]	evals-auc:0.95366	train-auc:0.96849
# [480]	evals-auc:0.95363	train-auc:0.96851
# [481]	evals-auc:0.95358	train-auc:0.96855
# [482]	evals-auc:0.95362	train-auc:0.96855
# [483]	evals-auc:0.95363	train-auc:0.96857
# [484]	evals-auc:0.95368	train-auc:0.96860
# [485]	evals-auc:0.95367	train-auc:0.96859
# [486]	evals-auc:0.95375	train-auc:0.96861
# [487]	evals-auc:0.95373	train-auc:0.96863
# [488]	evals-auc:0.95373	train-auc:0.96864
# [489]	evals-auc:0.95372	train-auc:0.96865
# [490]	evals-auc:0.95373	train-auc:0.96865
# [491]	evals-auc:0.95379	train-auc:0.96866
# [492]	evals-auc:0.95374	train-auc:0.96870
# [493]	evals-auc:0.95375	train-auc:0.96869
# [494]	evals-auc:0.95381	train-auc:0.96872
# [495]	evals-auc:0.95380	train-auc:0.96873
# [496]	evals-auc:0.95379	train-auc:0.96873
# [497]	evals-auc:0.95379	train-auc:0.96875
# [498]	evals-auc:0.95380	train-auc:0.96876
# [499]	evals-auc:0.95378	train-auc:0.96876
# [500]	evals-auc:0.95382	train-auc:0.96877
# [501]	evals-auc:0.95377	train-auc:0.96879
# [502]	evals-auc:0.95384	train-auc:0.96882
# [503]	evals-auc:0.95374	train-auc:0.96884
# [504]	evals-auc:0.95381	train-auc:0.96887
# [505]	evals-auc:0.95383	train-auc:0.96886
# [506]	evals-auc:0.95378	train-auc:0.96887
# [507]	evals-auc:0.95378	train-auc:0.96892
# [508]	evals-auc:0.95379	train-auc:0.96894
# [509]	evals-auc:0.95375	train-auc:0.96897
# [510]	evals-auc:0.95375	train-auc:0.96898
# [511]	evals-auc:0.95374	train-auc:0.96902
# [512]	evals-auc:0.95372	train-auc:0.96903
# [513]	evals-auc:0.95375	train-auc:0.96903
# [514]	evals-auc:0.95370	train-auc:0.96905
# [515]	evals-auc:0.95372	train-auc:0.96905
# [516]	evals-auc:0.95377	train-auc:0.96906
# [517]	evals-auc:0.95373	train-auc:0.96908
# [518]	evals-auc:0.95376	train-auc:0.96909
# [519]	evals-auc:0.95377	train-auc:0.96911
# [520]	evals-auc:0.95369	train-auc:0.96912
# [521]	evals-auc:0.95366	train-auc:0.96912
# [522]	evals-auc:0.95373	train-auc:0.96916
# [523]	evals-auc:0.95372	train-auc:0.96919
# [524]	evals-auc:0.95365	train-auc:0.96919
# [525]	evals-auc:0.95373	train-auc:0.96919
# [526]	evals-auc:0.95366	train-auc:0.96922
# [527]	evals-auc:0.95366	train-auc:0.96925
# [528]	evals-auc:0.95364	train-auc:0.96926
# [529]	evals-auc:0.95370	train-auc:0.96928
# [530]	evals-auc:0.95369	train-auc:0.96931
# [531]	evals-auc:0.95369	train-auc:0.96931
# [532]	evals-auc:0.95370	train-auc:0.96933
# [533]	evals-auc:0.95367	train-auc:0.96933
# [534]	evals-auc:0.95370	train-auc:0.96934
# [535]	evals-auc:0.95369	train-auc:0.96935
# [536]	evals-auc:0.95369	train-auc:0.96937
# [537]	evals-auc:0.95376	train-auc:0.96938
# [538]	evals-auc:0.95365	train-auc:0.96941
# [539]	evals-auc:0.95367	train-auc:0.96943
# [540]	evals-auc:0.95369	train-auc:0.96944
# [541]	evals-auc:0.95367	train-auc:0.96948
# [542]	evals-auc:0.95367	train-auc:0.96950
# [543]	evals-auc:0.95364	train-auc:0.96951
# [544]	evals-auc:0.95363	train-auc:0.96950
# [545]	evals-auc:0.95363	train-auc:0.96951
# [546]	evals-auc:0.95359	train-auc:0.96956
# [547]	evals-auc:0.95365	train-auc:0.96957
# [548]	evals-auc:0.95368	train-auc:0.96957
# [549]	evals-auc:0.95363	train-auc:0.96957
# [550]	evals-auc:0.95367	train-auc:0.96958
# [551]	evals-auc:0.95370	train-auc:0.96960
# [552]	evals-auc:0.95361	train-auc:0.96967
# [553]	evals-auc:0.95360	train-auc:0.96970
# [554]	evals-auc:0.95357	train-auc:0.96973
# [555]	evals-auc:0.95359	train-auc:0.96973
# [556]	evals-auc:0.95357	train-auc:0.96973
# [557]	evals-auc:0.95354	train-auc:0.96976
# [558]	evals-auc:0.95351	train-auc:0.96979
# [559]	evals-auc:0.95357	train-auc:0.96979
# [560]	evals-auc:0.95357	train-auc:0.96980
# [561]	evals-auc:0.95352	train-auc:0.96982
# [562]	evals-auc:0.95362	train-auc:0.96986
# [563]	evals-auc:0.95365	train-auc:0.96986
# [564]	evals-auc:0.95362	train-auc:0.96993
# [565]	evals-auc:0.95366	train-auc:0.96992
# [566]	evals-auc:0.95366	train-auc:0.96993
# [567]	evals-auc:0.95375	train-auc:0.96995
# [568]	evals-auc:0.95373	train-auc:0.97000
# [569]	evals-auc:0.95368	train-auc:0.97003
# [570]	evals-auc:0.95372	train-auc:0.97008
# [571]	evals-auc:0.95363	train-auc:0.97009
# [572]	evals-auc:0.95361	train-auc:0.97010
# [573]	evals-auc:0.95361	train-auc:0.97012
# [574]	evals-auc:0.95363	train-auc:0.97014
# [575]	evals-auc:0.95358	train-auc:0.97016
# [576]	evals-auc:0.95350	train-auc:0.97018
# [577]	evals-auc:0.95351	train-auc:0.97018
# [578]	evals-auc:0.95351	train-auc:0.97021
# [579]	evals-auc:0.95346	train-auc:0.97024
# [580]	evals-auc:0.95350	train-auc:0.97023
# [581]	evals-auc:0.95354	train-auc:0.97023
# [582]	evals-auc:0.95355	train-auc:0.97024
# [583]	evals-auc:0.95361	train-auc:0.97027
# [584]	evals-auc:0.95360	train-auc:0.97028
# [585]	evals-auc:0.95366	train-auc:0.97029
# [586]	evals-auc:0.95365	train-auc:0.97031
# [587]	evals-auc:0.95366	train-auc:0.97030
# [588]	evals-auc:0.95362	train-auc:0.97032
# [589]	evals-auc:0.95356	train-auc:0.97032
# [590]	evals-auc:0.95358	train-auc:0.97033
# [591]	evals-auc:0.95357	train-auc:0.97035
# [592]	evals-auc:0.95355	train-auc:0.97037
# [593]	evals-auc:0.95357	train-auc:0.97036
# [594]	evals-auc:0.95354	train-auc:0.97040
# [595]	evals-auc:0.95357	train-auc:0.97042
# [596]	evals-auc:0.95361	train-auc:0.97046
# [597]	evals-auc:0.95353	train-auc:0.97047
# [598]	evals-auc:0.95357	train-auc:0.97048
# [599]	evals-auc:0.95354	train-auc:0.97047
# [600]	evals-auc:0.95350	train-auc:0.97048
# [601]	evals-auc:0.95350	train-auc:0.97050
# [602]	evals-auc:0.95348	train-auc:0.97049
# [603]	evals-auc:0.95345	train-auc:0.97053
# [604]	evals-auc:0.95343	train-auc:0.97053
# [605]	evals-auc:0.95340	train-auc:0.97056
# [606]	evals-auc:0.95345	train-auc:0.97057
# [607]	evals-auc:0.95356	train-auc:0.97061
# [608]	evals-auc:0.95354	train-auc:0.97064
# [609]	evals-auc:0.95356	train-auc:0.97065
# [610]	evals-auc:0.95360	train-auc:0.97067
# [611]	evals-auc:0.95360	train-auc:0.97068
# [612]	evals-auc:0.95362	train-auc:0.97068
# [613]	evals-auc:0.95364	train-auc:0.97069
# [614]	evals-auc:0.95372	train-auc:0.97071
# [615]	evals-auc:0.95366	train-auc:0.97073
# [616]	evals-auc:0.95359	train-auc:0.97074
# [617]	evals-auc:0.95356	train-auc:0.97075
# [618]	evals-auc:0.95355	train-auc:0.97078
# [619]	evals-auc:0.95355	train-auc:0.97081
# [620]	evals-auc:0.95345	train-auc:0.97081
# [621]	evals-auc:0.95344	train-auc:0.97085
# [622]	evals-auc:0.95342	train-auc:0.97086
# [623]	evals-auc:0.95343	train-auc:0.97088
# [624]	evals-auc:0.95345	train-auc:0.97091
# [625]	evals-auc:0.95356	train-auc:0.97093
# [626]	evals-auc:0.95356	train-auc:0.97094
# [627]	evals-auc:0.95363	train-auc:0.97093
# [628]	evals-auc:0.95365	train-auc:0.97094
# [629]	evals-auc:0.95364	train-auc:0.97097
# [630]	evals-auc:0.95367	train-auc:0.97100
# [631]	evals-auc:0.95364	train-auc:0.97103
# [632]	evals-auc:0.95363	train-auc:0.97103
# [633]	evals-auc:0.95368	train-auc:0.97103
# [634]	evals-auc:0.95374	train-auc:0.97101
# [635]	evals-auc:0.95375	train-auc:0.97102
# [636]	evals-auc:0.95375	train-auc:0.97105
# [637]	evals-auc:0.95378	train-auc:0.97105
# [638]	evals-auc:0.95379	train-auc:0.97106
# [639]	evals-auc:0.95369	train-auc:0.97108
# [640]	evals-auc:0.95373	train-auc:0.97108
# [641]	evals-auc:0.95368	train-auc:0.97111
# [642]	evals-auc:0.95379	train-auc:0.97112
# [643]	evals-auc:0.95372	train-auc:0.97114
# [644]	evals-auc:0.95362	train-auc:0.97114
# [645]	evals-auc:0.95359	train-auc:0.97115
# [646]	evals-auc:0.95365	train-auc:0.97113
# [647]	evals-auc:0.95362	train-auc:0.97112
# [648]	evals-auc:0.95361	train-auc:0.97115
# [649]	evals-auc:0.95356	train-auc:0.97116
# [650]	evals-auc:0.95355	train-auc:0.97116
# [651]	evals-auc:0.95357	train-auc:0.97117
# [652]	evals-auc:0.95355	train-auc:0.97119
# [653]	evals-auc:0.95352	train-auc:0.97119
# [654]	evals-auc:0.95347	train-auc:0.97120
# [655]	evals-auc:0.95350	train-auc:0.97122
# [656]	evals-auc:0.95348	train-auc:0.97124
# [657]	evals-auc:0.95341	train-auc:0.97125
# [658]	evals-auc:0.95333	train-auc:0.97127
# [659]	evals-auc:0.95333	train-auc:0.97127
# [660]	evals-auc:0.95343	train-auc:0.97128
# [661]	evals-auc:0.95347	train-auc:0.97131
# [662]	evals-auc:0.95355	train-auc:0.97133
# [663]	evals-auc:0.95351	train-auc:0.97133
# [664]	evals-auc:0.95349	train-auc:0.97134
# [665]	evals-auc:0.95343	train-auc:0.97134
# [666]	evals-auc:0.95343	train-auc:0.97134
# [667]	evals-auc:0.95346	train-auc:0.97135
# [668]	evals-auc:0.95350	train-auc:0.97135
# [669]	evals-auc:0.95351	train-auc:0.97136
# [670]	evals-auc:0.95340	train-auc:0.97138
# [671]	evals-auc:0.95344	train-auc:0.97140
# [672]	evals-auc:0.95347	train-auc:0.97141
# [673]	evals-auc:0.95345	train-auc:0.97143
# [674]	evals-auc:0.95342	train-auc:0.97148
# [675]	evals-auc:0.95355	train-auc:0.97146
# [676]	evals-auc:0.95353	train-auc:0.97147
# [677]	evals-auc:0.95352	train-auc:0.97147
# [678]	evals-auc:0.95351	train-auc:0.97149
# [679]	evals-auc:0.95341	train-auc:0.97152
# [680]	evals-auc:0.95348	train-auc:0.97155
# [681]	evals-auc:0.95343	train-auc:0.97155
# [682]	evals-auc:0.95344	train-auc:0.97156
# [683]	evals-auc:0.95348	train-auc:0.97159
# [684]	evals-auc:0.95360	train-auc:0.97159
# [685]	evals-auc:0.95356	train-auc:0.97162
# [686]	evals-auc:0.95358	train-auc:0.97164
# [687]	evals-auc:0.95370	train-auc:0.97165
# [688]	evals-auc:0.95368	train-auc:0.97168
# [689]	evals-auc:0.95367	train-auc:0.97169
# [690]	evals-auc:0.95359	train-auc:0.97172
# [691]	evals-auc:0.95363	train-auc:0.97171
# [692]	evals-auc:0.95355	train-auc:0.97173
# [693]	evals-auc:0.95348	train-auc:0.97174
# [694]	evals-auc:0.95348	train-auc:0.97175
# [695]	evals-auc:0.95341	train-auc:0.97176
# [696]	evals-auc:0.95346	train-auc:0.97177
# [697]	evals-auc:0.95346	train-auc:0.97180
# [698]	evals-auc:0.95343	train-auc:0.97180
# [699]	evals-auc:0.95344	train-auc:0.97180
# [700]	evals-auc:0.95343	train-auc:0.97180
# [701]	evals-auc:0.95342	train-auc:0.97179
# [702]	evals-auc:0.95346	train-auc:0.97180
# [703]	evals-auc:0.95341	train-auc:0.97181
# [704]	evals-auc:0.95342	train-auc:0.97180
# [705]	evals-auc:0.95344	train-auc:0.97183
# [706]	evals-auc:0.95343	train-auc:0.97184
# [707]	evals-auc:0.95344	train-auc:0.97184
# [708]	evals-auc:0.95341	train-auc:0.97187
# [709]	evals-auc:0.95338	train-auc:0.97187
# [710]	evals-auc:0.95335	train-auc:0.97188
# [711]	evals-auc:0.95341	train-auc:0.97190
# [712]	evals-auc:0.95343	train-auc:0.97189
# [713]	evals-auc:0.95343	train-auc:0.97191
# [714]	evals-auc:0.95333	train-auc:0.97193
# [715]	evals-auc:0.95335	train-auc:0.97193
# [716]	evals-auc:0.95334	train-auc:0.97197
# [717]	evals-auc:0.95337	train-auc:0.97199
# [718]	evals-auc:0.95343	train-auc:0.97199
# [719]	evals-auc:0.95339	train-auc:0.97200
# [720]	evals-auc:0.95340	train-auc:0.97200
# [721]	evals-auc:0.95335	train-auc:0.97201
# [722]	evals-auc:0.95336	train-auc:0.97201
# [723]	evals-auc:0.95333	train-auc:0.97202
# [724]	evals-auc:0.95337	train-auc:0.97201
# [725]	evals-auc:0.95327	train-auc:0.97203
# [726]	evals-auc:0.95323	train-auc:0.97203
# [727]	evals-auc:0.95318	train-auc:0.97205
# [728]	evals-auc:0.95322	train-auc:0.97208
# [729]	evals-auc:0.95325	train-auc:0.97208
# [730]	evals-auc:0.95325	train-auc:0.97209
# [731]	evals-auc:0.95325	train-auc:0.97209
# [732]	evals-auc:0.95327	train-auc:0.97211
# [733]	evals-auc:0.95325	train-auc:0.97212
# [734]	evals-auc:0.95325	train-auc:0.97216
# [735]	evals-auc:0.95325	train-auc:0.97215
# [736]	evals-auc:0.95324	train-auc:0.97216
# [737]	evals-auc:0.95324	train-auc:0.97217
# [738]	evals-auc:0.95321	train-auc:0.97218
# [739]	evals-auc:0.95322	train-auc:0.97218
# [740]	evals-auc:0.95324	train-auc:0.97223
# [741]	evals-auc:0.95326	train-auc:0.97221
# [742]	evals-auc:0.95328	train-auc:0.97221
# [743]	evals-auc:0.95328	train-auc:0.97223
# [744]	evals-auc:0.95325	train-auc:0.97223
# [745]	evals-auc:0.95327	train-auc:0.97225
# [746]	evals-auc:0.95335	train-auc:0.97225
# [747]	evals-auc:0.95329	train-auc:0.97229
# [748]	evals-auc:0.95326	train-auc:0.97231
# [749]	evals-auc:0.95324	train-auc:0.97232
# [750]	evals-auc:0.95322	train-auc:0.97234
# [751]	evals-auc:0.95326	train-auc:0.97234
# [752]	evals-auc:0.95322	train-auc:0.97237
# [753]	evals-auc:0.95324	train-auc:0.97236
# [754]	evals-auc:0.95322	train-auc:0.97238
# [755]	evals-auc:0.95328	train-auc:0.97237
# [756]	evals-auc:0.95336	train-auc:0.97238
# [757]	evals-auc:0.95329	train-auc:0.97240
# [758]	evals-auc:0.95336	train-auc:0.97240
# [759]	evals-auc:0.95339	train-auc:0.97241
# [760]	evals-auc:0.95340	train-auc:0.97242
# [761]	evals-auc:0.95336	train-auc:0.97242
# [762]	evals-auc:0.95338	train-auc:0.97243
# [763]	evals-auc:0.95343	train-auc:0.97245
# [764]	evals-auc:0.95342	train-auc:0.97245
# [765]	evals-auc:0.95338	train-auc:0.97246
# [766]	evals-auc:0.95340	train-auc:0.97245
# [767]	evals-auc:0.95334	train-auc:0.97248
# [768]	evals-auc:0.95331	train-auc:0.97248
# [769]	evals-auc:0.95332	train-auc:0.97249
# [770]	evals-auc:0.95330	train-auc:0.97249
# [771]	evals-auc:0.95328	train-auc:0.97251
# [772]	evals-auc:0.95331	train-auc:0.97250
# [773]	evals-auc:0.95329	train-auc:0.97252
# [774]	evals-auc:0.95330	train-auc:0.97253
# [775]	evals-auc:0.95325	train-auc:0.97254
# [776]	evals-auc:0.95321	train-auc:0.97255
# [777]	evals-auc:0.95320	train-auc:0.97257
# [778]	evals-auc:0.95324	train-auc:0.97257
# [779]	evals-auc:0.95323	train-auc:0.97258
# [780]	evals-auc:0.95325	train-auc:0.97258
# [781]	evals-auc:0.95322	train-auc:0.97259
# [782]	evals-auc:0.95322	train-auc:0.97260
# [783]	evals-auc:0.95318	train-auc:0.97262
# [784]	evals-auc:0.95316	train-auc:0.97262
# [785]	evals-auc:0.95329	train-auc:0.97261
# [786]	evals-auc:0.95321	train-auc:0.97263
# [787]	evals-auc:0.95325	train-auc:0.97264
# [788]	evals-auc:0.95327	train-auc:0.97265
# [789]	evals-auc:0.95338	train-auc:0.97266
# [790]	evals-auc:0.95340	train-auc:0.97269
# [791]	evals-auc:0.95332	train-auc:0.97271
# [792]	evals-auc:0.95322	train-auc:0.97274
# [793]	evals-auc:0.95320	train-auc:0.97275
# [794]	evals-auc:0.95322	train-auc:0.97278
# [795]	evals-auc:0.95329	train-auc:0.97279
# [796]	evals-auc:0.95327	train-auc:0.97280
# [797]	evals-auc:0.95323	train-auc:0.97281
# [798]	evals-auc:0.95326	train-auc:0.97284
# [799]	evals-auc:0.95330	train-auc:0.97282
# [800]	evals-auc:0.95334	train-auc:0.97283
# [801]	evals-auc:0.95335	train-auc:0.97284
# [802]	evals-auc:0.95336	train-auc:0.97283
# [803]	evals-auc:0.95354	train-auc:0.97289
# [804]	evals-auc:0.95347	train-auc:0.97291
# [805]	evals-auc:0.95352	train-auc:0.97293
# [806]	evals-auc:0.95347	train-auc:0.97292
# [807]	evals-auc:0.95348	train-auc:0.97294
# [808]	evals-auc:0.95348	train-auc:0.97295
# [809]	evals-auc:0.95341	train-auc:0.97298
# [810]	evals-auc:0.95338	train-auc:0.97300
# [811]	evals-auc:0.95337	train-auc:0.97300
# [812]	evals-auc:0.95338	train-auc:0.97301
# [813]	evals-auc:0.95344	train-auc:0.97302
# [814]	evals-auc:0.95342	train-auc:0.97304
# [815]	evals-auc:0.95350	train-auc:0.97303
# [816]	evals-auc:0.95339	train-auc:0.97308
# [817]	evals-auc:0.95339	train-auc:0.97310
# [818]	evals-auc:0.95335	train-auc:0.97311
# [819]	evals-auc:0.95332	train-auc:0.97314
# [820]	evals-auc:0.95327	train-auc:0.97314
# [821]	evals-auc:0.95321	train-auc:0.97315
# [822]	evals-auc:0.95325	train-auc:0.97315
# [823]	evals-auc:0.95324	train-auc:0.97314
# [824]	evals-auc:0.95326	train-auc:0.97316
# [825]	evals-auc:0.95326	train-auc:0.97318
# [826]	evals-auc:0.95326	train-auc:0.97319
# [827]	evals-auc:0.95322	train-auc:0.97321
# [828]	evals-auc:0.95319	train-auc:0.97324
# [829]	evals-auc:0.95317	train-auc:0.97326
# [830]	evals-auc:0.95312	train-auc:0.97328
# [831]	evals-auc:0.95313	train-auc:0.97328
# [832]	evals-auc:0.95319	train-auc:0.97331
# [833]	evals-auc:0.95315	train-auc:0.97335
# [834]	evals-auc:0.95317	train-auc:0.97334
# [835]	evals-auc:0.95318	train-auc:0.97334
# [836]	evals-auc:0.95323	train-auc:0.97333
# [837]	evals-auc:0.95323	train-auc:0.97334
# [838]	evals-auc:0.95315	train-auc:0.97336
# [839]	evals-auc:0.95318	train-auc:0.97338
# [840]	evals-auc:0.95325	train-auc:0.97339
# [841]	evals-auc:0.95325	train-auc:0.97341
# [842]	evals-auc:0.95320	train-auc:0.97344
# [843]	evals-auc:0.95321	train-auc:0.97346
# [844]	evals-auc:0.95324	train-auc:0.97345
# [845]	evals-auc:0.95324	train-auc:0.97346
# [846]	evals-auc:0.95328	train-auc:0.97347
# [847]	evals-auc:0.95326	train-auc:0.97349
# [848]	evals-auc:0.95323	train-auc:0.97351
# [849]	evals-auc:0.95329	train-auc:0.97351
# [850]	evals-auc:0.95322	train-auc:0.97352
# [851]	evals-auc:0.95327	train-auc:0.97353
# [852]	evals-auc:0.95328	train-auc:0.97354
# [853]	evals-auc:0.95332	train-auc:0.97354
# [854]	evals-auc:0.95330	train-auc:0.97356
# [855]	evals-auc:0.95322	train-auc:0.97356
# [856]	evals-auc:0.95321	train-auc:0.97359
# [857]	evals-auc:0.95313	train-auc:0.97362
# [858]	evals-auc:0.95321	train-auc:0.97360
# [859]	evals-auc:0.95325	train-auc:0.97360
# [860]	evals-auc:0.95309	train-auc:0.97363
# [861]	evals-auc:0.95309	train-auc:0.97364
# [862]	evals-auc:0.95315	train-auc:0.97364
# [863]	evals-auc:0.95312	train-auc:0.97364
# [864]	evals-auc:0.95316	train-auc:0.97364
# [865]	evals-auc:0.95310	train-auc:0.97366
# [866]	evals-auc:0.95310	train-auc:0.97366
# [867]	evals-auc:0.95306	train-auc:0.97368
# [868]	evals-auc:0.95305	train-auc:0.97371
# [869]	evals-auc:0.95298	train-auc:0.97371
# [870]	evals-auc:0.95300	train-auc:0.97373
# [871]	evals-auc:0.95302	train-auc:0.97372
# [872]	evals-auc:0.95301	train-auc:0.97373
# [873]	evals-auc:0.95294	train-auc:0.97374
# [874]	evals-auc:0.95294	train-auc:0.97376
# [875]	evals-auc:0.95294	train-auc:0.97371
# [876]	evals-auc:0.95292	train-auc:0.97368
# [877]	evals-auc:0.95290	train-auc:0.97370
# [878]	evals-auc:0.95286	train-auc:0.97372
# [879]	evals-auc:0.95285	train-auc:0.97372
# [880]	evals-auc:0.95282	train-auc:0.97373
# [881]	evals-auc:0.95280	train-auc:0.97376
# [882]	evals-auc:0.95280	train-auc:0.97375
# [883]	evals-auc:0.95276	train-auc:0.97377
# [884]	evals-auc:0.95272	train-auc:0.97378
# [885]	evals-auc:0.95278	train-auc:0.97379
# [886]	evals-auc:0.95280	train-auc:0.97378
# [887]	evals-auc:0.95284	train-auc:0.97379
# [888]	evals-auc:0.95279	train-auc:0.97380
# [889]	evals-auc:0.95278	train-auc:0.97381
# [890]	evals-auc:0.95281	train-auc:0.97384
# [891]	evals-auc:0.95289	train-auc:0.97384
# [892]	evals-auc:0.95289	train-auc:0.97384
# [893]	evals-auc:0.95279	train-auc:0.97385
# [894]	evals-auc:0.95277	train-auc:0.97388
# [895]	evals-auc:0.95278	train-auc:0.97388
# [896]	evals-auc:0.95281	train-auc:0.97390
# [897]	evals-auc:0.95283	train-auc:0.97389
# [898]	evals-auc:0.95282	train-auc:0.97390
# [899]	evals-auc:0.95283	train-auc:0.97390
# [900]	evals-auc:0.95281	train-auc:0.97392
# [901]	evals-auc:0.95285	train-auc:0.97393
# [902]	evals-auc:0.95289	train-auc:0.97394
# [903]	evals-auc:0.95292	train-auc:0.97395
# [904]	evals-auc:0.95291	train-auc:0.97398
# [905]	evals-auc:0.95291	train-auc:0.97399
# [906]	evals-auc:0.95284	train-auc:0.97401
# [907]	evals-auc:0.95281	train-auc:0.97402
# [908]	evals-auc:0.95281	train-auc:0.97401
# [909]	evals-auc:0.95280	train-auc:0.97403
# [910]	evals-auc:0.95277	train-auc:0.97403
# [911]	evals-auc:0.95277	train-auc:0.97405
# [912]	evals-auc:0.95287	train-auc:0.97406
# [913]	evals-auc:0.95281	train-auc:0.97407
# [914]	evals-auc:0.95279	train-auc:0.97408
# [915]	evals-auc:0.95278	train-auc:0.97408
# [916]	evals-auc:0.95285	train-auc:0.97411
# [917]	evals-auc:0.95283	train-auc:0.97411
# [918]	evals-auc:0.95286	train-auc:0.97410
# [919]	evals-auc:0.95288	train-auc:0.97410
# [920]	evals-auc:0.95282	train-auc:0.97412
# [921]	evals-auc:0.95287	train-auc:0.97415
# [922]	evals-auc:0.95289	train-auc:0.97415
# [923]	evals-auc:0.95281	train-auc:0.97416
# [924]	evals-auc:0.95277	train-auc:0.97418
# [925]	evals-auc:0.95278	train-auc:0.97419
# [926]	evals-auc:0.95279	train-auc:0.97421
# [927]	evals-auc:0.95279	train-auc:0.97420
# [928]	evals-auc:0.95283	train-auc:0.97422
# [929]	evals-auc:0.95287	train-auc:0.97423
# [930]	evals-auc:0.95276	train-auc:0.97425
# [931]	evals-auc:0.95280	train-auc:0.97424
# [932]	evals-auc:0.95282	train-auc:0.97424
# [933]	evals-auc:0.95277	train-auc:0.97427
# [934]	evals-auc:0.95272	train-auc:0.97428
# [935]	evals-auc:0.95272	train-auc:0.97429
# [936]	evals-auc:0.95269	train-auc:0.97430
# [937]	evals-auc:0.95268	train-auc:0.97430
# [938]	evals-auc:0.95265	train-auc:0.97434
# [939]	evals-auc:0.95263	train-auc:0.97435
# [940]	evals-auc:0.95271	train-auc:0.97434
# [941]	evals-auc:0.95270	train-auc:0.97435
# [942]	evals-auc:0.95270	train-auc:0.97434
# [943]	evals-auc:0.95271	train-auc:0.97435
# [944]	evals-auc:0.95264	train-auc:0.97439
# [945]	evals-auc:0.95260	train-auc:0.97438
# [946]	evals-auc:0.95257	train-auc:0.97438
# [947]	evals-auc:0.95264	train-auc:0.97438
# [948]	evals-auc:0.95260	train-auc:0.97442
# [949]	evals-auc:0.95265	train-auc:0.97441
# [950]	evals-auc:0.95272	train-auc:0.97444
# [951]	evals-auc:0.95267	train-auc:0.97446
# [952]	evals-auc:0.95267	train-auc:0.97447
# [953]	evals-auc:0.95273	train-auc:0.97448
# [954]	evals-auc:0.95280	train-auc:0.97448
# [955]	evals-auc:0.95275	train-auc:0.97450
# [956]	evals-auc:0.95277	train-auc:0.97451
# [957]	evals-auc:0.95277	train-auc:0.97450
# [958]	evals-auc:0.95271	train-auc:0.97450
# [959]	evals-auc:0.95268	train-auc:0.97453
# [960]	evals-auc:0.95267	train-auc:0.97455
# [961]	evals-auc:0.95273	train-auc:0.97454
# [962]	evals-auc:0.95276	train-auc:0.97455
# [963]	evals-auc:0.95274	train-auc:0.97456
# [964]	evals-auc:0.95280	train-auc:0.97457
# [965]	evals-auc:0.95280	train-auc:0.97459
# [966]	evals-auc:0.95276	train-auc:0.97461
# [967]	evals-auc:0.95275	train-auc:0.97460
# [968]	evals-auc:0.95274	train-auc:0.97460
# [969]	evals-auc:0.95262	train-auc:0.97462
# [970]	evals-auc:0.95268	train-auc:0.97461
# [971]	evals-auc:0.95264	train-auc:0.97461
# [972]	evals-auc:0.95265	train-auc:0.97462
# [973]	evals-auc:0.95264	train-auc:0.97462
# [974]	evals-auc:0.95264	train-auc:0.97463
# [975]	evals-auc:0.95266	train-auc:0.97464
# [976]	evals-auc:0.95263	train-auc:0.97464
# [977]	evals-auc:0.95261	train-auc:0.97466
# [978]	evals-auc:0.95266	train-auc:0.97466
# [979]	evals-auc:0.95264	train-auc:0.97466
# [980]	evals-auc:0.95260	train-auc:0.97469
# [981]	evals-auc:0.95258	train-auc:0.97467
# [982]	evals-auc:0.95251	train-auc:0.97468
# [983]	evals-auc:0.95250	train-auc:0.97469
# [984]	evals-auc:0.95254	train-auc:0.97470
# [985]	evals-auc:0.95259	train-auc:0.97471
# [986]	evals-auc:0.95258	train-auc:0.97472
# [987]	evals-auc:0.95263	train-auc:0.97472
# [988]	evals-auc:0.95264	train-auc:0.97477
# [989]	evals-auc:0.95252	train-auc:0.97477
# [990]	evals-auc:0.95257	train-auc:0.97479
# [991]	evals-auc:0.95251	train-auc:0.97479
# [992]	evals-auc:0.95252	train-auc:0.97478
# [993]	evals-auc:0.95250	train-auc:0.97480
# [994]	evals-auc:0.95256	train-auc:0.97481
# [995]	evals-auc:0.95256	train-auc:0.97481
# [996]	evals-auc:0.95260	train-auc:0.97482
# [997]	evals-auc:0.95261	train-auc:0.97482
# [998]	evals-auc:0.95257	train-auc:0.97483
# [999]	evals-auc:0.95257	train-auc:0.97484

# %% [markdown]
# ## Cross Validation

# %%
cv_results = xgb.cv(param, dtrain, num_round, nfold=5, metrics={'auc'}, early_stopping_rounds=10)
cv_results = pd.DataFrame(cv_results)
cv_results.plot(y=['train-auc-mean', 'test-auc-mean'], title='AUC')
# Out:
# <Axes: title={'center': 'AUC'}>

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ## 1st Try
#
# GridSearchCV:
# ```python
# param_grid = {
#     'max_depth': [3, 5, 7],
#     'learning_rate': [0.01, 0.1],
#     'n_estimators': [100, 200],
# 	}
#
# Best_Parameters = {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
# Best_AUC_Score = 0.9528388314968684
# ```

# %% [markdown]
# ## 2nd Try
#
# GridSearchCV:
#
# ```python
# param_grid = {
#     'max_depth': [5, 7],
#     'learning_rate': [0.1, 0.2, 0.5],
#     'n_estimators': [200, 300, 500],
# 	'subsample': [0.8],
#     'colsample_bytree': [0.8],
#     'gamma': [0, 0.1, 0.3],
# }
#
# Best_Parameters = {'colsample_bytree': 0.8, 'gamma': 0, 'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 300, 'subsample': 0.8}
# Best_AUC_Score = 0.9543454696625759
# ```

# %% [markdown]
# ## 3rd Try
#
# RandomizedSearchCV:
#
# ```python
# param_dist = {
# 	'max_depth': np.arange(3, 12),
# 	'learning_rate': np.linspace(0.01, 0.3, 20),
# 	'n_estimators': np.arange(300, 600, 25),
# 	'subsample': np.linspace(0.6, 1.0, 10),
# 	'colsample_bytree': np.linspace(0.5, 1.0, 10),
# 	'gamma': np.linspace(0, 0.3, 20),
# 	'min_child_weight': np.arange(1, 9),
# }
#
# Best_params = {
# 	'subsample': 0.9111111111111111,
# 	'n_estimators': 525,
# 	'min_child_weight': 5,
# 	'max_depth': 5,
# 	'learning_rate': 0.07105263157894737,
# 	'gamma': 0.3,
# 	'colsample_bytree': 0.5
# 	}
#
# Best_AUC_score =  0.9532664601824515
# ```

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import optuna

# %%
# Using RandomizedSearchCV
xgb_model = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc')

param_dist = {
    'max_depth': np.arange(3, 10),
    'learning_rate': np.linspace(0.01, 0.3, 10),
    'n_estimators': np.arange(100, 1000, 100),
    'subsample': np.linspace(0.5, 1.0, 6),
    'colsample_bytree': np.linspace(0.5, 1.0, 6),
    'gamma': np.linspace(0, 0.5, 6),
    'min_child_weight': np.arange(1, 6),
    'alpha': np.logspace(-3, 1, 5),  # L1 regularization
    'lambda': np.logspace(-3, 1, 5)  # L2 regularization
}

rs = RandomizedSearchCV(xgb_model, param_dist, n_iter=100, cv=3, scoring='roc_auc', n_jobs=-1, verbose=1, random_state=2024)

# %%
rs.fit(X_train_prep_1hot, y_train)
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# RandomizedSearchCV(cv=3,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric='auc',
#                                            feature_types=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constraints=None,
#                                            learning_rat...
#                                         'lambda': array([1.e-03, 1.e-02, 1.e-01, 1.e+00, 1.e+01]),
#                                         'learning_rate': array([0.01      , 0.04222222, 0.07444444, 0.10666667, 0.13888889,
#        0.17111111, 0.20333333, 0.23555556, 0.26777778, 0.3       ]),
#                                         'max_depth': array([3, 4, 5, 6, 7, 8, 9]),
#                                         'min_child_weight': array([1, 2, 3, 4, 5]),
#                                         'n_estimators': array([100, 200, 300, 400, 500, 600, 700, 800, 900]),
#                                         'subsample': array([0.5, 0.6, 0.7, 0.8, 0.9, 1. ])},
#                    random_state=2024, scoring='roc_auc', verbose=1)

# %%
rs.best_params_, rs.best_score_
# Out:
# ({'subsample': 0.8,
#   'n_estimators': 900,
#   'min_child_weight': 4,
#   'max_depth': 5,
#   'learning_rate': 0.07444444444444444,
#   'lambda': 1.0,
#   'gamma': 0.30000000000000004,
#   'colsample_bytree': 0.5,
#   'alpha': 1.0},
#  0.9540136407455174)

# %%
xgb_best = rs.best_estimator_
xgb_best.fit(X_train_prep, y_train)

y_pred = xgb_best.predict_proba(X_test_prep)
roc_auc_score(y_test, y_pred[:, 1])
# Out:
# 0.9600627499030651

# %%
import catboost as CatBoosterClassifier

# %%
cat_features = np.where(X_train.dtypes == object)[0]
cat_features
# Out:
# array([2, 4, 5, 9], dtype=int64)

# %%
cat_params = [
        {
            'task_type'           : "CPU",
            'loss_function'       : 'Logloss',
            'eval_metric'         : "AUC",
            'bagging_temperature' : 0.25,
            'colsample_bylevel'   : 0.40,
            'iterations'          : 5_000,
            'learning_rate'       : 0.045,
            'max_depth'           : 7,
            'l2_leaf_reg'         : 0.80,
            'min_data_in_leaf'    : 30,
            'random_strength'     : 0.25,
            'random_state': 42,
        },
        {
            'iterations': 1500,
            'depth': 6,
            'eta': 0.3, 
            'reg_lambda': 41.0, 
            'loss_function': 'Logloss',
            'eval_metric': 'AUC',
            'random_state': 42,
            'min_data_in_leaf': 51,
            'early_stopping_rounds': 150,
            'verbose':200,
        },
        {
            'iterations': 3000,
            'depth': 7,
            'eta': 0.3, 
            'reg_lambda': 40.0, 
            'loss_function': 'Logloss',
            'eval_metric': 'AUC',
            'random_state': 42,
            'min_data_in_leaf': 51,
            'early_stopping_rounds': 300,
            'verbose':200,
        },
        {
            'task_type'           : "CPU",
            'loss_function'       : 'Logloss',
            'eval_metric'         : "AUC",
            'bagging_temperature' : 0.25,
            'colsample_bylevel'   : 0.40,
            'iterations'          : 7_000,
            'learning_rate'       : 0.035,
            'max_depth'           : 8,
            'l2_leaf_reg'         : 0.80,
            'min_data_in_leaf'    : 30,
            'random_strength'     : 0.25,
            'early_stopping_rounds': 200,
            'random_state': 42,
        },
    ]

# %%
X_train_cat, X_test_cat, y_train_cat, y_test_cat = train_test_split(X, y, stratify=y, shuffle=True, test_size=0.2, random_state=2024)

# %%
cat_clf_0 = CatBoosterClassifier.CatBoostClassifier(**cat_params[0])
cat_clf_0.fit(X_train_cat, y_train_cat, cat_features=cat_features, eval_set=(X_test_cat, y_test_cat), early_stopping_rounds=200, verbose=50)
# Out:
# 0:	test: 0.8624934	best: 0.8624934 (0)	total: 101ms	remaining: 8m 22s
# 50:	test: 0.9265291	best: 0.9265291 (50)	total: 7.27s	remaining: 11m 45s
# 100:	test: 0.9347965	best: 0.9347965 (100)	total: 14.7s	remaining: 11m 50s
# 150:	test: 0.9399071	best: 0.9399071 (150)	total: 22.8s	remaining: 12m 13s
# 200:	test: 0.9429913	best: 0.9429913 (200)	total: 30.1s	remaining: 11m 58s
# 250:	test: 0.9448070	best: 0.9448295 (249)	total: 36.7s	remaining: 11m 33s
# 300:	test: 0.9464600	best: 0.9464600 (300)	total: 42.6s	remaining: 11m 5s
# 350:	test: 0.9479376	best: 0.9479376 (350)	total: 49s	remaining: 10m 48s
# 400:	test: 0.9489621	best: 0.9489830 (399)	total: 55.4s	remaining: 10m 35s
# 450:	test: 0.9503349	best: 0.9503349 (450)	total: 1m 1s	remaining: 10m 20s
# 500:	test: 0.9506825	best: 0.9506928 (499)	total: 1m 7s	remaining: 10m 7s
# 550:	test: 0.9520689	best: 0.9520775 (549)	total: 1m 14s	remaining: 10m
# 600:	test: 0.9527808	best: 0.9527808 (600)	total: 1m 20s	remaining: 9m 47s
# 650:	test: 0.9533661	best: 0.9533661 (650)	total: 1m 26s	remaining: 9m 41s
# 700:	test: 0.9537108	best: 0.9537632 (697)	total: 1m 33s	remaining: 9m 31s
# 750:	test: 0.9541632	best: 0.9541632 (750)	total: 1m 39s	remaining: 9m 21s
# 800:	test: 0.9544485	best: 0.9544485 (800)	total: 1m 45s	remaining: 9m 12s
# 850:	test: 0.9545431	best: 0.9545431 (850)	total: 1m 51s	remaining: 9m 4s
# 900:	test: 0.9550953	best: 0.9550989 (899)	total: 1m 57s	remaining: 8m 56s
# 950:	test: 0.9553674	best: 0.9554039 (947)	total: 2m 4s	remaining: 8m 48s
# 1000:	test: 0.9555892	best: 0.9555892 (1000)	total: 2m 10s	remaining: 8m 41s
# 1050:	test: 0.9557647	best: 0.9558041 (1042)	total: 2m 16s	remaining: 8m 34s
# 1100:	test: 0.9558539	best: 0.9558897 (1086)	total: 2m 23s	remaining: 8m 27s
# 1150:	test: 0.9559021	best: 0.9559585 (1145)	total: 2m 29s	remaining: 8m 20s
# 1200:	test: 0.9560552	best: 0.9560665 (1198)	total: 2m 36s	remaining: 8m 13s
# 1250:	test: 0.9563294	best: 0.9563340 (1246)	total: 2m 42s	remaining: 8m 6s
# 1300:	test: 0.9564788	best: 0.9565155 (1292)	total: 2m 49s	remaining: 8m
# 1350:	test: 0.9565544	best: 0.9565908 (1344)	total: 2m 55s	remaining: 7m 54s
# 1400:	test: 0.9565940	best: 0.9566157 (1363)	total: 3m 1s	remaining: 7m 47s
# 1450:	test: 0.9565390	best: 0.9566157 (1363)	total: 3m 8s	remaining: 7m 40s
# 1500:	test: 0.9565763	best: 0.9566157 (1363)	total: 3m 14s	remaining: 7m 33s
# 1550:	test: 0.9566103	best: 0.9566157 (1363)	total: 3m 21s	remaining: 7m 27s
# 1600:	test: 0.9566623	best: 0.9566795 (1599)	total: 3m 27s	remaining: 7m 20s
# 1650:	test: 0.9567920	best: 0.9568202 (1647)	total: 3m 33s	remaining: 7m 13s
# 1700:	test: 0.9568716	best: 0.9568834 (1683)	total: 3m 40s	remaining: 7m 6s
# 1750:	test: 0.9568094	best: 0.9569252 (1736)	total: 3m 46s	remaining: 6m 59s
# 1800:	test: 0.9570620	best: 0.9570620 (1800)	total: 3m 52s	remaining: 6m 52s
# 1850:	test: 0.9571317	best: 0.9571484 (1835)	total: 3m 58s	remaining: 6m 46s
# 1900:	test: 0.9571865	best: 0.9572243 (1886)	total: 4m 4s	remaining: 6m 39s
# 1950:	test: 0.9571646	best: 0.9572243 (1886)	total: 4m 11s	remaining: 6m 32s
# 2000:	test: 0.9571440	best: 0.9572243 (1886)	total: 4m 17s	remaining: 6m 25s
# 2050:	test: 0.9571247	best: 0.9572243 (1886)	total: 4m 23s	remaining: 6m 18s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.9572242869
# bestIteration = 1886
#
# Shrink model to first 1887 iterations.

# %%
cat_clf_1 = CatBoosterClassifier.CatBoostClassifier(**cat_params[1])
cat_clf_1.fit(X_train_prep, y_train, eval_set=(X_test_prep, y_test_cat), early_stopping_rounds=200, verbose=50)
# Out:
# 0:	test: 0.8855804	best: 0.8855804 (0)	total: 28.4ms	remaining: 42.5s
# 50:	test: 0.9466704	best: 0.9466704 (50)	total: 1.7s	remaining: 48.4s
# 100:	test: 0.9532432	best: 0.9532432 (100)	total: 3.19s	remaining: 44.1s
# 150:	test: 0.9547997	best: 0.9548737 (136)	total: 4.51s	remaining: 40.3s
# 200:	test: 0.9570397	best: 0.9570397 (200)	total: 5.84s	remaining: 37.7s
# 250:	test: 0.9575087	best: 0.9575325 (247)	total: 7.09s	remaining: 35.3s
# 300:	test: 0.9580442	best: 0.9580442 (300)	total: 8.5s	remaining: 33.9s
# 350:	test: 0.9586021	best: 0.9586160 (344)	total: 10.1s	remaining: 33.1s
# 400:	test: 0.9585136	best: 0.9587749 (363)	total: 11.4s	remaining: 31.3s
# 450:	test: 0.9588652	best: 0.9588662 (443)	total: 12.9s	remaining: 30.1s
# 500:	test: 0.9588589	best: 0.9589277 (455)	total: 14.3s	remaining: 28.6s
# 550:	test: 0.9588397	best: 0.9589546 (517)	total: 15.9s	remaining: 27.5s
# 600:	test: 0.9588573	best: 0.9589546 (517)	total: 17.3s	remaining: 25.9s
# 650:	test: 0.9591834	best: 0.9591958 (646)	total: 19.2s	remaining: 25s
# 700:	test: 0.9595459	best: 0.9596208 (684)	total: 21.1s	remaining: 24.1s
# 750:	test: 0.9597472	best: 0.9598275 (747)	total: 22.8s	remaining: 22.7s
# 800:	test: 0.9596018	best: 0.9598275 (747)	total: 24.4s	remaining: 21.3s
# 850:	test: 0.9596203	best: 0.9598275 (747)	total: 25.7s	remaining: 19.6s
# 900:	test: 0.9592486	best: 0.9598275 (747)	total: 27s	remaining: 17.9s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.959827466
# bestIteration = 747
#
# Shrink model to first 748 iterations.

# %%
cat_clf_2 = CatBoosterClassifier.CatBoostClassifier(**cat_params[2])
cat_clf_2.fit(X_train_prep, y_train, eval_set=(X_test_prep, y_test_cat), early_stopping_rounds=200, verbose=50)
# Out:
# 0:	test: 0.8884270	best: 0.8884270 (0)	total: 39.3ms	remaining: 1m 57s
# 50:	test: 0.9490826	best: 0.9490826 (50)	total: 1.76s	remaining: 1m 41s
# 100:	test: 0.9536958	best: 0.9536958 (100)	total: 3.55s	remaining: 1m 41s
# 150:	test: 0.9552012	best: 0.9552020 (149)	total: 5.21s	remaining: 1m 38s
# 200:	test: 0.9567336	best: 0.9567336 (200)	total: 7.19s	remaining: 1m 40s
# 250:	test: 0.9572742	best: 0.9573473 (225)	total: 9.39s	remaining: 1m 42s
# 300:	test: 0.9575185	best: 0.9575185 (300)	total: 11.2s	remaining: 1m 40s
# 350:	test: 0.9574038	best: 0.9575343 (323)	total: 12.7s	remaining: 1m 36s
# 400:	test: 0.9577072	best: 0.9577072 (400)	total: 14.4s	remaining: 1m 33s
# 450:	test: 0.9580413	best: 0.9580517 (449)	total: 15.9s	remaining: 1m 30s
# 500:	test: 0.9581806	best: 0.9582802 (482)	total: 17.4s	remaining: 1m 26s
# 550:	test: 0.9580079	best: 0.9582802 (482)	total: 19s	remaining: 1m 24s
# 600:	test: 0.9579940	best: 0.9582802 (482)	total: 20.6s	remaining: 1m 22s
# 650:	test: 0.9578055	best: 0.9582802 (482)	total: 22.2s	remaining: 1m 19s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.9582801778
# bestIteration = 482
#
# Shrink model to first 483 iterations.

# %%
cat_clf_3 = CatBoosterClassifier.CatBoostClassifier(**cat_params[3])
cat_clf_3.fit(X_train_prep, y_train, eval_set=(X_test_prep, y_test_cat), early_stopping_rounds=200, verbose=50)
# Out:
# 0:	test: 0.8958575	best: 0.8958575 (0)	total: 121ms	remaining: 14m 6s
# 50:	test: 0.9279955	best: 0.9279955 (50)	total: 2.22s	remaining: 5m 2s
# 100:	test: 0.9354182	best: 0.9354182 (100)	total: 4.26s	remaining: 4m 50s
# 150:	test: 0.9396179	best: 0.9396179 (150)	total: 6.32s	remaining: 4m 46s
# 200:	test: 0.9428561	best: 0.9428561 (200)	total: 8.34s	remaining: 4m 42s
# 250:	test: 0.9447389	best: 0.9447389 (250)	total: 10.3s	remaining: 4m 36s
# 300:	test: 0.9470127	best: 0.9470127 (300)	total: 12.1s	remaining: 4m 29s
# 350:	test: 0.9481959	best: 0.9481959 (350)	total: 13.9s	remaining: 4m 23s
# 400:	test: 0.9492682	best: 0.9492682 (400)	total: 15.7s	remaining: 4m 18s
# 450:	test: 0.9501160	best: 0.9501160 (450)	total: 17.5s	remaining: 4m 14s
# 500:	test: 0.9509767	best: 0.9509767 (500)	total: 19.4s	remaining: 4m 11s
# 550:	test: 0.9518964	best: 0.9519049 (549)	total: 21.1s	remaining: 4m 7s
# 600:	test: 0.9525691	best: 0.9525816 (596)	total: 22.9s	remaining: 4m 4s
# 650:	test: 0.9529495	best: 0.9529495 (650)	total: 24.7s	remaining: 4m 1s
# 700:	test: 0.9536611	best: 0.9536611 (700)	total: 26.6s	remaining: 3m 59s
# 750:	test: 0.9542719	best: 0.9542719 (750)	total: 28.4s	remaining: 3m 56s
# 800:	test: 0.9545828	best: 0.9545828 (800)	total: 30.2s	remaining: 3m 53s
# 850:	test: 0.9547757	best: 0.9547787 (842)	total: 32s	remaining: 3m 51s
# 900:	test: 0.9548633	best: 0.9548729 (898)	total: 34s	remaining: 3m 49s
# 950:	test: 0.9550642	best: 0.9550974 (948)	total: 36.1s	remaining: 3m 49s
# 1000:	test: 0.9551875	best: 0.9551881 (998)	total: 37.9s	remaining: 3m 47s
# 1050:	test: 0.9554482	best: 0.9554487 (1046)	total: 39.9s	remaining: 3m 45s
# 1100:	test: 0.9556204	best: 0.9556503 (1097)	total: 42.1s	remaining: 3m 45s
# 1150:	test: 0.9556353	best: 0.9557079 (1121)	total: 44.1s	remaining: 3m 44s
# 1200:	test: 0.9558295	best: 0.9558333 (1199)	total: 45.9s	remaining: 3m 41s
# 1250:	test: 0.9559997	best: 0.9560461 (1239)	total: 47.7s	remaining: 3m 39s
# 1300:	test: 0.9561229	best: 0.9561229 (1300)	total: 49.5s	remaining: 3m 36s
# 1350:	test: 0.9562619	best: 0.9562619 (1350)	total: 51.3s	remaining: 3m 34s
# 1400:	test: 0.9563810	best: 0.9563810 (1400)	total: 53.1s	remaining: 3m 32s
# 1450:	test: 0.9565158	best: 0.9565159 (1447)	total: 54.8s	remaining: 3m 29s
# 1500:	test: 0.9566112	best: 0.9566367 (1491)	total: 56.6s	remaining: 3m 27s
# 1550:	test: 0.9566138	best: 0.9566487 (1504)	total: 58.4s	remaining: 3m 25s
# 1600:	test: 0.9565881	best: 0.9566621 (1566)	total: 1m	remaining: 3m 23s
# 1650:	test: 0.9566041	best: 0.9566621 (1566)	total: 1m 2s	remaining: 3m 21s
# 1700:	test: 0.9566873	best: 0.9567092 (1693)	total: 1m 4s	remaining: 3m 19s
# 1750:	test: 0.9567823	best: 0.9567841 (1746)	total: 1m 6s	remaining: 3m 18s
# 1800:	test: 0.9567740	best: 0.9568365 (1776)	total: 1m 8s	remaining: 3m 16s
# 1850:	test: 0.9568411	best: 0.9568601 (1848)	total: 1m 9s	remaining: 3m 14s
# 1900:	test: 0.9566866	best: 0.9568601 (1848)	total: 1m 11s	remaining: 3m 11s
# 1950:	test: 0.9566716	best: 0.9568601 (1848)	total: 1m 13s	remaining: 3m 9s
# 2000:	test: 0.9567069	best: 0.9568601 (1848)	total: 1m 14s	remaining: 3m 7s
# Stopped by overfitting detector  (200 iterations wait)
#
# bestTest = 0.9568601086
# bestIteration = 1848
#
# Shrink model to first 1849 iterations.

# %%
y_preds_cat_0 = cat_clf_0.predict_proba(X_test_cat)
auc_cat_0 = roc_auc_score(y_test_cat, y_preds_cat_0[:, 1])

y_preds_cat_1 = cat_clf_1.predict_proba(X_test_cat)
auc_cat_1 = roc_auc_score(y_test_cat, y_preds_cat_1[:, 1])

y_preds_cat_2 = cat_clf_2.predict_proba(X_test_cat)
auc_cat_2 = roc_auc_score(y_test_cat, y_preds_cat_2[:, 1])

y_preds_cat_3 = cat_clf_3.predict_proba(X_test_cat)
auc_cat_3 = roc_auc_score(y_test_cat, y_preds_cat_3[:, 1])

auc_cat_0, auc_cat_1, auc_cat_2, auc_cat_3
# Out:
# (0.9572242868857734,
#  0.9592276090524516,
#  0.9589631614774814,
#  0.9567769391641247)

# %% [markdown]
# # Predictions and submission

# %%
cat_clf_1.fit(preprocessor.transform(X), y, verbose=50, early_stopping_rounds=200)
# Out:
# 0:	total: 32.9ms	remaining: 49.3s
# 50:	total: 1.58s	remaining: 45s
# 100:	total: 3.01s	remaining: 41.7s
# 150:	total: 4.43s	remaining: 39.6s
# 200:	total: 5.89s	remaining: 38.1s
# 250:	total: 7.28s	remaining: 36.2s
# 300:	total: 8.67s	remaining: 34.5s
# 350:	total: 10.1s	remaining: 33.2s
# 400:	total: 11.7s	remaining: 32s
# 450:	total: 13.1s	remaining: 30.5s
# 500:	total: 14.5s	remaining: 28.9s
# 550:	total: 15.9s	remaining: 27.3s
# 600:	total: 17.3s	remaining: 25.8s
# 650:	total: 18.5s	remaining: 24.2s
# 700:	total: 19.9s	remaining: 22.7s
# 750:	total: 21.2s	remaining: 21.2s
# 800:	total: 23s	remaining: 20s
# 850:	total: 24.7s	remaining: 18.8s
# 900:	total: 26.1s	remaining: 17.4s
# 950:	total: 27.5s	remaining: 15.9s
# 1000:	total: 29s	remaining: 14.4s
# 1050:	total: 30.4s	remaining: 13s
# 1100:	total: 31.8s	remaining: 11.5s
# 1150:	total: 33.2s	remaining: 10.1s
# 1200:	total: 34.6s	remaining: 8.61s
# 1250:	total: 36.1s	remaining: 7.18s
# 1300:	total: 37.5s	remaining: 5.73s
# 1350:	total: 38.9s	remaining: 4.29s
# 1400:	total: 40.2s	remaining: 2.84s
# 1450:	total: 41.6s	remaining: 1.41s
# 1499:	total: 43.2s	remaining: 0us

# %%
y_preds_cat = cat_clf_1.predict_proba(preprocessor.transform(data_to_predict))[:,1]
y_preds_cat
# Out:
# array([0.99977203, 0.05595793, 0.51426483, ..., 0.00193344, 0.21880379,
#        0.95807827])

# %%
# to DF
submission = pd.DataFrame({'id': data_to_predict['id'], 'loan_status': y_preds_cat})
submission.to_csv('../submissions/catboost_v1.csv', index=False)

# %% [markdown]
# # Experimenting with stacking

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.linear_model import LogisticRegression

# %%
xgb_v2 = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc')
xgb_v2.load_model('../models/xgboost_v2.json')

xgb_v3 = xgb.XGBClassifier(objective='binary:logistic', eval_metric='auc')
xgb_v3.load_model('../models/xgboost_v3.json')

cat_v1 = cat_clf_1

log_reg = LogisticRegression()

estimators = [
	('xgb_v2', xgb_v2),
	('xgb_v3', xgb_v3),
	('cat_v1', cat_v1)
]

stacking_clf = StackingClassifier(estimators=estimators, final_estimator=log_reg, cv=5)

# %%
stacking_clf.fit(X_train_prep, y_train)
# Out:
# 0:	total: 29ms	remaining: 43.5s
# 200:	total: 5.32s	remaining: 34.4s
# 400:	total: 10.5s	remaining: 28.9s
# 600:	total: 15.2s	remaining: 22.7s
# 800:	total: 20.1s	remaining: 17.5s
# 1000:	total: 25.2s	remaining: 12.6s
# 1200:	total: 30.2s	remaining: 7.51s
# 1400:	total: 35.4s	remaining: 2.5s
# 1499:	total: 37.9s	remaining: 0us
# 0:	total: 22.7ms	remaining: 34s
# 200:	total: 4.41s	remaining: 28.5s
# 400:	total: 8.64s	remaining: 23.7s
# 600:	total: 12.9s	remaining: 19.3s
# 800:	total: 17.1s	remaining: 14.9s
# 1000:	total: 21.7s	remaining: 10.8s
# 1200:	total: 26.2s	remaining: 6.52s
# 1400:	total: 30.7s	remaining: 2.17s
# 1499:	total: 32.9s	remaining: 0us
# 0:	total: 21.9ms	remaining: 32.9s
# 200:	total: 4.34s	remaining: 28.1s
# 400:	total: 8.61s	remaining: 23.6s
# 600:	total: 12.8s	remaining: 19.2s
# 800:	total: 16.7s	remaining: 14.6s
# 1000:	total: 21s	remaining: 10.5s
# 1200:	total: 25.8s	remaining: 6.41s
# 1400:	total: 31.7s	remaining: 2.24s
# 1499:	total: 34.2s	remaining: 0us
# 0:	total: 25ms	remaining: 37.4s
# 200:	total: 5.2s	remaining: 33.6s
# 400:	total: 10.2s	remaining: 27.9s
# 600:	total: 14.5s	remaining: 21.6s
# 800:	total: 19.3s	remaining: 16.8s
# 1000:	total: 23.6s	remaining: 11.8s
# 1200:	total: 27.8s	remaining: 6.92s
# 1400:	total: 32.1s	remaining: 2.27s
# 1499:	total: 34.1s	remaining: 0us
# 0:	total: 23.8ms	remaining: 35.7s
# 200:	total: 4.96s	remaining: 32s
# 400:	total: 9.9s	remaining: 27.1s
# 600:	total: 14.3s	remaining: 21.4s
# 800:	total: 18.3s	remaining: 16s
# 1000:	total: 22.7s	remaining: 11.3s
# 1200:	total: 27s	remaining: 6.73s
# 1400:	total: 31.2s	remaining: 2.2s
# 1499:	total: 33.4s	remaining: 0us
# 0:	total: 24.2ms	remaining: 36.3s
# 200:	total: 4.02s	remaining: 26s
# 400:	total: 8.86s	remaining: 24.3s
# 600:	total: 14.9s	remaining: 22.3s
# 800:	total: 19.4s	remaining: 17s
# 1000:	total: 24s	remaining: 12s
# 1200:	total: 28.4s	remaining: 7.08s
# 1400:	total: 32.8s	remaining: 2.32s
# 1499:	total: 35.4s	remaining: 0us
# StackingClassifier(cv=5,
#                    estimators=[('xgb_v2',
#                                 XGBClassifier(base_score='1.9302522E-1',
#                                               booster='gbtree', callbacks=None,
#                                               colsample_bylevel=None,
#                                               colsample_bynode=None,
#                                               colsample_bytree=None,
#                                               device=None,
#                                               early_stopping_rounds=None,
#                                               enable_categorical=False,
#                                               eval_metric='auc',
#                                               feature_types=None, gamma=None,
#                                               grow_policy=None,
#                                               importance_type=None,
#                                               interaction_con...
#                                               max_cat_threshold=None,
#                                               max_cat_to_onehot=None,
#                                               max_delta_step=None,
#                                               max_depth=None, max_leaves=None,
#                                               min_child_weight=None,
#                                               missing=nan,
#                                               monotone_constraints=None,
#                                               multi_strategy=None,
#                                               n_estimators=None, n_jobs=None,
#                                               num_parallel_tree=None,
#                                               random_state=None, ...)),
#                                ('cat_v1',
#                                 <catboost.core.CatBoostClassifier object at 0x0000024191EC5400>)],
#                    final_estimator=LogisticRegression())

# %%
y_preds_stacking = stacking_clf.predict_proba(X_test_prep)
roc_auc_score(y_test, y_preds_stacking[:, 1])
# Out:
# 0.9607703941986889

# %%
stacking_clf.fit(preprocessor.transform(X), y)
y_preds_stacking_sub = stacking_clf.predict_proba(preprocessor.transform(data_to_predict))[:, 1]
# Out:
# 0:	total: 27ms	remaining: 40.4s
# 200:	total: 7.8s	remaining: 50.4s
# 400:	total: 14.1s	remaining: 38.6s
# 600:	total: 19.8s	remaining: 29.7s
# 800:	total: 25.4s	remaining: 22.2s
# 1000:	total: 31.1s	remaining: 15.5s
# 1200:	total: 36.8s	remaining: 9.17s
# 1400:	total: 42.8s	remaining: 3.03s
# 1499:	total: 45.6s	remaining: 0us
# 0:	total: 27.1ms	remaining: 40.6s
# 200:	total: 5.14s	remaining: 33.2s
# 400:	total: 10.2s	remaining: 28s
# 600:	total: 15.4s	remaining: 23s
# 800:	total: 20.4s	remaining: 17.8s
# 1000:	total: 25.4s	remaining: 12.7s
# 1200:	total: 30.5s	remaining: 7.59s
# 1400:	total: 35.4s	remaining: 2.5s
# 1499:	total: 37.9s	remaining: 0us
# 0:	total: 23.3ms	remaining: 34.9s
# 200:	total: 4.96s	remaining: 32.1s
# 400:	total: 9.99s	remaining: 27.4s
# 600:	total: 15.2s	remaining: 22.8s
# 800:	total: 20.2s	remaining: 17.7s
# 1000:	total: 25.6s	remaining: 12.7s
# 1200:	total: 30.5s	remaining: 7.59s
# 1400:	total: 35.2s	remaining: 2.49s
# 1499:	total: 37.5s	remaining: 0us
# 0:	total: 23.8ms	remaining: 35.6s
# 200:	total: 5.17s	remaining: 33.4s
# 400:	total: 10.4s	remaining: 28.5s
# 600:	total: 15.3s	remaining: 22.9s
# 800:	total: 20.8s	remaining: 18.1s
# 1000:	total: 25.7s	remaining: 12.8s
# 1200:	total: 30.8s	remaining: 7.66s
# 1400:	total: 35.6s	remaining: 2.52s
# 1499:	total: 38.1s	remaining: 0us
# 0:	total: 23.6ms	remaining: 35.4s
# 200:	total: 5.13s	remaining: 33.2s
# 400:	total: 10.1s	remaining: 27.6s
# 600:	total: 15s	remaining: 22.4s
# 800:	total: 20s	remaining: 17.4s
# 1000:	total: 24.9s	remaining: 12.4s
# 1200:	total: 30s	remaining: 7.46s
# 1400:	total: 34.9s	remaining: 2.47s
# 1499:	total: 37.4s	remaining: 0us
# 0:	total: 26.4ms	remaining: 39.6s
# 200:	total: 5.63s	remaining: 36.4s
# 400:	total: 10.8s	remaining: 29.7s
# 600:	total: 15.7s	remaining: 23.5s
# 800:	total: 20.7s	remaining: 18s
# 1000:	total: 25.4s	remaining: 12.7s
# 1200:	total: 30.3s	remaining: 7.54s
# 1400:	total: 35s	remaining: 2.47s
# 1499:	total: 37.2s	remaining: 0us

# %%
submission = pd.DataFrame({'id': data_to_predict['id'], 'loan_status': y_preds_stacking_sub})
submission.to_csv('../submissions/stacking_v1.csv', index=False)
